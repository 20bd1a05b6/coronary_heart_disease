# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("CHD_preprocessed.csv")
data.columns = ['sex','Age','Education','CurrentSmoker','CigsPerDay','BPMeds','PrevalentStroke','PrevalentHyp','Diabetes','TotChol','SysBP','DiaBP','BMI','HeartRate','Glucose','TenYearCHD']
data.head()
# Out:
#    sex  Age  Education  CurrentSmoker  CigsPerDay  BPMeds  PrevalentStroke  \
# 0    1   39          1              0           0       0                0
# 1    0   46          0              0           0       0                0
# 2    1   48          0              1          20       0                0
# 3    0   61          1              1          30       0                0
# 4    0   46          1              1          23       0                0
#
#    PrevalentHyp  Diabetes  TotChol  SysBP  DiaBP    BMI  HeartRate  Glucose  \
# 0             0         0      195  106.0   70.0  26.97         80       77
# 1             0         0      250  121.0   81.0  28.73         95       76
# 2             0         0      245  127.5   80.0  25.34         75       70
# 3             1         0      225  150.0   95.0  28.58         65      103
# 4             0         0      285  130.0   84.0  23.10         85       85
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('CHD_preprocessed.csv')

# Define a function to classify sex column and create separate 'male' and 'female' columns
def classify_sex(row):
    if row['sex'] == 'female':
        return 1
    else:
        return 0

# Apply the function to create 'male' and 'female' columns
df['male'] = df.apply(classify_sex, axis=1)
df['female'] = 1 - df['male']  # Alternatively, you can create 'female' column using this formula

# Write the updated DataFrame back to a new CSV file
df.to_csv("processed.csv", index=False)

# Display the first few rows of the updated DataFrame
print(df.head())
# Out:
#    sex  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0    1   39          1              0           0       0                0
# 1    0   46          0              0           0       0                0
# 2    1   48          0              1          20       0                0
# 3    0   61          1              1          30       0                0
# 4    0   46          1              1          23       0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0      195  106.0   70.0  26.97         80       77
# 1             0         0      250  121.0   81.0  28.73         95       76
# 2             0         0      245  127.5   80.0  25.34         75       70
# 3             1         0      225  150.0   95.0  28.58         65      103
# 4             0         0      285  130.0   84.0  23.10         85       85
#
#    TenYearCHD  male  female
# 0           0     0       1
# 1           0     0       1
# 2           0     0       1
# 3           1     0       1
# 4           0     0       1

# %%
data = data.drop(columns=['Education'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4133 entries, 0 to 4132
# Data columns (total 15 columns):
# sex                4133 non-null int64
# Age                4133 non-null int64
# CurrentSmoker      4133 non-null int64
# CigsPerDay         4133 non-null int64
# BPMeds             4133 non-null int64
# PrevalentStroke    4133 non-null int64
# PrevalentHyp       4133 non-null int64
# Diabetes           4133 non-null int64
# TotChol            4133 non-null int64
# SysBP              4133 non-null float64
# DiaBP              4133 non-null float64
# BMI                4133 non-null float64
# HeartRate          4133 non-null int64
# Glucose            4133 non-null int64
# TenYearCHD         4133 non-null int64
# dtypes: float64(3), int64(12)
# memory usage: 484.5 KB

# %%
data.isnull().sum()
# Out:
# sex                0
# Age                0
# CurrentSmoker      0
# CigsPerDay         0
# BPMeds             0
# PrevalentStroke    0
# PrevalentHyp       0
# Diabetes           0
# TotChol            0
# SysBP              0
# DiaBP              0
# BMI                0
# HeartRate          0
# Glucose            0
# TenYearCHD         0
# dtype: int64

# %%
l = ['CigsPerDay', 'BPMeds', 'TotChol', 'HeartRate', 'BMI', 'Glucose', 'PrevalentStroke', 'Diabetes',
    'SysBP', 'DiaBP']
for i in l:
    data[i] = data[i].replace(np.nan, data[i].mean())

# %%
data.isnull().sum()
# Out:
# sex                0
# Age                0
# CurrentSmoker      0
# CigsPerDay         0
# BPMeds             0
# PrevalentStroke    0
# PrevalentHyp       0
# Diabetes           0
# TotChol            0
# SysBP              0
# DiaBP              0
# BMI                0
# HeartRate          0
# Glucose            0
# TenYearCHD         0
# dtype: int64

# %%
sns.countplot(x=data['TenYearCHD'])
# Out:
# <AxesSubplot:xlabel='TenYearCHD', ylabel='count'>

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %%
q1 = data.drop('TenYearCHD', axis = 1).quantile(0.25)

# compute the first quartile using quantile(0.75)
# use .drop() to drop the target variable 
# axis=1: specifies that the labels are dropped from the columns
q3 = data.drop('TenYearCHD', axis = 1).quantile(0.75)

# calculate of interquartile range 
IQR = q3 - q1

LL = q1 - 1.5 * IQR
UL = q3 + 1.5 * IQR

data = data[~((data < LL) | (data > UL)).any(axis = 1)]

# %%
data.shape
# Out:
# (3435, 15)

# %%
X = data.drop(["TenYearCHD"],axis =1)
y = data["TenYearCHD"]

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE(sampling_strategy = 'minority', random_state = 1)
X, y = oversample.fit_resample(X, y)

# %%
X = X.drop(['BPMeds', 'PrevalentStroke', 'Diabetes'], axis = 1)

# %%
X.columns
# Out:
# Index(['sex', 'Age', 'CurrentSmoker', 'CigsPerDay', 'PrevalentHyp', 'TotChol',
#        'SysBP', 'DiaBP', 'BMI', 'HeartRate', 'Glucose'],
#       dtype='object')

# %%
df = data[['sex', 'Age', 'CurrentSmoker', 'CigsPerDay', 'PrevalentHyp', 'TotChol',
       'SysBP', 'DiaBP', 'BMI', 'HeartRate', 'Glucose','TenYearCHD']]
df.to_csv('processed.csv')

# %%
# Assuming X and y are defined elsewhere in your code
from sklearn.model_selection import train_test_split

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Printing the shapes of the resulting arrays
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (4790, 11)
# y_train shape: (4790,)
# X_test shape: (1198, 11)
# y_test shape: (1198,)

# %%
ML_Model = []
accuracy = []
precision = []
recall = []
f1score = []
auprc = []
auroc = []
mcc = []
sens = []
spec = []

#function to call for storing the results
def storeResults(model, a,b,c,d,e,f,g,h,i):
    ML_Model.append(model)
    accuracy.append(round(a, 3))
    precision.append(round(b, 3))
    recall.append(round(c, 3))
    f1score.append(round(d, 3))
    auprc.append(round(e, 3))
    auroc.append(round(f, 3))
    mcc.append(round(g, 3))
    sens.append(round(h, 3))
    spec.append(round(i, 3))

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score, matthews_corrcoef, confusion_matrix

# %% [markdown]
# # AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# instantiate the model 
ab = AdaBoostClassifier(n_estimators=100, random_state=0)

# fit the model 
ab.fit(X_train, y_train)

#predicting the target value from the model for the samples

y_pred = ab.predict(X_test)

confusion = confusion_matrix(y_pred, y_test)
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

ab_acc = accuracy_score(y_pred, y_test)
ab_prec = precision_score(y_pred, y_test)
ab_rec = recall_score(y_pred, y_test)
ab_f1 = f1_score(y_pred, y_test)
ab_auprc = average_precision_score(y_pred, y_test)
ab_auroc = roc_auc_score(y_test, ab.predict_proba(X_test)[:, 1])
ab_mcc = matthews_corrcoef(y_pred, y_test)

ab_sens = TP / (TP + FN)
ab_spec = TN / (TN + FP)

storeResults('AdaBoost Classifier',ab_acc,ab_prec,ab_rec,ab_f1,ab_auprc,ab_auroc,ab_mcc,ab_sens,ab_spec)

# %%
ab_acc
# Out:
# 0.7270450751252087

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

#predicting the target value from the model for the samples

y_pred = tree.predict(X_test)

confusion = confusion_matrix(y_pred, y_test)
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

dt_acc = accuracy_score(y_pred, y_test)
dt_prec = precision_score(y_pred, y_test)
dt_rec = recall_score(y_pred, y_test)
dt_f1 = f1_score(y_pred, y_test)
dt_auprc = average_precision_score(y_pred, y_test)
dt_auroc = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_mcc = matthews_corrcoef(y_pred, y_test)

dt_sens = TP / (TP + FN)
dt_spec = TN / (TN + FP)

storeResults('Decision Tree Classifier',dt_acc,dt_prec,dt_rec,dt_f1,dt_auprc,dt_auroc,dt_mcc,dt_sens,dt_spec)

# %%
dt_acc
# Out:
# 0.7821368948247078

# %% [markdown]
# # Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC

# instantiate the model 
clf = BaggingClassifier(SVC(),n_estimators=10, random_state=0)

# fit the model 
clf.fit(X_train, y_train)

#predicting the target value from the model for the samples

y_pred = clf.predict(X_test)

confusion = confusion_matrix(y_pred, y_test)
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

bg_acc = accuracy_score(y_pred, y_test)
bg_prec = precision_score(y_pred, y_test)
bg_rec = recall_score(y_pred, y_test)
bg_f1 = f1_score(y_pred, y_test)
bg_auprc = average_precision_score(y_pred, y_test)
bg_auroc = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
bg_mcc = matthews_corrcoef(y_pred, y_test)

bg_sens = TP / (TP + FN)
bg_spec = TN / (TN + FP)

storeResults('Bagging Classifier',bg_acc,bg_prec,bg_rec,bg_f1,bg_auprc,bg_auroc,bg_mcc,bg_sens,bg_spec)

# %%
bg_acc
# Out:
# 0.6519198664440734

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# instantiate the model 
gbm = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,max_depth=1, random_state=0)

# fit the model 
gbm.fit(X_train, y_train)

#predicting the target value from the model for the samples

y_pred = gbm.predict(X_test)

confusion = confusion_matrix(y_pred, y_test)
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

gb_acc = accuracy_score(y_pred, y_test)
gb_prec = precision_score(y_pred, y_test)
gb_rec = recall_score(y_pred, y_test)
gb_f1 = f1_score(y_pred, y_test)
gb_auprc = average_precision_score(y_pred, y_test)
gb_auroc = roc_auc_score(y_test, gbm.predict_proba(X_test)[:, 1])
gb_mcc = matthews_corrcoef(y_pred, y_test)

gb_sens = TP / (TP + FN)
gb_spec = TN / (TN + FP)

storeResults('Gradient Boosting Classifier',gb_acc,gb_prec,gb_rec,gb_f1,gb_auprc,gb_auroc,gb_mcc,gb_sens,gb_spec)

# %%
gb_acc
# Out:
# 0.7512520868113522

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

# instantiate the model
xgb = XGBClassifier()

# fit the model 
xgb.fit(X_train, y_train)

#predicting the target value from the model for the samples

y_pred = xgb.predict(X_test)

confusion = confusion_matrix(y_pred, y_test)
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

xgb_acc = accuracy_score(y_pred, y_test)
xgb_prec = precision_score(y_pred, y_test)
xgb_rec = recall_score(y_pred, y_test)
xgb_f1 = f1_score(y_pred, y_test)
xgb_auprc = average_precision_score(y_pred, y_test)
xgb_auroc = roc_auc_score(y_test, xgb.predict_proba(X_test)[:, 1])
xgb_mcc = matthews_corrcoef(y_pred, y_test)

xgb_sens = TP / (TP + FN)
xgb_spec = TN / (TN + FP)

storeResults('XGBoost Classifier',xgb_acc,xgb_prec,xgb_rec,xgb_f1,xgb_auprc,xgb_auroc,xgb_mcc,xgb_sens,xgb_spec)

# %%
xgb_acc
# Out:
# 0.8881469115191987

# %% [markdown]
# # CatBoost

# %%
from catboost import CatBoostClassifier

clf = CatBoostClassifier(
    iterations=5, 
    learning_rate=0.1, 
    #loss_function='CrossEntropy'
)

# fit the model 
clf.fit(X_train, y_train)

#predicting the target value from the model for the samples

y_pred = clf.predict(X_test)

confusion = confusion_matrix(y_pred, y_test)
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

cat_acc = accuracy_score(y_pred, y_test)
cat_prec = precision_score(y_pred, y_test)
cat_rec = recall_score(y_pred, y_test)
cat_f1 = f1_score(y_pred, y_test)
cat_auprc = average_precision_score(y_pred, y_test)
cat_auroc = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
cat_mcc = matthews_corrcoef(y_pred, y_test)

cat_sens = TP / (TP + FN)
cat_spec = TN / (TN + FP)

storeResults('CatBoost Classifier',cat_acc,cat_prec,cat_rec,cat_f1,cat_auprc,cat_auroc,cat_mcc,cat_sens,cat_spec)
# Out:
# 0:	learn: 0.6822355	total: 146ms	remaining: 584ms
# 1:	learn: 0.6687898	total: 149ms	remaining: 224ms
# 2:	learn: 0.6580490	total: 152ms	remaining: 102ms
# 3:	learn: 0.6509901	total: 155ms	remaining: 38.8ms
# 4:	learn: 0.6405928	total: 158ms	remaining: 0us

# %%
cat_acc
# Out:
# 0.6686143572621035

# %% [markdown]
# # LightGBM

# %%
import lightgbm as lgb
clf = lgb.LGBMClassifier(boosting_type='gbdt',verbosity=1,metric='auc',objctive='binary',num_threads = 10000,force_row_wise=True)
clf.fit(X_train, y_train, verbose=0)

y_pred = clf.predict(X_test)

confusion = confusion_matrix(y_pred, y_test)
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

lgb_acc = accuracy_score(y_pred, y_test)
lgb_prec = precision_score(y_pred, y_test)
lgb_rec = recall_score(y_pred, y_test)
lgb_f1 = f1_score(y_pred, y_test)
lgb_auprc = average_precision_score(y_pred, y_test)
lgb_auroc = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
lgb_mcc = matthews_corrcoef(y_pred, y_test)

lgb_sens = TP / (TP + FN)
lgb_spec = TN / (TN + FP)

storeResults('LightGBM w/o Focal Loss',lgb_acc,lgb_prec,lgb_rec,lgb_f1,lgb_auprc,lgb_auroc,lgb_mcc,lgb_sens,lgb_spec)
# Out:
# [LightGBM] [Warning] Unknown parameter: objctive
# [LightGBM] [Warning] num_threads is set=10000, n_jobs=-1 will be ignored. Current value: num_threads=10000
# [LightGBM] [Warning] Unknown parameter: objctive
# [LightGBM] [Warning] num_threads is set=10000, n_jobs=-1 will be ignored. Current value: num_threads=10000
# [LightGBM] [Info] Number of positive: 2389, number of negative: 2401
# [LightGBM] [Info] Total Bins 1162
# [LightGBM] [Info] Number of data points in the train set: 4790, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498747 -> initscore=-0.005010
# [LightGBM] [Info] Start training from score -0.005010

# %%
lgb_acc
# Out:
# 0.8739565943238731

# %% [markdown]
# # LightGBM with Focal Loss

# %%
from scipy.misc import derivative

def focal_loss(ytrue, ypred, gamma=2.0):   
    p = 1 / (1 + np.exp(-ypred))
    loss = -(1 - ytrue) * p**gamma * np.log(1 - p) - ytrue * (1 - p)**gamma * np.log(p)
    return loss


def focal_loss_metric(ytrue, ypred):
    return 'focal_loss_metric', np.mean(focal_loss(ytrue, ypred)), False


def focal_loss_objective(ytrue, ypred):
    func = lambda z: focal_loss(ytrue, z)
    grad = derivative(func, ypred, n=1, dx=1e-6)
    hess = derivative(func, ypred, n=2, dx=1e-6)
    return grad, hess

# %%
gbm_focal_loss = lgb.LGBMClassifier(objective=focal_loss_objective, learning_rate=0.25, n_estimators=16000, max_depth=1,boosting_type='gbdt',verbosity=1,metric='auc',num_threads = 100,force_row_wise=True)
gbm_focal_loss.fit(X_train, y_train, eval_set=[(X_test, y_test)], eval_metric=focal_loss_metric)
# Out:
# [LightGBM] [Warning] num_threads is set=100, n_jobs=-1 will be ignored. Current value: num_threads=100
# [LightGBM] [Warning] num_threads is set=100, n_jobs=-1 will be ignored. Current value: num_threads=100
# [LightGBM] [Warning] Using self-defined objective function
# [LightGBM] [Info] Total Bins 1162
# [LightGBM] [Info] Number of data points in the train set: 4790, number of used features: 11
# [LightGBM] [Warning] num_threads is set=100, n_jobs=-1 will be ignored. Current value: num_threads=100
# [LightGBM] [Warning] Using self-defined objective function
# [1]	valid_0's auc: 0.624735	valid_0's focal_loss_metric: 0.169657
# [2]	valid_0's auc: 0.626041	valid_0's focal_loss_metric: 0.1679
# [3]	valid_0's auc: 0.642174	valid_0's focal_loss_metric: 0.16647
# [4]	valid_0's auc: 0.660774	valid_0's focal_loss_metric: 0.165233
# [5]	valid_0's auc: 0.666096	valid_0's focal_loss_metric: 0.164326
# [6]	valid_0's auc: 0.683539	valid_0's focal_loss_metric: 0.163174
# [7]	valid_0's auc: 0.691111	valid_0's focal_loss_metric: 0.162351
# [8]	valid_0's auc: 0.691761	valid_0's focal_loss_metric: 0.161872
# [9]	valid_0's auc: 0.695228	valid_0's focal_loss_metric: 0.161331
# [10]	valid_0's auc: 0.699469	valid_0's focal_loss_metric: 0.160638
# [11]	valid_0's auc: 0.699397	valid_0's focal_loss_metric: 0.160345
# [12]	valid_0's auc: 0.703799	valid_0's focal_loss_metric: 0.159928
# [13]	valid_0's auc: 0.70456	valid_0's focal_loss_metric: 0.159632
# [14]	valid_0's auc: 0.70256	valid_0's focal_loss_metric: 0.159402
# [15]	valid_0's auc: 0.705145	valid_0's focal_loss_metric: 0.158998
# [16]	valid_0's auc: 0.708005	valid_0's focal_loss_metric: 0.158639
# [17]	valid_0's auc: 0.708458	valid_0's focal_loss_metric: 0.158523
# [18]	valid_0's auc: 0.71061	valid_0's focal_loss_metric: 0.158128
# [19]	valid_0's auc: 0.712176	valid_0's focal_loss_metric: 0.157873
# [20]	valid_0's auc: 0.711413	valid_0's focal_loss_metric: 0.157695
# [21]	valid_0's auc: 0.713829	valid_0's focal_loss_metric: 0.157459
# [22]	valid_0's auc: 0.713746	valid_0's focal_loss_metric: 0.157295
# [23]	valid_0's auc: 0.715906	valid_0's focal_loss_metric: 0.157063
# [24]	valid_0's auc: 0.717261	valid_0's focal_loss_metric: 0.15685
# [25]	valid_0's auc: 0.718546	valid_0's focal_loss_metric: 0.156714
# [26]	valid_0's auc: 0.720672	valid_0's focal_loss_metric: 0.156481
# [27]	valid_0's auc: 0.722324	valid_0's focal_loss_metric: 0.15634
# [28]	valid_0's auc: 0.723871	valid_0's focal_loss_metric: 0.156125
# [29]	valid_0's auc: 0.726455	valid_0's focal_loss_metric: 0.155911
# [30]	valid_0's auc: 0.726254	valid_0's focal_loss_metric: 0.155759
# [31]	valid_0's auc: 0.728824	valid_0's focal_loss_metric: 0.15555
# [32]	valid_0's auc: 0.728372	valid_0's focal_loss_metric: 0.155414
# [33]	valid_0's auc: 0.731015	valid_0's focal_loss_metric: 0.155213
# [34]	valid_0's auc: 0.730404	valid_0's focal_loss_metric: 0.155089
# [35]	valid_0's auc: 0.732609	valid_0's focal_loss_metric: 0.154898
# [36]	valid_0's auc: 0.73187	valid_0's focal_loss_metric: 0.154784
# [37]	valid_0's auc: 0.732445	valid_0's focal_loss_metric: 0.154712
# [38]	valid_0's auc: 0.733137	valid_0's focal_loss_metric: 0.154578
# [39]	valid_0's auc: 0.734065	valid_0's focal_loss_metric: 0.154334
# [40]	valid_0's auc: 0.733979	valid_0's focal_loss_metric: 0.154288
# [41]	valid_0's auc: 0.735992	valid_0's focal_loss_metric: 0.154178
# [42]	valid_0's auc: 0.737232	valid_0's focal_loss_metric: 0.15389
# [43]	valid_0's auc: 0.737979	valid_0's focal_loss_metric: 0.153831
# [44]	valid_0's auc: 0.738265	valid_0's focal_loss_metric: 0.153805
# [45]	valid_0's auc: 0.73917	valid_0's focal_loss_metric: 0.153639
# [46]	valid_0's auc: 0.740545	valid_0's focal_loss_metric: 0.153462
# [47]	valid_0's auc: 0.740464	valid_0's focal_loss_metric: 0.153359
# [48]	valid_0's auc: 0.740782	valid_0's focal_loss_metric: 0.15321
# [49]	valid_0's auc: 0.742407	valid_0's focal_loss_metric: 0.153046
# [50]	valid_0's auc: 0.742047	valid_0's focal_loss_metric: 0.152949
# [51]	valid_0's auc: 0.743881	valid_0's focal_loss_metric: 0.152852
# [52]	valid_0's auc: 0.745938	valid_0's focal_loss_metric: 0.152682
# [53]	valid_0's auc: 0.746749	valid_0's focal_loss_metric: 0.152482
# [54]	valid_0's auc: 0.747021	valid_0's focal_loss_metric: 0.152258
# [55]	valid_0's auc: 0.748494	valid_0's focal_loss_metric: 0.152059
# [56]	valid_0's auc: 0.749729	valid_0's focal_loss_metric: 0.151903
# [57]	valid_0's auc: 0.750691	valid_0's focal_loss_metric: 0.151768
# [58]	valid_0's auc: 0.750972	valid_0's focal_loss_metric: 0.151705
# [59]	valid_0's auc: 0.751089	valid_0's focal_loss_metric: 0.151669
# [60]	valid_0's auc: 0.752115	valid_0's focal_loss_metric: 0.151494
# [61]	valid_0's auc: 0.753745	valid_0's focal_loss_metric: 0.15135
# [62]	valid_0's auc: 0.753238	valid_0's focal_loss_metric: 0.151254
# [63]	valid_0's auc: 0.754955	valid_0's focal_loss_metric: 0.151108
# [64]	valid_0's auc: 0.754236	valid_0's focal_loss_metric: 0.151026
# [65]	valid_0's auc: 0.755694	valid_0's focal_loss_metric: 0.150882
# [66]	valid_0's auc: 0.756463	valid_0's focal_loss_metric: 0.150702
# [67]	valid_0's auc: 0.757023	valid_0's focal_loss_metric: 0.150613
# [68]	valid_0's auc: 0.756715	valid_0's focal_loss_metric: 0.150585
# [69]	valid_0's auc: 0.757156	valid_0's focal_loss_metric: 0.150506
# [70]	valid_0's auc: 0.757191	valid_0's focal_loss_metric: 0.150378
# [71]	valid_0's auc: 0.758657	valid_0's focal_loss_metric: 0.150299
# [72]	valid_0's auc: 0.758993	valid_0's focal_loss_metric: 0.150208
# [73]	valid_0's auc: 0.758605	valid_0's focal_loss_metric: 0.150155
# [74]	valid_0's auc: 0.760099	valid_0's focal_loss_metric: 0.149991
# [75]	valid_0's auc: 0.759539	valid_0's focal_loss_metric: 0.149936
# [76]	valid_0's auc: 0.761011	valid_0's focal_loss_metric: 0.149787
# [77]	valid_0's auc: 0.761326	valid_0's focal_loss_metric: 0.149637
# [78]	valid_0's auc: 0.762703	valid_0's focal_loss_metric: 0.149505
# [79]	valid_0's auc: 0.762062	valid_0's focal_loss_metric: 0.149444
# [80]	valid_0's auc: 0.763411	valid_0's focal_loss_metric: 0.149316
# [81]	valid_0's auc: 0.76273	valid_0's focal_loss_metric: 0.14926
# [82]	valid_0's auc: 0.762976	valid_0's focal_loss_metric: 0.149224
# [83]	valid_0's auc: 0.763185	valid_0's focal_loss_metric: 0.149192
# [84]	valid_0's auc: 0.761702	valid_0's focal_loss_metric: 0.149272
# [85]	valid_0's auc: 0.762599	valid_0's focal_loss_metric: 0.149215
# [86]	valid_0's auc: 0.763303	valid_0's focal_loss_metric: 0.149072
# [87]	valid_0's auc: 0.763914	valid_0's focal_loss_metric: 0.148972
# [88]	valid_0's auc: 0.765174	valid_0's focal_loss_metric: 0.14884
# [89]	valid_0's auc: 0.76473	valid_0's focal_loss_metric: 0.148794
# [90]	valid_0's auc: 0.765843	valid_0's focal_loss_metric: 0.14867
# [91]	valid_0's auc: 0.766403	valid_0's focal_loss_metric: 0.148542
# [92]	valid_0's auc: 0.766803	valid_0's focal_loss_metric: 0.148424
# [93]	valid_0's auc: 0.766636	valid_0's focal_loss_metric: 0.148379
# [94]	valid_0's auc: 0.767084	valid_0's focal_loss_metric: 0.148284
# [95]	valid_0's auc: 0.766697	valid_0's focal_loss_metric: 0.14828
# [96]	valid_0's auc: 0.767933	valid_0's focal_loss_metric: 0.14813
# [97]	valid_0's auc: 0.767805	valid_0's focal_loss_metric: 0.148088
# [98]	valid_0's auc: 0.767158	valid_0's focal_loss_metric: 0.148105
# [99]	valid_0's auc: 0.767964	valid_0's focal_loss_metric: 0.148017
# [100]	valid_0's auc: 0.768298	valid_0's focal_loss_metric: 0.147866
# [101]	valid_0's auc: 0.768925	valid_0's focal_loss_metric: 0.14782
# [102]	valid_0's auc: 0.769263	valid_0's focal_loss_metric: 0.147661
# [103]	valid_0's auc: 0.768801	valid_0's focal_loss_metric: 0.147644
# [104]	valid_0's auc: 0.769005	valid_0's focal_loss_metric: 0.14761
# [105]	valid_0's auc: 0.768793	valid_0's focal_loss_metric: 0.147624
# [106]	valid_0's auc: 0.769395	valid_0's focal_loss_metric: 0.147587
# [107]	valid_0's auc: 0.769412	valid_0's focal_loss_metric: 0.147445
# [108]	valid_0's auc: 0.769086	valid_0's focal_loss_metric: 0.147415
# [109]	valid_0's auc: 0.770053	valid_0's focal_loss_metric: 0.14728
# [110]	valid_0's auc: 0.769621	valid_0's focal_loss_metric: 0.147248
# [111]	valid_0's auc: 0.770616	valid_0's focal_loss_metric: 0.147126
# [112]	valid_0's auc: 0.770334	valid_0's focal_loss_metric: 0.147093
# [113]	valid_0's auc: 0.771112	valid_0's focal_loss_metric: 0.14698
# [114]	valid_0's auc: 0.771773	valid_0's focal_loss_metric: 0.14687
# [115]	valid_0's auc: 0.77223	valid_0's focal_loss_metric: 0.146761
# [116]	valid_0's auc: 0.772074	valid_0's focal_loss_metric: 0.14672
# [117]	valid_0's auc: 0.772559	valid_0's focal_loss_metric: 0.146643
# [118]	valid_0's auc: 0.773322	valid_0's focal_loss_metric: 0.146543
# [119]	valid_0's auc: 0.772896	valid_0's focal_loss_metric: 0.146505
# [120]	valid_0's auc: 0.773746	valid_0's focal_loss_metric: 0.146407
# [121]	valid_0's auc: 0.773286	valid_0's focal_loss_metric: 0.146373
# [122]	valid_0's auc: 0.772906	valid_0's focal_loss_metric: 0.146393
# [123]	valid_0's auc: 0.773552	valid_0's focal_loss_metric: 0.14631
# [124]	valid_0's auc: 0.773934	valid_0's focal_loss_metric: 0.146225
# [125]	valid_0's auc: 0.774865	valid_0's focal_loss_metric: 0.146131
# [126]	valid_0's auc: 0.775052	valid_0's focal_loss_metric: 0.146089
# [127]	valid_0's auc: 0.774935	valid_0's focal_loss_metric: 0.146024
# [128]	valid_0's auc: 0.775721	valid_0's focal_loss_metric: 0.145995
# [129]	valid_0's auc: 0.775838	valid_0's focal_loss_metric: 0.145902
# [130]	valid_0's auc: 0.776209	valid_0's focal_loss_metric: 0.145797
# [131]	valid_0's auc: 0.776515	valid_0's focal_loss_metric: 0.14571
# [132]	valid_0's auc: 0.776621	valid_0's focal_loss_metric: 0.145651
# [133]	valid_0's auc: 0.777544	valid_0's focal_loss_metric: 0.145543
# [134]	valid_0's auc: 0.777625	valid_0's focal_loss_metric: 0.145485
# [135]	valid_0's auc: 0.778489	valid_0's focal_loss_metric: 0.145387
# [136]	valid_0's auc: 0.77802	valid_0's focal_loss_metric: 0.145359
# [137]	valid_0's auc: 0.778885	valid_0's focal_loss_metric: 0.145267
# [138]	valid_0's auc: 0.778408	valid_0's focal_loss_metric: 0.145241
# [139]	valid_0's auc: 0.778834	valid_0's focal_loss_metric: 0.145153
# [140]	valid_0's auc: 0.779208	valid_0's focal_loss_metric: 0.145078
# [141]	valid_0's auc: 0.78005	valid_0's focal_loss_metric: 0.144986
# [142]	valid_0's auc: 0.780195	valid_0's focal_loss_metric: 0.144896
# [143]	valid_0's auc: 0.780621	valid_0's focal_loss_metric: 0.144814
# [144]	valid_0's auc: 0.781388	valid_0's focal_loss_metric: 0.144675
# [145]	valid_0's auc: 0.781992	valid_0's focal_loss_metric: 0.144596
# [146]	valid_0's auc: 0.781661	valid_0's focal_loss_metric: 0.144567
# [147]	valid_0's auc: 0.78221	valid_0's focal_loss_metric: 0.144488
# [148]	valid_0's auc: 0.781942	valid_0's focal_loss_metric: 0.144463
# [149]	valid_0's auc: 0.781884	valid_0's focal_loss_metric: 0.144455
# [150]	valid_0's auc: 0.78233	valid_0's focal_loss_metric: 0.144399
# [151]	valid_0's auc: 0.782728	valid_0's focal_loss_metric: 0.144323
# [152]	valid_0's auc: 0.782926	valid_0's focal_loss_metric: 0.144261
# [153]	valid_0's auc: 0.783336	valid_0's focal_loss_metric: 0.144177
# [154]	valid_0's auc: 0.783553	valid_0's focal_loss_metric: 0.144123
# [155]	valid_0's auc: 0.784133	valid_0's focal_loss_metric: 0.144046
# [156]	valid_0's auc: 0.78476	valid_0's focal_loss_metric: 0.143924
# [157]	valid_0's auc: 0.785273	valid_0's focal_loss_metric: 0.143907
# [158]	valid_0's auc: 0.78556	valid_0's focal_loss_metric: 0.143782
# [159]	valid_0's auc: 0.785989	valid_0's focal_loss_metric: 0.143705
# [160]	valid_0's auc: 0.786207	valid_0's focal_loss_metric: 0.143647
# [161]	valid_0's auc: 0.786413	valid_0's focal_loss_metric: 0.143623
# [162]	valid_0's auc: 0.786101	valid_0's focal_loss_metric: 0.143628
# [163]	valid_0's auc: 0.787125	valid_0's focal_loss_metric: 0.14352
# [164]	valid_0's auc: 0.7871	valid_0's focal_loss_metric: 0.143411
# [165]	valid_0's auc: 0.786729	valid_0's focal_loss_metric: 0.143391
# [166]	valid_0's auc: 0.787368	valid_0's focal_loss_metric: 0.143313
# [167]	valid_0's auc: 0.78785	valid_0's focal_loss_metric: 0.143249
# [168]	valid_0's auc: 0.787819	valid_0's focal_loss_metric: 0.143189
# [169]	valid_0's auc: 0.787323	valid_0's focal_loss_metric: 0.14317
# [170]	valid_0's auc: 0.7871	valid_0's focal_loss_metric: 0.143153
# [171]	valid_0's auc: 0.787652	valid_0's focal_loss_metric: 0.143081
# [172]	valid_0's auc: 0.78763	valid_0's focal_loss_metric: 0.143031
# [173]	valid_0's auc: 0.788237	valid_0's focal_loss_metric: 0.142958
# [174]	valid_0's auc: 0.788106	valid_0's focal_loss_metric: 0.142939
# [175]	valid_0's auc: 0.788689	valid_0's focal_loss_metric: 0.142869
# [176]	valid_0's auc: 0.788293	valid_0's focal_loss_metric: 0.142851
# [177]	valid_0's auc: 0.788895	valid_0's focal_loss_metric: 0.142782
# [178]	valid_0's auc: 0.788817	valid_0's focal_loss_metric: 0.142742
# [179]	valid_0's auc: 0.788692	valid_0's focal_loss_metric: 0.142783
# [180]	valid_0's auc: 0.788722	valid_0's focal_loss_metric: 0.142746
# [181]	valid_0's auc: 0.788982	valid_0's focal_loss_metric: 0.142721
# [182]	valid_0's auc: 0.789238	valid_0's focal_loss_metric: 0.142652
# [183]	valid_0's auc: 0.789907	valid_0's focal_loss_metric: 0.142638
# [184]	valid_0's auc: 0.789606	valid_0's focal_loss_metric: 0.142549
# [185]	valid_0's auc: 0.789567	valid_0's focal_loss_metric: 0.14254
# [186]	valid_0's auc: 0.789992	valid_0's focal_loss_metric: 0.142548
# [187]	valid_0's auc: 0.79019	valid_0's focal_loss_metric: 0.142484
# [188]	valid_0's auc: 0.790552	valid_0's focal_loss_metric: 0.142449
# [189]	valid_0's auc: 0.790399	valid_0's focal_loss_metric: 0.142483
# [190]	valid_0's auc: 0.790485	valid_0's focal_loss_metric: 0.142459
# [191]	valid_0's auc: 0.790288	valid_0's focal_loss_metric: 0.142439
# [192]	valid_0's auc: 0.790681	valid_0's focal_loss_metric: 0.142342
# [193]	valid_0's auc: 0.791274	valid_0's focal_loss_metric: 0.142264
# [194]	valid_0's auc: 0.791297	valid_0's focal_loss_metric: 0.142233
# [195]	valid_0's auc: 0.791821	valid_0's focal_loss_metric: 0.14216
# [196]	valid_0's auc: 0.791556	valid_0's focal_loss_metric: 0.142147
# [197]	valid_0's auc: 0.792018	valid_0's focal_loss_metric: 0.142076
# [198]	valid_0's auc: 0.79174	valid_0's focal_loss_metric: 0.142064
# [199]	valid_0's auc: 0.792191	valid_0's focal_loss_metric: 0.141997
# [200]	valid_0's auc: 0.791907	valid_0's focal_loss_metric: 0.141986
# [201]	valid_0's auc: 0.792342	valid_0's focal_loss_metric: 0.141921
# [202]	valid_0's auc: 0.792317	valid_0's focal_loss_metric: 0.141889
# [203]	valid_0's auc: 0.792161	valid_0's focal_loss_metric: 0.141877
# [204]	valid_0's auc: 0.792322	valid_0's focal_loss_metric: 0.141832
# [205]	valid_0's auc: 0.792777	valid_0's focal_loss_metric: 0.141771
# [206]	valid_0's auc: 0.792481	valid_0's focal_loss_metric: 0.141759
# [207]	valid_0's auc: 0.792857	valid_0's focal_loss_metric: 0.141699
# [208]	valid_0's auc: 0.792765	valid_0's focal_loss_metric: 0.141687
# [209]	valid_0's auc: 0.793351	valid_0's focal_loss_metric: 0.141638
# [210]	valid_0's auc: 0.793418	valid_0's focal_loss_metric: 0.141593
# [211]	valid_0's auc: 0.793702	valid_0's focal_loss_metric: 0.141529
# [212]	valid_0's auc: 0.794173	valid_0's focal_loss_metric: 0.14143
# [213]	valid_0's auc: 0.794076	valid_0's focal_loss_metric: 0.141429
# [214]	valid_0's auc: 0.79382	valid_0's focal_loss_metric: 0.14137
# [215]	valid_0's auc: 0.794239	valid_0's focal_loss_metric: 0.141358
# [216]	valid_0's auc: 0.794317	valid_0's focal_loss_metric: 0.141302
# [217]	valid_0's auc: 0.79437	valid_0's focal_loss_metric: 0.141267
# [218]	valid_0's auc: 0.794116	valid_0's focal_loss_metric: 0.141279
# [219]	valid_0's auc: 0.794492	valid_0's focal_loss_metric: 0.141274
# [220]	valid_0's auc: 0.794712	valid_0's focal_loss_metric: 0.141186
# [221]	valid_0's auc: 0.794966	valid_0's focal_loss_metric: 0.141194
# [222]	valid_0's auc: 0.794843	valid_0's focal_loss_metric: 0.141162
# [223]	valid_0's auc: 0.79498	valid_0's focal_loss_metric: 0.141165
# [224]	valid_0's auc: 0.794986	valid_0's focal_loss_metric: 0.14117
# [225]	valid_0's auc: 0.794765	valid_0's focal_loss_metric: 0.141175
# [226]	valid_0's auc: 0.795563	valid_0's focal_loss_metric: 0.141092
# [227]	valid_0's auc: 0.795498	valid_0's focal_loss_metric: 0.14104
# [228]	valid_0's auc: 0.79578	valid_0's focal_loss_metric: 0.141046
# [229]	valid_0's auc: 0.796017	valid_0's focal_loss_metric: 0.140992
# [230]	valid_0's auc: 0.796368	valid_0's focal_loss_metric: 0.140928
# [231]	valid_0's auc: 0.796198	valid_0's focal_loss_metric: 0.140921
# [232]	valid_0's auc: 0.796482	valid_0's focal_loss_metric: 0.140859
# [233]	valid_0's auc: 0.796304	valid_0's focal_loss_metric: 0.140853
# [234]	valid_0's auc: 0.796611	valid_0's focal_loss_metric: 0.140793
# [235]	valid_0's auc: 0.79675	valid_0's focal_loss_metric: 0.140761
# [236]	valid_0's auc: 0.797006	valid_0's focal_loss_metric: 0.140704
# [237]	valid_0's auc: 0.797441	valid_0's focal_loss_metric: 0.14061
# [238]	valid_0's auc: 0.797149	valid_0's focal_loss_metric: 0.140635
# [239]	valid_0's auc: 0.797241	valid_0's focal_loss_metric: 0.140599
# [240]	valid_0's auc: 0.797806	valid_0's focal_loss_metric: 0.140502
# [241]	valid_0's auc: 0.797739	valid_0's focal_loss_metric: 0.140507
# [242]	valid_0's auc: 0.796848	valid_0's focal_loss_metric: 0.140579
# [243]	valid_0's auc: 0.796926	valid_0's focal_loss_metric: 0.140545
# [244]	valid_0's auc: 0.797241	valid_0's focal_loss_metric: 0.140479
# [245]	valid_0's auc: 0.79704	valid_0's focal_loss_metric: 0.14052
# [246]	valid_0's auc: 0.797048	valid_0's focal_loss_metric: 0.140488
# [247]	valid_0's auc: 0.797739	valid_0's focal_loss_metric: 0.140433
# [248]	valid_0's auc: 0.797831	valid_0's focal_loss_metric: 0.140387
# [249]	valid_0's auc: 0.797837	valid_0's focal_loss_metric: 0.140335
# [250]	valid_0's auc: 0.798344	valid_0's focal_loss_metric: 0.140286
# [251]	valid_0's auc: 0.79857	valid_0's focal_loss_metric: 0.140241
# [252]	valid_0's auc: 0.798567	valid_0's focal_loss_metric: 0.140237
# [253]	valid_0's auc: 0.799075	valid_0's focal_loss_metric: 0.140149
# [254]	valid_0's auc: 0.799353	valid_0's focal_loss_metric: 0.140087
# [255]	valid_0's auc: 0.799713	valid_0's focal_loss_metric: 0.140006
# [256]	valid_0's auc: 0.799682	valid_0's focal_loss_metric: 0.140001
# [257]	valid_0's auc: 0.799298	valid_0's focal_loss_metric: 0.139997
# [258]	valid_0's auc: 0.799844	valid_0's focal_loss_metric: 0.139937
# [259]	valid_0's auc: 0.79981	valid_0's focal_loss_metric: 0.139884
# [260]	valid_0's auc: 0.800287	valid_0's focal_loss_metric: 0.139829
# [261]	valid_0's auc: 0.799925	valid_0's focal_loss_metric: 0.139823
# [262]	valid_0's auc: 0.800376	valid_0's focal_loss_metric: 0.13977
# [263]	valid_0's auc: 0.800014	valid_0's focal_loss_metric: 0.139764
# [264]	valid_0's auc: 0.800248	valid_0's focal_loss_metric: 0.139714
# [265]	valid_0's auc: 0.800279	valid_0's focal_loss_metric: 0.139677
# [266]	valid_0's auc: 0.800733	valid_0's focal_loss_metric: 0.139623
# [267]	valid_0's auc: 0.800892	valid_0's focal_loss_metric: 0.139587
# [268]	valid_0's auc: 0.801182	valid_0's focal_loss_metric: 0.139514
# [269]	valid_0's auc: 0.801533	valid_0's focal_loss_metric: 0.139459
# [270]	valid_0's auc: 0.801282	valid_0's focal_loss_metric: 0.139451
# [271]	valid_0's auc: 0.801265	valid_0's focal_loss_metric: 0.139376
# [272]	valid_0's auc: 0.801566	valid_0's focal_loss_metric: 0.139301
# [273]	valid_0's auc: 0.801394	valid_0's focal_loss_metric: 0.139293
# [274]	valid_0's auc: 0.8016	valid_0's focal_loss_metric: 0.139295
# [275]	valid_0's auc: 0.801778	valid_0's focal_loss_metric: 0.139213
# [276]	valid_0's auc: 0.801803	valid_0's focal_loss_metric: 0.139185
# [277]	valid_0's auc: 0.80228	valid_0's focal_loss_metric: 0.139105
# [278]	valid_0's auc: 0.801918	valid_0's focal_loss_metric: 0.139144
# [279]	valid_0's auc: 0.801915	valid_0's focal_loss_metric: 0.139142
# [280]	valid_0's auc: 0.801759	valid_0's focal_loss_metric: 0.139147
# [281]	valid_0's auc: 0.801672	valid_0's focal_loss_metric: 0.139121
# [282]	valid_0's auc: 0.801959	valid_0's focal_loss_metric: 0.139068
# [283]	valid_0's auc: 0.802247	valid_0's focal_loss_metric: 0.138996
# [284]	valid_0's auc: 0.802138	valid_0's focal_loss_metric: 0.139
# [285]	valid_0's auc: 0.80255	valid_0's focal_loss_metric: 0.138961
# [286]	valid_0's auc: 0.8025	valid_0's focal_loss_metric: 0.138939
# [287]	valid_0's auc: 0.802757	valid_0's focal_loss_metric: 0.138887
# [288]	valid_0's auc: 0.802562	valid_0's focal_loss_metric: 0.138883
# [289]	valid_0's auc: 0.802832	valid_0's focal_loss_metric: 0.138833
# [290]	valid_0's auc: 0.802656	valid_0's focal_loss_metric: 0.13883
# [291]	valid_0's auc: 0.802927	valid_0's focal_loss_metric: 0.138781
# [292]	valid_0's auc: 0.802824	valid_0's focal_loss_metric: 0.138761
# [293]	valid_0's auc: 0.803164	valid_0's focal_loss_metric: 0.138714
# [294]	valid_0's auc: 0.802882	valid_0's focal_loss_metric: 0.138711
# [295]	valid_0's auc: 0.803183	valid_0's focal_loss_metric: 0.138665
# [296]	valid_0's auc: 0.802943	valid_0's focal_loss_metric: 0.138662
# [297]	valid_0's auc: 0.803242	valid_0's focal_loss_metric: 0.138626
# [298]	valid_0's auc: 0.803264	valid_0's focal_loss_metric: 0.138596
# [299]	valid_0's auc: 0.803423	valid_0's focal_loss_metric: 0.13855
# [300]	valid_0's auc: 0.803674	valid_0's focal_loss_metric: 0.13848
# [301]	valid_0's auc: 0.803624	valid_0's focal_loss_metric: 0.138488
# [302]	valid_0's auc: 0.803755	valid_0's focal_loss_metric: 0.138444
# [303]	valid_0's auc: 0.804129	valid_0's focal_loss_metric: 0.138427
# [304]	valid_0's auc: 0.804082	valid_0's focal_loss_metric: 0.138373
# [305]	valid_0's auc: 0.804319	valid_0's focal_loss_metric: 0.138377
# [306]	valid_0's auc: 0.804294	valid_0's focal_loss_metric: 0.138361
# [307]	valid_0's auc: 0.804251	valid_0's focal_loss_metric: 0.13832
# [308]	valid_0's auc: 0.804081	valid_0's focal_loss_metric: 0.13832
# [309]	valid_0's auc: 0.803922	valid_0's focal_loss_metric: 0.138299
# [310]	valid_0's auc: 0.804181	valid_0's focal_loss_metric: 0.138309
# [311]	valid_0's auc: 0.804276	valid_0's focal_loss_metric: 0.138222
# [312]	valid_0's auc: 0.804502	valid_0's focal_loss_metric: 0.138231
# [313]	valid_0's auc: 0.804549	valid_0's focal_loss_metric: 0.13815
# [314]	valid_0's auc: 0.804789	valid_0's focal_loss_metric: 0.138159
# [315]	valid_0's auc: 0.804803	valid_0's focal_loss_metric: 0.138082
# [316]	valid_0's auc: 0.805251	valid_0's focal_loss_metric: 0.138065
# [317]	valid_0's auc: 0.805349	valid_0's focal_loss_metric: 0.138021
# [318]	valid_0's auc: 0.805288	valid_0's focal_loss_metric: 0.137979
# [319]	valid_0's auc: 0.805519	valid_0's focal_loss_metric: 0.137994
# [320]	valid_0's auc: 0.805759	valid_0's focal_loss_metric: 0.137954
# [321]	valid_0's auc: 0.805759	valid_0's focal_loss_metric: 0.137925
# [322]	valid_0's auc: 0.805948	valid_0's focal_loss_metric: 0.137878
# [323]	valid_0's auc: 0.80604	valid_0's focal_loss_metric: 0.137876
# [324]	valid_0's auc: 0.806288	valid_0's focal_loss_metric: 0.137828
# [325]	valid_0's auc: 0.806692	valid_0's focal_loss_metric: 0.13775
# [326]	valid_0's auc: 0.806575	valid_0's focal_loss_metric: 0.137749
# [327]	valid_0's auc: 0.806723	valid_0's focal_loss_metric: 0.13775
# [328]	valid_0's auc: 0.806885	valid_0's focal_loss_metric: 0.137698
# [329]	valid_0's auc: 0.807311	valid_0's focal_loss_metric: 0.137625
# [330]	valid_0's auc: 0.807152	valid_0's focal_loss_metric: 0.137625
# [331]	valid_0's auc: 0.807478	valid_0's focal_loss_metric: 0.137558
# [332]	valid_0's auc: 0.807587	valid_0's focal_loss_metric: 0.137507
# [333]	valid_0's auc: 0.807782	valid_0's focal_loss_metric: 0.137509
# [334]	valid_0's auc: 0.807584	valid_0's focal_loss_metric: 0.137484
# [335]	valid_0's auc: 0.807735	valid_0's focal_loss_metric: 0.137456
# [336]	valid_0's auc: 0.808147	valid_0's focal_loss_metric: 0.137394
# [337]	valid_0's auc: 0.808114	valid_0's focal_loss_metric: 0.137395
# [338]	valid_0's auc: 0.808303	valid_0's focal_loss_metric: 0.137335
# [339]	valid_0's auc: 0.808131	valid_0's focal_loss_metric: 0.137361
# [340]	valid_0's auc: 0.808131	valid_0's focal_loss_metric: 0.137323
# [341]	valid_0's auc: 0.808593	valid_0's focal_loss_metric: 0.13728
# [342]	valid_0's auc: 0.808409	valid_0's focal_loss_metric: 0.137268
# [343]	valid_0's auc: 0.808822	valid_0's focal_loss_metric: 0.137217
# [344]	valid_0's auc: 0.808596	valid_0's focal_loss_metric: 0.137215
# [345]	valid_0's auc: 0.808978	valid_0's focal_loss_metric: 0.137176
# [346]	valid_0's auc: 0.808766	valid_0's focal_loss_metric: 0.137164
# [347]	valid_0's auc: 0.809207	valid_0's focal_loss_metric: 0.137116
# [348]	valid_0's auc: 0.808833	valid_0's focal_loss_metric: 0.137116
# [349]	valid_0's auc: 0.809254	valid_0's focal_loss_metric: 0.13707
# [350]	valid_0's auc: 0.809176	valid_0's focal_loss_metric: 0.137048
# [351]	valid_0's auc: 0.809488	valid_0's focal_loss_metric: 0.137012
# [352]	valid_0's auc: 0.809519	valid_0's focal_loss_metric: 0.137007
# [353]	valid_0's auc: 0.809485	valid_0's focal_loss_metric: 0.136994
# [354]	valid_0's auc: 0.809753	valid_0's focal_loss_metric: 0.13695
# [355]	valid_0's auc: 0.809516	valid_0's focal_loss_metric: 0.13695
# [356]	valid_0's auc: 0.809789	valid_0's focal_loss_metric: 0.136907
# [357]	valid_0's auc: 0.809549	valid_0's focal_loss_metric: 0.136907
# [358]	valid_0's auc: 0.809722	valid_0's focal_loss_metric: 0.136871
# [359]	valid_0's auc: 0.809469	valid_0's focal_loss_metric: 0.136922
# [360]	valid_0's auc: 0.809273	valid_0's focal_loss_metric: 0.13691
# [361]	valid_0's auc: 0.8098	valid_0's focal_loss_metric: 0.136894
# [362]	valid_0's auc: 0.809761	valid_0's focal_loss_metric: 0.136831
# [363]	valid_0's auc: 0.809786	valid_0's focal_loss_metric: 0.13684
# [364]	valid_0's auc: 0.810051	valid_0's focal_loss_metric: 0.136774
# [365]	valid_0's auc: 0.810327	valid_0's focal_loss_metric: 0.13678
# [366]	valid_0's auc: 0.810043	valid_0's focal_loss_metric: 0.136748
# [367]	valid_0's auc: 0.810149	valid_0's focal_loss_metric: 0.136712
# [368]	valid_0's auc: 0.810174	valid_0's focal_loss_metric: 0.136686
# [369]	valid_0's auc: 0.810447	valid_0's focal_loss_metric: 0.136651
# [370]	valid_0's auc: 0.810391	valid_0's focal_loss_metric: 0.136639
# [371]	valid_0's auc: 0.810726	valid_0's focal_loss_metric: 0.136597
# [372]	valid_0's auc: 0.810439	valid_0's focal_loss_metric: 0.136598
# [373]	valid_0's auc: 0.810767	valid_0's focal_loss_metric: 0.136556
# [374]	valid_0's auc: 0.810726	valid_0's focal_loss_metric: 0.136536
# [375]	valid_0's auc: 0.810979	valid_0's focal_loss_metric: 0.136503
# [376]	valid_0's auc: 0.810904	valid_0's focal_loss_metric: 0.136491
# [377]	valid_0's auc: 0.811141	valid_0's focal_loss_metric: 0.136459
# [378]	valid_0's auc: 0.811227	valid_0's focal_loss_metric: 0.13647
# [379]	valid_0's auc: 0.811375	valid_0's focal_loss_metric: 0.136427
# [380]	valid_0's auc: 0.811556	valid_0's focal_loss_metric: 0.13637
# [381]	valid_0's auc: 0.811559	valid_0's focal_loss_metric: 0.136343
# [382]	valid_0's auc: 0.811816	valid_0's focal_loss_metric: 0.13633
# [383]	valid_0's auc: 0.811643	valid_0's focal_loss_metric: 0.136324
# [384]	valid_0's auc: 0.811746	valid_0's focal_loss_metric: 0.136335
# [385]	valid_0's auc: 0.811841	valid_0's focal_loss_metric: 0.136257
# [386]	valid_0's auc: 0.812234	valid_0's focal_loss_metric: 0.136243
# [387]	valid_0's auc: 0.812328	valid_0's focal_loss_metric: 0.136175
# [388]	valid_0's auc: 0.812457	valid_0's focal_loss_metric: 0.136185
# [389]	valid_0's auc: 0.812579	valid_0's focal_loss_metric: 0.136118
# [390]	valid_0's auc: 0.812696	valid_0's focal_loss_metric: 0.136129
# [391]	valid_0's auc: 0.812786	valid_0's focal_loss_metric: 0.136063
# [392]	valid_0's auc: 0.812947	valid_0's focal_loss_metric: 0.136075
# [393]	valid_0's auc: 0.813025	valid_0's focal_loss_metric: 0.13601
# [394]	valid_0's auc: 0.81317	valid_0's focal_loss_metric: 0.136022
# [395]	valid_0's auc: 0.81341	valid_0's focal_loss_metric: 0.135973
# [396]	valid_0's auc: 0.813165	valid_0's focal_loss_metric: 0.136011
# [397]	valid_0's auc: 0.813318	valid_0's focal_loss_metric: 0.135979
# [398]	valid_0's auc: 0.813265	valid_0's focal_loss_metric: 0.135991
# [399]	valid_0's auc: 0.813468	valid_0's focal_loss_metric: 0.135936
# [400]	valid_0's auc: 0.813616	valid_0's focal_loss_metric: 0.135897
# [401]	valid_0's auc: 0.813638	valid_0's focal_loss_metric: 0.135874
# [402]	valid_0's auc: 0.813803	valid_0's focal_loss_metric: 0.135838
# [403]	valid_0's auc: 0.813756	valid_0's focal_loss_metric: 0.135818
# [404]	valid_0's auc: 0.813664	valid_0's focal_loss_metric: 0.135833
# [405]	valid_0's auc: 0.813577	valid_0's focal_loss_metric: 0.135838
# [406]	valid_0's auc: 0.813736	valid_0's focal_loss_metric: 0.135792
# [407]	valid_0's auc: 0.813577	valid_0's focal_loss_metric: 0.135774
# [408]	valid_0's auc: 0.8138	valid_0's focal_loss_metric: 0.135775
# [409]	valid_0's auc: 0.813864	valid_0's focal_loss_metric: 0.135728
# [410]	valid_0's auc: 0.814093	valid_0's focal_loss_metric: 0.135731
# [411]	valid_0's auc: 0.814146	valid_0's focal_loss_metric: 0.135685
# [412]	valid_0's auc: 0.814383	valid_0's focal_loss_metric: 0.135688
# [413]	valid_0's auc: 0.814447	valid_0's focal_loss_metric: 0.135644
# [414]	valid_0's auc: 0.814854	valid_0's focal_loss_metric: 0.135579
# [415]	valid_0's auc: 0.814567	valid_0's focal_loss_metric: 0.135581
# [416]	valid_0's auc: 0.814918	valid_0's focal_loss_metric: 0.135521
# [417]	valid_0's auc: 0.814901	valid_0's focal_loss_metric: 0.135524
# [418]	valid_0's auc: 0.814918	valid_0's focal_loss_metric: 0.135537
# [419]	valid_0's auc: 0.814745	valid_0's focal_loss_metric: 0.13554
# [420]	valid_0's auc: 0.814475	valid_0's focal_loss_metric: 0.135577
# [421]	valid_0's auc: 0.814926	valid_0's focal_loss_metric: 0.135517
# [422]	valid_0's auc: 0.814767	valid_0's focal_loss_metric: 0.13552
# [423]	valid_0's auc: 0.815155	valid_0's focal_loss_metric: 0.135459
# [424]	valid_0's auc: 0.815043	valid_0's focal_loss_metric: 0.135462
# [425]	valid_0's auc: 0.815484	valid_0's focal_loss_metric: 0.135402
# [426]	valid_0's auc: 0.815213	valid_0's focal_loss_metric: 0.135426
# [427]	valid_0's auc: 0.815542	valid_0's focal_loss_metric: 0.135369
# [428]	valid_0's auc: 0.815503	valid_0's focal_loss_metric: 0.135366
# [429]	valid_0's auc: 0.815489	valid_0's focal_loss_metric: 0.135355
# [430]	valid_0's auc: 0.815659	valid_0's focal_loss_metric: 0.135311
# [431]	valid_0's auc: 0.815556	valid_0's focal_loss_metric: 0.135313
# [432]	valid_0's auc: 0.815698	valid_0's focal_loss_metric: 0.135272
# [433]	valid_0's auc: 0.815598	valid_0's focal_loss_metric: 0.135274
# [434]	valid_0's auc: 0.815748	valid_0's focal_loss_metric: 0.135234
# [435]	valid_0's auc: 0.815687	valid_0's focal_loss_metric: 0.135222
# [436]	valid_0's auc: 0.815871	valid_0's focal_loss_metric: 0.135192
# [437]	valid_0's auc: 0.815849	valid_0's focal_loss_metric: 0.135181
# [438]	valid_0's auc: 0.816063	valid_0's focal_loss_metric: 0.135142
# [439]	valid_0's auc: 0.815893	valid_0's focal_loss_metric: 0.135144
# [440]	valid_0's auc: 0.816019	valid_0's focal_loss_metric: 0.135112
# [441]	valid_0's auc: 0.816005	valid_0's focal_loss_metric: 0.135095
# [442]	valid_0's auc: 0.816072	valid_0's focal_loss_metric: 0.135099
# [443]	valid_0's auc: 0.816236	valid_0's focal_loss_metric: 0.135053
# [444]	valid_0's auc: 0.816362	valid_0's focal_loss_metric: 0.135058
# [445]	valid_0's auc: 0.816579	valid_0's focal_loss_metric: 0.135014
# [446]	valid_0's auc: 0.816836	valid_0's focal_loss_metric: 0.134955
# [447]	valid_0's auc: 0.816643	valid_0's focal_loss_metric: 0.134979
# [448]	valid_0's auc: 0.816682	valid_0's focal_loss_metric: 0.13492
# [449]	valid_0's auc: 0.816794	valid_0's focal_loss_metric: 0.134943
# [450]	valid_0's auc: 0.81676	valid_0's focal_loss_metric: 0.134889
# [451]	valid_0's auc: 0.81717	valid_0's focal_loss_metric: 0.134875
# [452]	valid_0's auc: 0.817217	valid_0's focal_loss_metric: 0.134814
# [453]	valid_0's auc: 0.817421	valid_0's focal_loss_metric: 0.134824
# [454]	valid_0's auc: 0.817424	valid_0's focal_loss_metric: 0.134765
# [455]	valid_0's auc: 0.817588	valid_0's focal_loss_metric: 0.134787
# [456]	valid_0's auc: 0.817847	valid_0's focal_loss_metric: 0.13473
# [457]	valid_0's auc: 0.817794	valid_0's focal_loss_metric: 0.134734
# [458]	valid_0's auc: 0.817906	valid_0's focal_loss_metric: 0.13474
# [459]	valid_0's auc: 0.818081	valid_0's focal_loss_metric: 0.134696
# [460]	valid_0's auc: 0.818318	valid_0's focal_loss_metric: 0.134639
# [461]	valid_0's auc: 0.818695	valid_0's focal_loss_metric: 0.134591
# [462]	valid_0's auc: 0.818784	valid_0's focal_loss_metric: 0.13457
# [463]	valid_0's auc: 0.81877	valid_0's focal_loss_metric: 0.134552
# [464]	valid_0's auc: 0.819071	valid_0's focal_loss_metric: 0.134516
# [465]	valid_0's auc: 0.819046	valid_0's focal_loss_metric: 0.134482
# [466]	valid_0's auc: 0.819235	valid_0's focal_loss_metric: 0.134489
# [467]	valid_0's auc: 0.819054	valid_0's focal_loss_metric: 0.134456
# [468]	valid_0's auc: 0.818982	valid_0's focal_loss_metric: 0.134493
# [469]	valid_0's auc: 0.818937	valid_0's focal_loss_metric: 0.134498
# [470]	valid_0's auc: 0.819355	valid_0's focal_loss_metric: 0.134437
# [471]	valid_0's auc: 0.819548	valid_0's focal_loss_metric: 0.134401
# [472]	valid_0's auc: 0.819408	valid_0's focal_loss_metric: 0.134403
# [473]	valid_0's auc: 0.819581	valid_0's focal_loss_metric: 0.134367
# [474]	valid_0's auc: 0.819428	valid_0's focal_loss_metric: 0.13437
# [475]	valid_0's auc: 0.819612	valid_0's focal_loss_metric: 0.134334
# [476]	valid_0's auc: 0.819592	valid_0's focal_loss_metric: 0.134326
# [477]	valid_0's auc: 0.819746	valid_0's focal_loss_metric: 0.134294
# [478]	valid_0's auc: 0.819782	valid_0's focal_loss_metric: 0.134286
# [479]	valid_0's auc: 0.819916	valid_0's focal_loss_metric: 0.134255
# [480]	valid_0's auc: 0.819963	valid_0's focal_loss_metric: 0.134248
# [481]	valid_0's auc: 0.820108	valid_0's focal_loss_metric: 0.134218
# [482]	valid_0's auc: 0.820261	valid_0's focal_loss_metric: 0.134168
# [483]	valid_0's auc: 0.820289	valid_0's focal_loss_metric: 0.134143
# [484]	valid_0's auc: 0.820278	valid_0's focal_loss_metric: 0.134149
# [485]	valid_0's auc: 0.820501	valid_0's focal_loss_metric: 0.134105
# [486]	valid_0's auc: 0.82049	valid_0's focal_loss_metric: 0.134096
# [487]	valid_0's auc: 0.820568	valid_0's focal_loss_metric: 0.13406
# [488]	valid_0's auc: 0.820515	valid_0's focal_loss_metric: 0.134064
# [489]	valid_0's auc: 0.820579	valid_0's focal_loss_metric: 0.134028
# [490]	valid_0's auc: 0.820543	valid_0's focal_loss_metric: 0.134031
# [491]	valid_0's auc: 0.820498	valid_0's focal_loss_metric: 0.134037
# [492]	valid_0's auc: 0.820702	valid_0's focal_loss_metric: 0.133978
# [493]	valid_0's auc: 0.820604	valid_0's focal_loss_metric: 0.13401
# [494]	valid_0's auc: 0.820718	valid_0's focal_loss_metric: 0.133979
# [495]	valid_0's auc: 0.820571	valid_0's focal_loss_metric: 0.134013
# [496]	valid_0's auc: 0.820799	valid_0's focal_loss_metric: 0.133957
# [497]	valid_0's auc: 0.821033	valid_0's focal_loss_metric: 0.133922
# [498]	valid_0's auc: 0.821075	valid_0's focal_loss_metric: 0.133874
# [499]	valid_0's auc: 0.821273	valid_0's focal_loss_metric: 0.133821
# [500]	valid_0's auc: 0.821582	valid_0's focal_loss_metric: 0.133809
# [501]	valid_0's auc: 0.821658	valid_0's focal_loss_metric: 0.133751
# [502]	valid_0's auc: 0.821803	valid_0's focal_loss_metric: 0.133762
# [503]	valid_0's auc: 0.822034	valid_0's focal_loss_metric: 0.133717
# [504]	valid_0's auc: 0.822028	valid_0's focal_loss_metric: 0.133729
# [505]	valid_0's auc: 0.822073	valid_0's focal_loss_metric: 0.133703
# [506]	valid_0's auc: 0.821945	valid_0's focal_loss_metric: 0.13373
# [507]	valid_0's auc: 0.822006	valid_0's focal_loss_metric: 0.133674
# [508]	valid_0's auc: 0.822112	valid_0's focal_loss_metric: 0.133685
# [509]	valid_0's auc: 0.822162	valid_0's focal_loss_metric: 0.13363
# [510]	valid_0's auc: 0.822288	valid_0's focal_loss_metric: 0.133652
# [511]	valid_0's auc: 0.822179	valid_0's focal_loss_metric: 0.133621
# [512]	valid_0's auc: 0.822009	valid_0's focal_loss_metric: 0.133611
# [513]	valid_0's auc: 0.82197	valid_0's focal_loss_metric: 0.133634
# [514]	valid_0's auc: 0.822151	valid_0's focal_loss_metric: 0.133612
# [515]	valid_0's auc: 0.822285	valid_0's focal_loss_metric: 0.133618
# [516]	valid_0's auc: 0.82202	valid_0's focal_loss_metric: 0.133623
# [517]	valid_0's auc: 0.822502	valid_0's focal_loss_metric: 0.133566
# [518]	valid_0's auc: 0.822586	valid_0's focal_loss_metric: 0.133526
# [519]	valid_0's auc: 0.822865	valid_0's focal_loss_metric: 0.133473
# [520]	valid_0's auc: 0.822653	valid_0's focal_loss_metric: 0.133479
# [521]	valid_0's auc: 0.823118	valid_0's focal_loss_metric: 0.133426
# [522]	valid_0's auc: 0.822778	valid_0's focal_loss_metric: 0.133451
# [523]	valid_0's auc: 0.822973	valid_0's focal_loss_metric: 0.133412
# [524]	valid_0's auc: 0.822734	valid_0's focal_loss_metric: 0.133448
# [525]	valid_0's auc: 0.822859	valid_0's focal_loss_metric: 0.133454
# [526]	valid_0's auc: 0.822906	valid_0's focal_loss_metric: 0.133414
# [527]	valid_0's auc: 0.823266	valid_0's focal_loss_metric: 0.133363
# [528]	valid_0's auc: 0.823079	valid_0's focal_loss_metric: 0.13337
# [529]	valid_0's auc: 0.823573	valid_0's focal_loss_metric: 0.133315
# [530]	valid_0's auc: 0.823678	valid_0's focal_loss_metric: 0.133281
# [531]	valid_0's auc: 0.823589	valid_0's focal_loss_metric: 0.133264
# [532]	valid_0's auc: 0.823731	valid_0's focal_loss_metric: 0.133231
# [533]	valid_0's auc: 0.823653	valid_0's focal_loss_metric: 0.13323
# [534]	valid_0's auc: 0.823904	valid_0's focal_loss_metric: 0.133204
# [535]	valid_0's auc: 0.823837	valid_0's focal_loss_metric: 0.133186
# [536]	valid_0's auc: 0.823472	valid_0's focal_loss_metric: 0.133211
# [537]	valid_0's auc: 0.823837	valid_0's focal_loss_metric: 0.133161
# [538]	valid_0's auc: 0.823486	valid_0's focal_loss_metric: 0.133199
# [539]	valid_0's auc: 0.823628	valid_0's focal_loss_metric: 0.133172
# [540]	valid_0's auc: 0.82355	valid_0's focal_loss_metric: 0.133164
# [541]	valid_0's auc: 0.823706	valid_0's focal_loss_metric: 0.133129
# [542]	valid_0's auc: 0.823578	valid_0's focal_loss_metric: 0.133132
# [543]	valid_0's auc: 0.823737	valid_0's focal_loss_metric: 0.133099
# [544]	valid_0's auc: 0.823826	valid_0's focal_loss_metric: 0.133053
# [545]	valid_0's auc: 0.823854	valid_0's focal_loss_metric: 0.133031
# [546]	valid_0's auc: 0.823709	valid_0's focal_loss_metric: 0.133035
# [547]	valid_0's auc: 0.823915	valid_0's focal_loss_metric: 0.133008
# [548]	valid_0's auc: 0.823823	valid_0's focal_loss_metric: 0.133001
# [549]	valid_0's auc: 0.82401	valid_0's focal_loss_metric: 0.132967
# [550]	valid_0's auc: 0.82386	valid_0's focal_loss_metric: 0.132999
# [551]	valid_0's auc: 0.82396	valid_0's focal_loss_metric: 0.132965
# [552]	valid_0's auc: 0.823904	valid_0's focal_loss_metric: 0.132957
# [553]	valid_0's auc: 0.824108	valid_0's focal_loss_metric: 0.132931
# [554]	valid_0's auc: 0.824016	valid_0's focal_loss_metric: 0.132914
# [555]	valid_0's auc: 0.824052	valid_0's focal_loss_metric: 0.132887
# [556]	valid_0's auc: 0.824228	valid_0's focal_loss_metric: 0.13288
# [557]	valid_0's auc: 0.824091	valid_0's focal_loss_metric: 0.132875
# [558]	valid_0's auc: 0.8242	valid_0's focal_loss_metric: 0.132887
# [559]	valid_0's auc: 0.824331	valid_0's focal_loss_metric: 0.13283
# [560]	valid_0's auc: 0.824414	valid_0's focal_loss_metric: 0.132851
# [561]	valid_0's auc: 0.82447	valid_0's focal_loss_metric: 0.132797
# [562]	valid_0's auc: 0.824579	valid_0's focal_loss_metric: 0.132809
# [563]	valid_0's auc: 0.824607	valid_0's focal_loss_metric: 0.132757
# [564]	valid_0's auc: 0.824768	valid_0's focal_loss_metric: 0.132769
# [565]	valid_0's auc: 0.824821	valid_0's focal_loss_metric: 0.132718
# [566]	valid_0's auc: 0.824888	valid_0's focal_loss_metric: 0.132739
# [567]	valid_0's auc: 0.825167	valid_0's focal_loss_metric: 0.132691
# [568]	valid_0's auc: 0.824927	valid_0's focal_loss_metric: 0.132727
# [569]	valid_0's auc: 0.824752	valid_0's focal_loss_metric: 0.132723
# [570]	valid_0's auc: 0.824537	valid_0's focal_loss_metric: 0.132745
# [571]	valid_0's auc: 0.824752	valid_0's focal_loss_metric: 0.1327
# [572]	valid_0's auc: 0.824874	valid_0's focal_loss_metric: 0.132682
# [573]	valid_0's auc: 0.824746	valid_0's focal_loss_metric: 0.132669
# [574]	valid_0's auc: 0.824899	valid_0's focal_loss_metric: 0.132675
# [575]	valid_0's auc: 0.824927	valid_0's focal_loss_metric: 0.132638
# [576]	valid_0's auc: 0.825092	valid_0's focal_loss_metric: 0.132644
# [577]	valid_0's auc: 0.825097	valid_0's focal_loss_metric: 0.132609
# [578]	valid_0's auc: 0.82534	valid_0's focal_loss_metric: 0.132558
# [579]	valid_0's auc: 0.825211	valid_0's focal_loss_metric: 0.132565
# [580]	valid_0's auc: 0.825588	valid_0's focal_loss_metric: 0.132511
# [581]	valid_0's auc: 0.825786	valid_0's focal_loss_metric: 0.13252
# [582]	valid_0's auc: 0.8258	valid_0's focal_loss_metric: 0.132472
# [583]	valid_0's auc: 0.826031	valid_0's focal_loss_metric: 0.132461
# [584]	valid_0's auc: 0.826011	valid_0's focal_loss_metric: 0.13247
# [585]	valid_0's auc: 0.825853	valid_0's focal_loss_metric: 0.132473
# [586]	valid_0's auc: 0.826028	valid_0's focal_loss_metric: 0.132474
# [587]	valid_0's auc: 0.826045	valid_0's focal_loss_metric: 0.13248
# [588]	valid_0's auc: 0.826315	valid_0's focal_loss_metric: 0.132435
# [589]	valid_0's auc: 0.826251	valid_0's focal_loss_metric: 0.132408
# [590]	valid_0's auc: 0.82629	valid_0's focal_loss_metric: 0.132417
# [591]	valid_0's auc: 0.826443	valid_0's focal_loss_metric: 0.132393
# [592]	valid_0's auc: 0.826558	valid_0's focal_loss_metric: 0.132343
# [593]	valid_0's auc: 0.826535	valid_0's focal_loss_metric: 0.132327
# [594]	valid_0's auc: 0.826703	valid_0's focal_loss_metric: 0.132282
# [595]	valid_0's auc: 0.826672	valid_0's focal_loss_metric: 0.132295
# [596]	valid_0's auc: 0.826733	valid_0's focal_loss_metric: 0.132256
# [597]	valid_0's auc: 0.826756	valid_0's focal_loss_metric: 0.132283
# [598]	valid_0's auc: 0.826789	valid_0's focal_loss_metric: 0.132246
# [599]	valid_0's auc: 0.826814	valid_0's focal_loss_metric: 0.132272
# [600]	valid_0's auc: 0.826675	valid_0's focal_loss_metric: 0.132281
# [601]	valid_0's auc: 0.826588	valid_0's focal_loss_metric: 0.132271
# [602]	valid_0's auc: 0.826469	valid_0's focal_loss_metric: 0.132274
# [603]	valid_0's auc: 0.826449	valid_0's focal_loss_metric: 0.132277
# [604]	valid_0's auc: 0.826605	valid_0's focal_loss_metric: 0.132231
# [605]	valid_0's auc: 0.826806	valid_0's focal_loss_metric: 0.132218
# [606]	valid_0's auc: 0.826745	valid_0's focal_loss_metric: 0.132171
# [607]	valid_0's auc: 0.826616	valid_0's focal_loss_metric: 0.132166
# [608]	valid_0's auc: 0.826873	valid_0's focal_loss_metric: 0.132138
# [609]	valid_0's auc: 0.826764	valid_0's focal_loss_metric: 0.132133
# [610]	valid_0's auc: 0.827004	valid_0's focal_loss_metric: 0.132107
# [611]	valid_0's auc: 0.826867	valid_0's focal_loss_metric: 0.132101
# [612]	valid_0's auc: 0.827093	valid_0's focal_loss_metric: 0.132076
# [613]	valid_0's auc: 0.826976	valid_0's focal_loss_metric: 0.132071
# [614]	valid_0's auc: 0.827179	valid_0's focal_loss_metric: 0.132039
# [615]	valid_0's auc: 0.826973	valid_0's focal_loss_metric: 0.132043
# [616]	valid_0's auc: 0.827204	valid_0's focal_loss_metric: 0.132012
# [617]	valid_0's auc: 0.826987	valid_0's focal_loss_metric: 0.132015
# [618]	valid_0's auc: 0.827171	valid_0's focal_loss_metric: 0.131992
# [619]	valid_0's auc: 0.827068	valid_0's focal_loss_metric: 0.131975
# [620]	valid_0's auc: 0.827288	valid_0's focal_loss_metric: 0.13195
# [621]	valid_0's auc: 0.827154	valid_0's focal_loss_metric: 0.131946
# [622]	valid_0's auc: 0.827377	valid_0's focal_loss_metric: 0.131914
# [623]	valid_0's auc: 0.827246	valid_0's focal_loss_metric: 0.131918
# [624]	valid_0's auc: 0.827433	valid_0's focal_loss_metric: 0.131887
# [625]	valid_0's auc: 0.827274	valid_0's focal_loss_metric: 0.131891
# [626]	valid_0's auc: 0.827447	valid_0's focal_loss_metric: 0.131861
# [627]	valid_0's auc: 0.827355	valid_0's focal_loss_metric: 0.131865
# [628]	valid_0's auc: 0.827522	valid_0's focal_loss_metric: 0.131861
# [629]	valid_0's auc: 0.8274	valid_0's focal_loss_metric: 0.131845
# [630]	valid_0's auc: 0.827592	valid_0's focal_loss_metric: 0.131821
# [631]	valid_0's auc: 0.827503	valid_0's focal_loss_metric: 0.131829
# [632]	valid_0's auc: 0.827664	valid_0's focal_loss_metric: 0.131777
# [633]	valid_0's auc: 0.827595	valid_0's focal_loss_metric: 0.131772
# [634]	valid_0's auc: 0.827765	valid_0's focal_loss_metric: 0.131742
# [635]	valid_0's auc: 0.827659	valid_0's focal_loss_metric: 0.13175
# [636]	valid_0's auc: 0.827929	valid_0's focal_loss_metric: 0.131698
# [637]	valid_0's auc: 0.827921	valid_0's focal_loss_metric: 0.131688
# [638]	valid_0's auc: 0.82799	valid_0's focal_loss_metric: 0.131694
# [639]	valid_0's auc: 0.828057	valid_0's focal_loss_metric: 0.131659
# [640]	valid_0's auc: 0.828149	valid_0's focal_loss_metric: 0.131665
# [641]	valid_0's auc: 0.828275	valid_0's focal_loss_metric: 0.131632
# [642]	valid_0's auc: 0.828375	valid_0's focal_loss_metric: 0.131638
# [643]	valid_0's auc: 0.828442	valid_0's focal_loss_metric: 0.131606
# [644]	valid_0's auc: 0.828751	valid_0's focal_loss_metric: 0.131557
# [645]	valid_0's auc: 0.828442	valid_0's focal_loss_metric: 0.131582
# [646]	valid_0's auc: 0.828685	valid_0's focal_loss_metric: 0.131535
# [647]	valid_0's auc: 0.828737	valid_0's focal_loss_metric: 0.131538
# [648]	valid_0's auc: 0.829008	valid_0's focal_loss_metric: 0.131498
# [649]	valid_0's auc: 0.828908	valid_0's focal_loss_metric: 0.131502
# [650]	valid_0's auc: 0.828782	valid_0's focal_loss_metric: 0.131476
# [651]	valid_0's auc: 0.828729	valid_0's focal_loss_metric: 0.131485
# [652]	valid_0's auc: 0.828938	valid_0's focal_loss_metric: 0.131435
# [653]	valid_0's auc: 0.829011	valid_0's focal_loss_metric: 0.131432
# [654]	valid_0's auc: 0.828969	valid_0's focal_loss_metric: 0.131415
# [655]	valid_0's auc: 0.829172	valid_0's focal_loss_metric: 0.131393
# [656]	valid_0's auc: 0.829058	valid_0's focal_loss_metric: 0.131388
# [657]	valid_0's auc: 0.829189	valid_0's focal_loss_metric: 0.131359
# [658]	valid_0's auc: 0.829161	valid_0's focal_loss_metric: 0.13136
# [659]	valid_0's auc: 0.829317	valid_0's focal_loss_metric: 0.131338
# [660]	valid_0's auc: 0.82949	valid_0's focal_loss_metric: 0.131312
# [661]	valid_0's auc: 0.829596	valid_0's focal_loss_metric: 0.131295
# [662]	valid_0's auc: 0.829476	valid_0's focal_loss_metric: 0.131288
# [663]	valid_0's auc: 0.829563	valid_0's focal_loss_metric: 0.131249
# [664]	valid_0's auc: 0.829735	valid_0's focal_loss_metric: 0.131228
# [665]	valid_0's auc: 0.829604	valid_0's focal_loss_metric: 0.131256
# [666]	valid_0's auc: 0.829844	valid_0's focal_loss_metric: 0.131219
# [667]	valid_0's auc: 0.829655	valid_0's focal_loss_metric: 0.131245
# [668]	valid_0's auc: 0.829822	valid_0's focal_loss_metric: 0.131199
# [669]	valid_0's auc: 0.829799	valid_0's focal_loss_metric: 0.131211
# [670]	valid_0's auc: 0.830056	valid_0's focal_loss_metric: 0.131174
# [671]	valid_0's auc: 0.829858	valid_0's focal_loss_metric: 0.131199
# [672]	valid_0's auc: 0.830011	valid_0's focal_loss_metric: 0.131152
# [673]	valid_0's auc: 0.830039	valid_0's focal_loss_metric: 0.131173
# [674]	valid_0's auc: 0.829936	valid_0's focal_loss_metric: 0.131148
# [675]	valid_0's auc: 0.830198	valid_0's focal_loss_metric: 0.131129
# [676]	valid_0's auc: 0.83029	valid_0's focal_loss_metric: 0.131104
# [677]	valid_0's auc: 0.830089	valid_0's focal_loss_metric: 0.131137
# [678]	valid_0's auc: 0.830321	valid_0's focal_loss_metric: 0.131095
# [679]	valid_0's auc: 0.830073	valid_0's focal_loss_metric: 0.131119
# [680]	valid_0's auc: 0.830429	valid_0's focal_loss_metric: 0.131069
# [681]	valid_0's auc: 0.830332	valid_0's focal_loss_metric: 0.131078
# [682]	valid_0's auc: 0.830708	valid_0's focal_loss_metric: 0.13103
# [683]	valid_0's auc: 0.830427	valid_0's focal_loss_metric: 0.131055
# [684]	valid_0's auc: 0.830764	valid_0's focal_loss_metric: 0.13101
# [685]	valid_0's auc: 0.830636	valid_0's focal_loss_metric: 0.131019
# [686]	valid_0's auc: 0.830889	valid_0's focal_loss_metric: 0.130974
# [687]	valid_0's auc: 0.830691	valid_0's focal_loss_metric: 0.130966
# [688]	valid_0's auc: 0.830694	valid_0's focal_loss_metric: 0.130951
# [689]	valid_0's auc: 0.830951	valid_0's focal_loss_metric: 0.130909
# [690]	valid_0's auc: 0.830814	valid_0's focal_loss_metric: 0.130905
# [691]	valid_0's auc: 0.830884	valid_0's focal_loss_metric: 0.130907
# [692]	valid_0's auc: 0.830942	valid_0's focal_loss_metric: 0.130883
# [693]	valid_0's auc: 0.830792	valid_0's focal_loss_metric: 0.130929
# [694]	valid_0's auc: 0.830926	valid_0's focal_loss_metric: 0.130885
# [695]	valid_0's auc: 0.830864	valid_0's focal_loss_metric: 0.130899
# [696]	valid_0's auc: 0.831048	valid_0's focal_loss_metric: 0.130856
# [697]	valid_0's auc: 0.831037	valid_0's focal_loss_metric: 0.130868
# [698]	valid_0's auc: 0.831151	valid_0's focal_loss_metric: 0.130825
# [699]	valid_0's auc: 0.831196	valid_0's focal_loss_metric: 0.130836
# [700]	valid_0's auc: 0.831054	valid_0's focal_loss_metric: 0.130867
# [701]	valid_0's auc: 0.831149	valid_0's focal_loss_metric: 0.130823
# ...
# [15779]	valid_0's auc: 0.911945	valid_0's focal_loss_metric: 0.0986611
# [15780]	valid_0's auc: 0.911976	valid_0's focal_loss_metric: 0.0986492
# [15781]	valid_0's auc: 0.911959	valid_0's focal_loss_metric: 0.0986584
# [15782]	valid_0's auc: 0.911984	valid_0's focal_loss_metric: 0.0986457
# [15783]	valid_0's auc: 0.911967	valid_0's focal_loss_metric: 0.0986549
# [15784]	valid_0's auc: 0.91199	valid_0's focal_loss_metric: 0.0986414
# [15785]	valid_0's auc: 0.911962	valid_0's focal_loss_metric: 0.0986521
# [15786]	valid_0's auc: 0.911984	valid_0's focal_loss_metric: 0.0986432
# [15787]	valid_0's auc: 0.911976	valid_0's focal_loss_metric: 0.0986521
# [15788]	valid_0's auc: 0.91199	valid_0's focal_loss_metric: 0.0986424
# [15789]	valid_0's auc: 0.911998	valid_0's focal_loss_metric: 0.0986528
# [15790]	valid_0's auc: 0.911995	valid_0's focal_loss_metric: 0.0986411
# [15791]	valid_0's auc: 0.91199	valid_0's focal_loss_metric: 0.0986514
# [15792]	valid_0's auc: 0.912004	valid_0's focal_loss_metric: 0.0986382
# [15793]	valid_0's auc: 0.911979	valid_0's focal_loss_metric: 0.098647
# [15794]	valid_0's auc: 0.912001	valid_0's focal_loss_metric: 0.0986354
# [15795]	valid_0's auc: 0.911987	valid_0's focal_loss_metric: 0.0986446
# [15796]	valid_0's auc: 0.912018	valid_0's focal_loss_metric: 0.0986337
# [15797]	valid_0's auc: 0.912012	valid_0's focal_loss_metric: 0.0986413
# [15798]	valid_0's auc: 0.912001	valid_0's focal_loss_metric: 0.0986394
# [15799]	valid_0's auc: 0.912023	valid_0's focal_loss_metric: 0.0986372
# [15800]	valid_0's auc: 0.912012	valid_0's focal_loss_metric: 0.0986329
# [15801]	valid_0's auc: 0.912018	valid_0's focal_loss_metric: 0.0986324
# [15802]	valid_0's auc: 0.912004	valid_0's focal_loss_metric: 0.0986278
# [15803]	valid_0's auc: 0.91202	valid_0's focal_loss_metric: 0.0986299
# [15804]	valid_0's auc: 0.912006	valid_0's focal_loss_metric: 0.0986253
# [15805]	valid_0's auc: 0.912015	valid_0's focal_loss_metric: 0.0986266
# [15806]	valid_0's auc: 0.912006	valid_0's focal_loss_metric: 0.0986236
# [15807]	valid_0's auc: 0.912023	valid_0's focal_loss_metric: 0.0986255
# [15808]	valid_0's auc: 0.912001	valid_0's focal_loss_metric: 0.0986206
# [15809]	valid_0's auc: 0.912026	valid_0's focal_loss_metric: 0.0986232
# [15810]	valid_0's auc: 0.912001	valid_0's focal_loss_metric: 0.0986187
# [15811]	valid_0's auc: 0.912026	valid_0's focal_loss_metric: 0.0986213
# [15812]	valid_0's auc: 0.912001	valid_0's focal_loss_metric: 0.0986168
# [15813]	valid_0's auc: 0.912034	valid_0's focal_loss_metric: 0.0986189
# [15814]	valid_0's auc: 0.912004	valid_0's focal_loss_metric: 0.0986144
# [15815]	valid_0's auc: 0.91204	valid_0's focal_loss_metric: 0.0986144
# [15816]	valid_0's auc: 0.912018	valid_0's focal_loss_metric: 0.0986106
# [15817]	valid_0's auc: 0.912034	valid_0's focal_loss_metric: 0.0986101
# [15818]	valid_0's auc: 0.912026	valid_0's focal_loss_metric: 0.0986045
# [15819]	valid_0's auc: 0.912059	valid_0's focal_loss_metric: 0.0986023
# [15820]	valid_0's auc: 0.91204	valid_0's focal_loss_metric: 0.0986004
# [15821]	valid_0's auc: 0.912034	valid_0's focal_loss_metric: 0.0986033
# [15822]	valid_0's auc: 0.912045	valid_0's focal_loss_metric: 0.0985972
# [15823]	valid_0's auc: 0.912057	valid_0's focal_loss_metric: 0.0986001
# [15824]	valid_0's auc: 0.912073	valid_0's focal_loss_metric: 0.0985893
# [15825]	valid_0's auc: 0.912051	valid_0's focal_loss_metric: 0.0985994
# [15826]	valid_0's auc: 0.912068	valid_0's focal_loss_metric: 0.0985867
# [15827]	valid_0's auc: 0.912054	valid_0's focal_loss_metric: 0.0985986
# [15828]	valid_0's auc: 0.912073	valid_0's focal_loss_metric: 0.0985869
# [15829]	valid_0's auc: 0.912065	valid_0's focal_loss_metric: 0.0985968
# [15830]	valid_0's auc: 0.912073	valid_0's focal_loss_metric: 0.0985858
# [15831]	valid_0's auc: 0.912073	valid_0's focal_loss_metric: 0.0985948
# [15832]	valid_0's auc: 0.912073	valid_0's focal_loss_metric: 0.0985888
# [15833]	valid_0's auc: 0.912071	valid_0's focal_loss_metric: 0.0985963
# [15834]	valid_0's auc: 0.912087	valid_0's focal_loss_metric: 0.0985855
# [15835]	valid_0's auc: 0.912073	valid_0's focal_loss_metric: 0.0985884
# [15836]	valid_0's auc: 0.912071	valid_0's focal_loss_metric: 0.0985865
# [15837]	valid_0's auc: 0.912076	valid_0's focal_loss_metric: 0.0985843
# [15838]	valid_0's auc: 0.912096	valid_0's focal_loss_metric: 0.0985784
# [15839]	valid_0's auc: 0.912082	valid_0's focal_loss_metric: 0.098586
# [15840]	valid_0's auc: 0.912101	valid_0's focal_loss_metric: 0.0985753
# [15841]	valid_0's auc: 0.912085	valid_0's focal_loss_metric: 0.0985829
# [15842]	valid_0's auc: 0.912101	valid_0's focal_loss_metric: 0.0985769
# [15843]	valid_0's auc: 0.912087	valid_0's focal_loss_metric: 0.0985798
# [15844]	valid_0's auc: 0.91209	valid_0's focal_loss_metric: 0.098578
# [15845]	valid_0's auc: 0.912082	valid_0's focal_loss_metric: 0.0985808
# [15846]	valid_0's auc: 0.912096	valid_0's focal_loss_metric: 0.0985748
# [15847]	valid_0's auc: 0.912082	valid_0's focal_loss_metric: 0.0985777
# [15848]	valid_0's auc: 0.912101	valid_0's focal_loss_metric: 0.0985717
# [15849]	valid_0's auc: 0.912087	valid_0's focal_loss_metric: 0.0985792
# [15850]	valid_0's auc: 0.912107	valid_0's focal_loss_metric: 0.0985685
# [15851]	valid_0's auc: 0.912093	valid_0's focal_loss_metric: 0.0985773
# [15852]	valid_0's auc: 0.91211	valid_0's focal_loss_metric: 0.0985664
# [15853]	valid_0's auc: 0.912104	valid_0's focal_loss_metric: 0.0985752
# [15854]	valid_0's auc: 0.912112	valid_0's focal_loss_metric: 0.0985645
# [15855]	valid_0's auc: 0.912112	valid_0's focal_loss_metric: 0.098572
# [15856]	valid_0's auc: 0.912121	valid_0's focal_loss_metric: 0.0985614
# [15857]	valid_0's auc: 0.912121	valid_0's focal_loss_metric: 0.0985688
# [15858]	valid_0's auc: 0.912118	valid_0's focal_loss_metric: 0.0985629
# [15859]	valid_0's auc: 0.912129	valid_0's focal_loss_metric: 0.0985657
# [15860]	valid_0's auc: 0.912096	valid_0's focal_loss_metric: 0.0985639
# [15861]	valid_0's auc: 0.912151	valid_0's focal_loss_metric: 0.0985617
# [15862]	valid_0's auc: 0.912096	valid_0's focal_loss_metric: 0.0985575
# [15863]	valid_0's auc: 0.91214	valid_0's focal_loss_metric: 0.098557
# [15864]	valid_0's auc: 0.912115	valid_0's focal_loss_metric: 0.0985532
# [15865]	valid_0's auc: 0.912151	valid_0's focal_loss_metric: 0.0985531
# [15866]	valid_0's auc: 0.912129	valid_0's focal_loss_metric: 0.0985487
# [15867]	valid_0's auc: 0.912157	valid_0's focal_loss_metric: 0.0985508
# [15868]	valid_0's auc: 0.912135	valid_0's focal_loss_metric: 0.0985464
# [15869]	valid_0's auc: 0.912165	valid_0's focal_loss_metric: 0.0985485
# [15870]	valid_0's auc: 0.912143	valid_0's focal_loss_metric: 0.098544
# [15871]	valid_0's auc: 0.912171	valid_0's focal_loss_metric: 0.0985465
# [15872]	valid_0's auc: 0.912146	valid_0's focal_loss_metric: 0.0985416
# [15873]	valid_0's auc: 0.912174	valid_0's focal_loss_metric: 0.0985436
# [15874]	valid_0's auc: 0.912146	valid_0's focal_loss_metric: 0.0985406
# [15875]	valid_0's auc: 0.912165	valid_0's focal_loss_metric: 0.0985419
# [15876]	valid_0's auc: 0.912137	valid_0's focal_loss_metric: 0.0985396
# [15877]	valid_0's auc: 0.912163	valid_0's focal_loss_metric: 0.0985361
# [15878]	valid_0's auc: 0.91214	valid_0's focal_loss_metric: 0.0985375
# [15879]	valid_0's auc: 0.912157	valid_0's focal_loss_metric: 0.0985356
# [15880]	valid_0's auc: 0.91214	valid_0's focal_loss_metric: 0.0985349
# [15881]	valid_0's auc: 0.912154	valid_0's focal_loss_metric: 0.0985375
# [15882]	valid_0's auc: 0.912151	valid_0's focal_loss_metric: 0.0985317
# [15883]	valid_0's auc: 0.912163	valid_0's focal_loss_metric: 0.0985354
# [15884]	valid_0's auc: 0.912151	valid_0's focal_loss_metric: 0.0985295
# [15885]	valid_0's auc: 0.912176	valid_0's focal_loss_metric: 0.0985322
# [15886]	valid_0's auc: 0.912132	valid_0's focal_loss_metric: 0.0985329
# [15887]	valid_0's auc: 0.912174	valid_0's focal_loss_metric: 0.0985302
# [15888]	valid_0's auc: 0.912143	valid_0's focal_loss_metric: 0.0985171
# [15889]	valid_0's auc: 0.912182	valid_0's focal_loss_metric: 0.098507
# [15890]	valid_0's auc: 0.912137	valid_0's focal_loss_metric: 0.0985184
# [15891]	valid_0's auc: 0.912132	valid_0's focal_loss_metric: 0.0985192
# [15892]	valid_0's auc: 0.912129	valid_0's focal_loss_metric: 0.0985219
# [15893]	valid_0's auc: 0.912146	valid_0's focal_loss_metric: 0.098516
# [15894]	valid_0's auc: 0.912143	valid_0's focal_loss_metric: 0.0985179
# [15895]	valid_0's auc: 0.912146	valid_0's focal_loss_metric: 0.0985157
# [15896]	valid_0's auc: 0.91214	valid_0's focal_loss_metric: 0.0985169
# [15897]	valid_0's auc: 0.912137	valid_0's focal_loss_metric: 0.098514
# [15898]	valid_0's auc: 0.912146	valid_0's focal_loss_metric: 0.098516
# [15899]	valid_0's auc: 0.912143	valid_0's focal_loss_metric: 0.0985111
# [15900]	valid_0's auc: 0.912149	valid_0's focal_loss_metric: 0.0985137
# [15901]	valid_0's auc: 0.912143	valid_0's focal_loss_metric: 0.0985091
# [15902]	valid_0's auc: 0.91216	valid_0's focal_loss_metric: 0.0985112
# [15903]	valid_0's auc: 0.912146	valid_0's focal_loss_metric: 0.0985068
# [15904]	valid_0's auc: 0.912168	valid_0's focal_loss_metric: 0.0985068
# [15905]	valid_0's auc: 0.912157	valid_0's focal_loss_metric: 0.0985031
# [15906]	valid_0's auc: 0.912171	valid_0's focal_loss_metric: 0.0985026
# [15907]	valid_0's auc: 0.912154	valid_0's focal_loss_metric: 0.098497
# [15908]	valid_0's auc: 0.912188	valid_0's focal_loss_metric: 0.0984992
# [15909]	valid_0's auc: 0.912168	valid_0's focal_loss_metric: 0.0984937
# [15910]	valid_0's auc: 0.91221	valid_0's focal_loss_metric: 0.0984932
# [15911]	valid_0's auc: 0.912229	valid_0's focal_loss_metric: 0.0984843
# [15912]	valid_0's auc: 0.912216	valid_0's focal_loss_metric: 0.0984894
# [15913]	valid_0's auc: 0.912196	valid_0's focal_loss_metric: 0.098484
# [15914]	valid_0's auc: 0.912199	valid_0's focal_loss_metric: 0.0984824
# [15915]	valid_0's auc: 0.912204	valid_0's focal_loss_metric: 0.098484
# [15916]	valid_0's auc: 0.912196	valid_0's focal_loss_metric: 0.0984835
# [15917]	valid_0's auc: 0.912224	valid_0's focal_loss_metric: 0.0984856
# [15918]	valid_0's auc: 0.91219	valid_0's focal_loss_metric: 0.0984814
# [15919]	valid_0's auc: 0.912224	valid_0's focal_loss_metric: 0.0984792
# [15920]	valid_0's auc: 0.912182	valid_0's focal_loss_metric: 0.0984817
# [15921]	valid_0's auc: 0.912232	valid_0's focal_loss_metric: 0.0984741
# [15922]	valid_0's auc: 0.912221	valid_0's focal_loss_metric: 0.0984699
# [15923]	valid_0's auc: 0.912232	valid_0's focal_loss_metric: 0.098472
# [15924]	valid_0's auc: 0.912196	valid_0's focal_loss_metric: 0.098489
# [15925]	valid_0's auc: 0.91228	valid_0's focal_loss_metric: 0.0984711
# [15926]	valid_0's auc: 0.912213	valid_0's focal_loss_metric: 0.0984893
# [15927]	valid_0's auc: 0.912268	valid_0's focal_loss_metric: 0.0984737
# [15928]	valid_0's auc: 0.912204	valid_0's focal_loss_metric: 0.0984893
# [15929]	valid_0's auc: 0.912196	valid_0's focal_loss_metric: 0.0984907
# [15930]	valid_0's auc: 0.912213	valid_0's focal_loss_metric: 0.0984947
# [15931]	valid_0's auc: 0.912193	valid_0's focal_loss_metric: 0.0984915
# [15932]	valid_0's auc: 0.912193	valid_0's focal_loss_metric: 0.0984989
# [15933]	valid_0's auc: 0.912207	valid_0's focal_loss_metric: 0.0984866
# [15934]	valid_0's auc: 0.912255	valid_0's focal_loss_metric: 0.0984689
# [15935]	valid_0's auc: 0.912213	valid_0's focal_loss_metric: 0.0984869
# [15936]	valid_0's auc: 0.912229	valid_0's focal_loss_metric: 0.0984877
# [15937]	valid_0's auc: 0.912238	valid_0's focal_loss_metric: 0.0984785
# [15938]	valid_0's auc: 0.912241	valid_0's focal_loss_metric: 0.0984857
# [15939]	valid_0's auc: 0.912213	valid_0's focal_loss_metric: 0.0984835
# [15940]	valid_0's auc: 0.912235	valid_0's focal_loss_metric: 0.0984874
# [15941]	valid_0's auc: 0.912241	valid_0's focal_loss_metric: 0.0984754
# [15942]	valid_0's auc: 0.91226	valid_0's focal_loss_metric: 0.0984841
# [15943]	valid_0's auc: 0.912246	valid_0's focal_loss_metric: 0.0984822
# [15944]	valid_0's auc: 0.912266	valid_0's focal_loss_metric: 0.0984787
# [15945]	valid_0's auc: 0.912302	valid_0's focal_loss_metric: 0.0984708
# [15946]	valid_0's auc: 0.912257	valid_0's focal_loss_metric: 0.0984803
# [15947]	valid_0's auc: 0.912299	valid_0's focal_loss_metric: 0.0984716
# [15948]	valid_0's auc: 0.912249	valid_0's focal_loss_metric: 0.0984808
# [15949]	valid_0's auc: 0.912288	valid_0's focal_loss_metric: 0.0984727
# [15950]	valid_0's auc: 0.912266	valid_0's focal_loss_metric: 0.098471
# [15951]	valid_0's auc: 0.912263	valid_0's focal_loss_metric: 0.0984739
# [15952]	valid_0's auc: 0.912266	valid_0's focal_loss_metric: 0.098468
# [15953]	valid_0's auc: 0.912243	valid_0's focal_loss_metric: 0.0984712
# [15954]	valid_0's auc: 0.912257	valid_0's focal_loss_metric: 0.0984683
# [15955]	valid_0's auc: 0.912263	valid_0's focal_loss_metric: 0.0984712
# [15956]	valid_0's auc: 0.91226	valid_0's focal_loss_metric: 0.0984653
# [15957]	valid_0's auc: 0.912263	valid_0's focal_loss_metric: 0.0984728
# [15958]	valid_0's auc: 0.912266	valid_0's focal_loss_metric: 0.0984622
# [15959]	valid_0's auc: 0.912274	valid_0's focal_loss_metric: 0.0984696
# [15960]	valid_0's auc: 0.912274	valid_0's focal_loss_metric: 0.0984591
# [15961]	valid_0's auc: 0.912277	valid_0's focal_loss_metric: 0.098468
# [15962]	valid_0's auc: 0.912268	valid_0's focal_loss_metric: 0.0984571
# [15963]	valid_0's auc: 0.912277	valid_0's focal_loss_metric: 0.098467
# [15964]	valid_0's auc: 0.912274	valid_0's focal_loss_metric: 0.0984553
# [15965]	valid_0's auc: 0.912288	valid_0's focal_loss_metric: 0.0984652
# [15966]	valid_0's auc: 0.912282	valid_0's focal_loss_metric: 0.0984537
# [15967]	valid_0's auc: 0.912285	valid_0's focal_loss_metric: 0.0984656
# [15968]	valid_0's auc: 0.912291	valid_0's focal_loss_metric: 0.098453
# [15969]	valid_0's auc: 0.912282	valid_0's focal_loss_metric: 0.0984648
# [15970]	valid_0's auc: 0.912294	valid_0's focal_loss_metric: 0.0984524
# [15971]	valid_0's auc: 0.912288	valid_0's focal_loss_metric: 0.0984615
# [15972]	valid_0's auc: 0.912299	valid_0's focal_loss_metric: 0.0984484
# [15973]	valid_0's auc: 0.912285	valid_0's focal_loss_metric: 0.0984559
# [15974]	valid_0's auc: 0.912302	valid_0's focal_loss_metric: 0.0984465
# [15975]	valid_0's auc: 0.912299	valid_0's focal_loss_metric: 0.0984583
# [15976]	valid_0's auc: 0.912252	valid_0's focal_loss_metric: 0.0984674
# [15977]	valid_0's auc: 0.912313	valid_0's focal_loss_metric: 0.0984588
# [15978]	valid_0's auc: 0.91231	valid_0's focal_loss_metric: 0.0984467
# [15979]	valid_0's auc: 0.912319	valid_0's focal_loss_metric: 0.0984558
# [15980]	valid_0's auc: 0.912316	valid_0's focal_loss_metric: 0.0984438
# [15981]	valid_0's auc: 0.912319	valid_0's focal_loss_metric: 0.0984556
# [15982]	valid_0's auc: 0.912305	valid_0's focal_loss_metric: 0.0984444
# [15983]	valid_0's auc: 0.912316	valid_0's focal_loss_metric: 0.0984543
# [15984]	valid_0's auc: 0.912299	valid_0's focal_loss_metric: 0.0984437
# [15985]	valid_0's auc: 0.912307	valid_0's focal_loss_metric: 0.0984525
# [15986]	valid_0's auc: 0.912285	valid_0's focal_loss_metric: 0.0984421
# [15987]	valid_0's auc: 0.912316	valid_0's focal_loss_metric: 0.0984496
# [15988]	valid_0's auc: 0.912285	valid_0's focal_loss_metric: 0.0984438
# [15989]	valid_0's auc: 0.912319	valid_0's focal_loss_metric: 0.0984466
# [15990]	valid_0's auc: 0.912285	valid_0's focal_loss_metric: 0.0984449
# [15991]	valid_0's auc: 0.912321	valid_0's focal_loss_metric: 0.0984426
# [15992]	valid_0's auc: 0.912288	valid_0's focal_loss_metric: 0.0984385
# [15993]	valid_0's auc: 0.912296	valid_0's focal_loss_metric: 0.0984404
# [15994]	valid_0's auc: 0.91228	valid_0's focal_loss_metric: 0.0984527
# [15995]	valid_0's auc: 0.912296	valid_0's focal_loss_metric: 0.0984419
# [15996]	valid_0's auc: 0.912288	valid_0's focal_loss_metric: 0.0984353
# [15997]	valid_0's auc: 0.912321	valid_0's focal_loss_metric: 0.0984346
# [15998]	valid_0's auc: 0.912288	valid_0's focal_loss_metric: 0.0984348
# [15999]	valid_0's auc: 0.912296	valid_0's focal_loss_metric: 0.0984384
# [16000]	valid_0's auc: 0.912294	valid_0's focal_loss_metric: 0.0984319
# LGBMClassifier(force_row_wise=True, learning_rate=0.25, max_depth=1,
#                metric='auc', n_estimators=16000, num_threads=100,
#                objective=<function focal_loss_objective at 0x000001FC8DF4C9D8>,
#                verbosity=1)

# %%
from scipy.special import expit                               # Import the sigmoid function from scipy
probs = expit(gbm_focal_loss.predict(X_test, raw_score=True))   # Get raw scores and then compute the probability positive class
                                                              # using the sigmoid function
y_pred = (probs > 0.5).astype(int)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 0, 1, 1])

# %%
confusion = confusion_matrix(y_pred, y_test)
confusion
# Out:
# array([[518, 110],
#        [ 75, 495]], dtype=int64)

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
lgb_acc = accuracy_score(y_pred, y_test)
lgb_prec = precision_score(y_pred, y_test)
lgb_rec = recall_score(y_pred, y_test)
lgb_f1 = f1_score(y_pred, y_test)
lgb_auprc = average_precision_score(y_pred, y_test)
lgb_auroc = roc_auc_score(y_test, y_pred)
lgb_mcc = matthews_corrcoef(y_pred, y_test)

lgb_sens = TP / (TP + FN)
lgb_spec = TN / (TN + FP)

storeResults('LightGBM Focal Loss',lgb_acc,lgb_prec,lgb_rec,lgb_f1,lgb_auprc,lgb_auroc,lgb_mcc,lgb_sens,lgb_spec)

# %%
lgb_acc
# Out:
# 0.845575959933222

# %% [markdown]
# # Voting  CLassifier

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, AdaBoostClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, average_precision_score, roc_auc_score, matthews_corrcoef


# Define classifiers
clf1 = AdaBoostClassifier(n_estimators=100, random_state=0)
clf2 = RandomForestClassifier(n_estimators=50, random_state=1)

# Create a voting classifier
voting_clf = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2)], voting='soft')


# Train the voting classifier
voting_clf.fit(X_train, y_train)

# Predict on the training set
y_pred_train = voting_clf.predict(X_train)

# Calculate confusion matrix
confusion = confusion_matrix(y_train, y_train)
TP = confusion[1, 1]  # true positive
TN = confusion[0, 0]  # true negatives
FP = confusion[0, 1]  # false positives
FN = confusion[1, 0]  # false negatives

# Calculate evaluation metrics
stac_acc = accuracy_score(y_train, y_train)
stac_prec = precision_score(y_train, y_train)
stac_rec = recall_score(y_train, y_train)
stac_f1 = f1_score(y_train, y_train)
stac_auprc = average_precision_score(y_train, y_train)
stac_auroc = roc_auc_score(y_train, voting_clf.predict_proba(X_train)[:, 1])
stac_mcc = matthews_corrcoef(y_train, y_train)

# Calculate sensitivity and specificity
stac_sens = TP / (TP + FN)
stac_spec = TN / (TN + FP)

stac_acc

# Store results (assuming there's a function named 'storeResults' defined)
storeResults('Voting Classifier', stac_acc, stac_prec, stac_rec, stac_f1, stac_auprc, stac_auroc, stac_mcc, stac_sens, stac_spec)

# %%
stac_acc
# Out:
# 1.0

# %% [markdown]
# # Comparison

# %%
#creating dataframe
result = pd.DataFrame({ 'ML Model' : ML_Model,
                        'Accuracy' : accuracy,
                        'Precision': precision,
                        'Recall'   : recall,
                        'F1-Score': f1score,
                        'AUC-PRC' : auprc,
                        'AUC-ROC' : auroc,
                        'MCC' : mcc,
                        'Senstivity' : sens,
                        'Specificity' : spec,
                      })

# %%
result
# Out:
#                     ML Model  Accuracy  Precision  Recall  F1-Score  AUC-PRC  \
# 0        AdaBoost Classifier     0.727      0.747   0.722     0.734    0.685
# 1   Decision Tree Classifier     0.773      0.807   0.759     0.782    0.742
# 2         Bagging Classifier     0.652      0.671   0.651     0.661    0.619
# 3   Decision Tree Classifier     0.782      0.808   0.771     0.789    0.744
# 4        AdaBoost Classifier     0.727      0.747   0.722     0.734    0.685
# 5        CatBoost Classifier     0.669      0.727   0.655     0.689    0.670
# 6    LightGBM w/o Focal Loss     0.874      0.868   0.881     0.874    0.824
# 7        LightGBM Focal Loss     0.846      0.818   0.868     0.843    0.773
# 8          Voting Classifier     1.000      1.000   1.000     1.000    1.000
# 9          Voting Classifier     1.000      1.000   1.000     1.000    1.000
# 10         Voting Classifier     1.000      1.000   1.000     1.000    1.000
# 11         Voting Classifier     1.000      1.000   1.000     1.000    1.000
# 12         Voting Classifier     1.000      1.000   1.000     1.000    1.000
# 13         Voting Classifier     1.000      1.000   1.000     1.000    1.000
# 14         Voting Classifier     1.000      1.000   1.000     1.000    1.000
#
#     AUC-ROC    MCC  Senstivity  Specificity
# 0     0.816  0.454       0.722        0.733
# 1     0.773  0.547       0.759        0.789
# 2     0.671  0.304       0.651        0.653
# 3     0.782  0.565       0.771        0.794
# 4     0.816  0.454       0.722        0.733
# 5     0.748  0.339       0.655        0.686
# 6     0.944  0.748       0.881        0.867
# 7     0.846  0.692       0.868        0.825
# 8     1.000  1.000       1.000        1.000
# 9     1.000  1.000       1.000        1.000
# 10    1.000  1.000       1.000        1.000
# 11    1.000  1.000       1.000        1.000
# 12    1.000  1.000       1.000        1.000
# 13    1.000  1.000       1.000        1.000
# 14    1.000  1.000       1.000        1.000

# %%
import joblib
filename = 'model.sav'
joblib.dump(voting_clf, filename)
# Out:
# ['model.sav']

# %% [markdown]
# # Graph

# %%
classifier = ML_Model
y_pos = np.arange(len(classifier))

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, accuracy, align='center', alpha=0.5,color='blue')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Accuracy Score')
plt2.title('Classification Performance')
plt2.show()

# %%
plt2.barh(y_pos, precision, align='center', alpha=0.5,color='red')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Precision Score')
plt2.title('Classification Performance')
plt2.show()

# %%
plt2.barh(y_pos, recall, align='center', alpha=0.5,color='cyan')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Recall Score')
plt2.title('Classification Performance')
plt2.show()

# %%
plt2.barh(y_pos, f1score, align='center', alpha=0.5,color='magenta')
plt2.yticks(y_pos, classifier)
plt2.xlabel('F1 Score')
plt2.title('Classification Performance')
plt2.show()

# %%
plt2.barh(y_pos, sens, align='center', alpha=0.5,color='yellow')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Sensitivity')
plt2.title('Classification Performance')
plt2.show()

# %%
plt2.barh(y_pos, spec, align='center', alpha=0.5,color='black')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Specificity')
plt2.title('Classification Performance')
plt2.show()

# %%
plt2.barh(y_pos, auprc, align='center', alpha=0.5,color='pink')
plt2.yticks(y_pos, classifier)
plt2.xlabel('AUCPRC')
plt2.title('Classification Performance')
plt2.show()

# %%
plt2.barh(y_pos, auroc, align='center', alpha=0.5,color='green')
plt2.yticks(y_pos, classifier)
plt2.xlabel('AUC - ROC')
plt2.title('Classification Performance')
plt2.show()

# %%
plt2.barh(y_pos, mcc, align='center', alpha=0.5,color='brown')
plt2.yticks(y_pos, classifier)
plt2.xlabel('MCC')
plt2.title('Classification Performance')
plt2.show()
