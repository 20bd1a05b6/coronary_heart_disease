# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("CHD_preprocessed.csv")
data.columns = ['sex','Age','Education','CurrentSmoker','CigsPerDay','BPMeds','PrevalentStroke','PrevalentHyp','Diabetes','TotChol','SysBP','DiaBP','BMI','HeartRate','Glucose','TenYearCHD']
data.head()
# Out:
#    sex  Age  Education  CurrentSmoker  CigsPerDay  BPMeds  PrevalentStroke  \
# 0    1   39          1              0           0       0                0
# 1    0   46          0              0           0       0                0
# 2    1   48          0              1          20       0                0
# 3    0   61          1              1          30       0                0
# 4    0   46          1              1          23       0                0
#
#    PrevalentHyp  Diabetes  TotChol  SysBP  DiaBP    BMI  HeartRate  Glucose  \
# 0             0         0      195  106.0   70.0  26.97         80       77
# 1             0         0      250  121.0   81.0  28.73         95       76
# 2             0         0      245  127.5   80.0  25.34         75       70
# 3             1         0      225  150.0   95.0  28.58         65      103
# 4             0         0      285  130.0   84.0  23.10         85       85
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %%
import pandas as pd

# Read the excel sheet
df = pd.read_csv('preprocessed.csv')


# Define a function to classify sex column and create separate 'male' and 'female' columns
def classify_sex(row):
    if row['sex'] == 'female':
        return 1
    else:
        return 0

# Apply the function to create 'male' and 'female' columns
df['male'] = df.apply(classify_sex, axis=1)
df['female'] = 1 - df['male']  # Alternatively, you can create 'female' column using this formula


# Write the updated DataFrame back to the Excel file
df.to_csv("preprocessed.csv", index=False)
data.head()
# Out:
#    sex  Age  Education  CurrentSmoker  CigsPerDay  BPMeds  PrevalentStroke  \
# 0    1   39          1              0           0       0                0
# 1    0   46          0              0           0       0                0
# 2    1   48          0              1          20       0                0
# 3    0   61          1              1          30       0                0
# 4    0   46          1              1          23       0                0
#
#    PrevalentHyp  Diabetes  TotChol  SysBP  DiaBP    BMI  HeartRate  Glucose  \
# 0             0         0      195  106.0   70.0  26.97         80       77
# 1             0         0      250  121.0   81.0  28.73         95       76
# 2             0         0      245  127.5   80.0  25.34         75       70
# 3             1         0      225  150.0   95.0  28.58         65      103
# 4             0         0      285  130.0   84.0  23.10         85       85
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %%
 data = data.drop(columns=['Education'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4133 entries, 0 to 4132
# Data columns (total 15 columns):
# sex                4133 non-null int64
# Age                4133 non-null int64
# CurrentSmoker      4133 non-null int64
# CigsPerDay         4133 non-null int64
# BPMeds             4133 non-null int64
# PrevalentStroke    4133 non-null int64
# PrevalentHyp       4133 non-null int64
# Diabetes           4133 non-null int64
# TotChol            4133 non-null int64
# SysBP              4133 non-null float64
# DiaBP              4133 non-null float64
# BMI                4133 non-null float64
# HeartRate          4133 non-null int64
# Glucose            4133 non-null int64
# TenYearCHD         4133 non-null int64
# dtypes: float64(3), int64(12)
# memory usage: 484.5 KB

# %%
data.isnull().sum()
# Out:
# sex                0
# Age                0
# CurrentSmoker      0
# CigsPerDay         0
# BPMeds             0
# PrevalentStroke    0
# PrevalentHyp       0
# Diabetes           0
# TotChol            0
# SysBP              0
# DiaBP              0
# BMI                0
# HeartRate          0
# Glucose            0
# TenYearCHD         0
# dtype: int64

# %%
l = ['CigsPerDay', 'BPMeds', 'TotChol', 'HeartRate', 'BMI', 'Glucose', 'PrevalentStroke', 'Diabetes',
    'SysBP', 'DiaBP']
for i in l:
    data[i] = data[i].replace(np.nan, data[i].mean())

# %%
data.isnull().sum()
# Out:
# Sex                0
# Age                0
# CurrentSmoker      0
# CigsPerDay         0
# BPMeds             0
# PrevalentStroke    0
# PrevalentHyp       0
# Diabetes           0
# TotChol            0
# SysBP              0
# DiaBP              0
# BMI                0
# HeartRate          0
# Glucose            0
# TenYearCHD         0
# dtype: int64

# %%
sns.countplot(x=data['TenYearCHD'])
# Out:
# <AxesSubplot:xlabel='TenYearCHD', ylabel='count'>

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %%
q1 = data.drop('TenYearCHD', axis = 1).quantile(0.25)

# compute the first quartile using quantile(0.75)
# use .drop() to drop the target variable 
# axis=1: specifies that the labels are dropped from the columns
q3 = data.drop('TenYearCHD', axis = 1).quantile(0.75)

# calculate of interquartile range 
IQR = q3 - q1

LL = q1 - 1.5 * IQR
UL = q3 + 1.5 * IQR

data = data[~((data < LL) | (data > UL)).any(axis = 1)]

# %%
data.shape
# Out:
# (3435, 15)

# %%
X = data.drop(["TenYearCHD"],axis =1)
y = data["TenYearCHD"]

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE(sampling_strategy = 'minority', random_state = 1)
X, y = oversample.fit_resample(X, y)

# %%
X = X.drop(['BPMeds', 'PrevalentStroke', 'Diabetes'], axis = 1)

# %%
X.columns
# Out:
# Index(['Sex', 'Age', 'CurrentSmoker', 'CigsPerDay', 'PrevalentHyp', 'TotChol',
#        'SysBP', 'DiaBP', 'BMI', 'HeartRate', 'Glucose'],
#       dtype='object')

# %%
df = data[['Sex', 'Age', 'CurrentSmoker', 'CigsPerDay', 'PrevalentHyp', 'TotChol',
       'SysBP', 'DiaBP', 'BMI', 'HeartRate', 'Glucose','TenYearCHD']]
df.to_csv('processed.csv')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((4790, 11), (4790,), (1198, 11), (1198,))

# %%
ML_Model = []
accuracy = []
precision = []
recall = []
f1score = []
auprc = []
auroc = []
mcc = []
sens = []
spec = []

#function to call for storing the results
def storeResults(model, a,b,c,d,e,f,g,h,i):
    ML_Model.append(model)
    accuracy.append(round(a, 3))
    precision.append(round(b, 3))
    recall.append(round(c, 3))
    f1score.append(round(d, 3))
    auprc.append(round(e, 3))
    auroc.append(round(f, 3))
    mcc.append(round(g, 3))
    sens.append(round(h, 3))
    spec.append(round(i, 3))

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score, matthews_corrcoef, confusion_matrix

# %%
from sklearn.ensemble import AdaBoostClassifier

# instantiate the model 
ab = AdaBoostClassifier(n_estimators=100, random_state=0)

# fit the model 
ab.fit(X_train, y_train)

#predicting the target value from the model for the samples

y_pred = ab.predict(X_test)

confusion = confusion_matrix(y_pred, y_test)
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

ab_acc = accuracy_score(y_pred, y_test)
ab_prec = precision_score(y_pred, y_test)
ab_rec = recall_score(y_pred, y_test)
ab_f1 = f1_score(y_pred, y_test)
ab_auprc = average_precision_score(y_pred, y_test)
ab_auroc = roc_auc_score(y_test, ab.predict_proba(X_test)[:, 1])
ab_mcc = matthews_corrcoef(y_pred, y_test)

ab_sens = TP / (TP + FN)
ab_spec = TN / (TN + FP)

storeResults('AdaBoost Classifier',ab_acc,ab_prec,ab_rec,ab_f1,ab_auprc,ab_auroc,ab_mcc,ab_sens,ab_spec)

# %%
ab_acc
# Out:
# 0.7579298831385642

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

#predicting the target value from the model for the samples

y_pred = tree.predict(X_test)

confusion = confusion_matrix(y_pred, y_test)
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

dt_acc = accuracy_score(y_pred, y_test)
dt_prec = precision_score(y_pred, y_test)
dt_rec = recall_score(y_pred, y_test)
dt_f1 = f1_score(y_pred, y_test)
dt_auprc = average_precision_score(y_pred, y_test)
dt_auroc = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_mcc = matthews_corrcoef(y_pred, y_test)

dt_sens = TP / (TP + FN)
dt_spec = TN / (TN + FP)

storeResults('Decision Tree Classifier',dt_acc,dt_prec,dt_rec,dt_f1,dt_auprc,dt_auroc,dt_mcc,dt_sens,dt_spec)

# %%
dt_acc
# Out:
# 0.820534223706177

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC

# instantiate the model 
clf = BaggingClassifier(SVC(),n_estimators=10, random_state=0)

# fit the model 
clf.fit(X_train, y_train)

#predicting the target value from the model for the samples

y_pred = clf.predict(X_test)

confusion = confusion_matrix(y_pred, y_test)
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

bg_acc = accuracy_score(y_pred, y_test)
bg_prec = precision_score(y_pred, y_test)
bg_rec = recall_score(y_pred, y_test)
bg_f1 = f1_score(y_pred, y_test)
bg_auprc = average_precision_score(y_pred, y_test)
bg_auroc = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
bg_mcc = matthews_corrcoef(y_pred, y_test)

bg_sens = TP / (TP + FN)
bg_spec = TN / (TN + FP)

storeResults('Bagging Classifier',bg_acc,bg_prec,bg_rec,bg_f1,bg_auprc,bg_auroc,bg_mcc,bg_sens,bg_spec)

# %%
bg_acc
# Out:
# 0.6510851419031719

# %%
from sklearn.ensemble import GradientBoostingClassifier

# instantiate the model 
gbm = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,max_depth=1, random_state=0)

# fit the model 
gbm.fit(X_train, y_train)

#predicting the target value from the model for the samples

y_pred = gbm.predict(X_test)

confusion = confusion_matrix(y_pred, y_test)
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

gb_acc = accuracy_score(y_pred, y_test)
gb_prec = precision_score(y_pred, y_test)
gb_rec = recall_score(y_pred, y_test)
gb_f1 = f1_score(y_pred, y_test)
gb_auprc = average_precision_score(y_pred, y_test)
gb_auroc = roc_auc_score(y_test, gbm.predict_proba(X_test)[:, 1])
gb_mcc = matthews_corrcoef(y_pred, y_test)

gb_sens = TP / (TP + FN)
gb_spec = TN / (TN + FP)

storeResults('Gradient Boosting Classifier',gb_acc,gb_prec,gb_rec,gb_f1,gb_auprc,gb_auroc,gb_mcc,gb_sens,gb_spec)

# %%
gb_acc
# Out:
# 0.7687813021702838

# %%
from xgboost import XGBClassifier

# instantiate the model
xgb = XGBClassifier()

# fit the model 
xgb.fit(X_train, y_train)

#predicting the target value from the model for the samples

y_pred = xgb.predict(X_test)

confusion = confusion_matrix(y_pred, y_test)
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

xgb_acc = accuracy_score(y_pred, y_test)
xgb_prec = precision_score(y_pred, y_test)
xgb_rec = recall_score(y_pred, y_test)
xgb_f1 = f1_score(y_pred, y_test)
xgb_auprc = average_precision_score(y_pred, y_test)
xgb_auroc = roc_auc_score(y_test, xgb.predict_proba(X_test)[:, 1])
xgb_mcc = matthews_corrcoef(y_pred, y_test)

xgb_sens = TP / (TP + FN)
xgb_spec = TN / (TN + FP)

storeResults('XGBoost Classifier',xgb_acc,xgb_prec,xgb_rec,xgb_f1,xgb_auprc,xgb_auroc,xgb_mcc,xgb_sens,xgb_spec)

# %%
xgb_acc
# Out:
# 0.9040066777963273

# %%
from catboost import CatBoostClassifier

clf = CatBoostClassifier(
    iterations=5, 
    learning_rate=0.1, 
    #loss_function='CrossEntropy'
)

# fit the model 
clf.fit(X_train, y_train)

#predicting the target value from the model for the samples

y_pred = clf.predict(X_test)

confusion = confusion_matrix(y_pred, y_test)
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

cat_acc = accuracy_score(y_pred, y_test)
cat_prec = precision_score(y_pred, y_test)
cat_rec = recall_score(y_pred, y_test)
cat_f1 = f1_score(y_pred, y_test)
cat_auprc = average_precision_score(y_pred, y_test)
cat_auroc = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
cat_mcc = matthews_corrcoef(y_pred, y_test)

cat_sens = TP / (TP + FN)
cat_spec = TN / (TN + FP)

storeResults('CatBoost Classifier',cat_acc,cat_prec,cat_rec,cat_f1,cat_auprc,cat_auroc,cat_mcc,cat_sens,cat_spec)
# Out:
# 0:	learn: 0.6783127	total: 167ms	remaining: 667ms
# 1:	learn: 0.6620612	total: 177ms	remaining: 266ms
# 2:	learn: 0.6504584	total: 187ms	remaining: 125ms
# 3:	learn: 0.6396822	total: 199ms	remaining: 49.7ms
# 4:	learn: 0.6292837	total: 209ms	remaining: 0us

# %%
cat_acc
# Out:
# 0.671118530884808

# %%
import lightgbm as lgb
clf = lgb.LGBMClassifier(boosting_type='gbdt',verbosity=1,metric='auc',objctive='binary',num_threads = 10000,force_row_wise=True)
clf.fit(X_train, y_train, verbose=0)

y_pred = clf.predict(X_test)

confusion = confusion_matrix(y_pred, y_test)
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

lgb_acc = accuracy_score(y_pred, y_test)
lgb_prec = precision_score(y_pred, y_test)
lgb_rec = recall_score(y_pred, y_test)
lgb_f1 = f1_score(y_pred, y_test)
lgb_auprc = average_precision_score(y_pred, y_test)
lgb_auroc = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
lgb_mcc = matthews_corrcoef(y_pred, y_test)

lgb_sens = TP / (TP + FN)
lgb_spec = TN / (TN + FP)

storeResults('LightGBM w/o Focal Loss',lgb_acc,lgb_prec,lgb_rec,lgb_f1,lgb_auprc,lgb_auroc,lgb_mcc,lgb_sens,lgb_spec)
# Out:
# [LightGBM] [Warning] Unknown parameter: objctive
# [LightGBM] [Warning] num_threads is set=10000, n_jobs=-1 will be ignored. Current value: num_threads=10000
# [LightGBM] [Warning] Unknown parameter: objctive
# [LightGBM] [Warning] num_threads is set=10000, n_jobs=-1 will be ignored. Current value: num_threads=10000
# [LightGBM] [Info] Number of positive: 2389, number of negative: 2401
# [LightGBM] [Info] Total Bins 1825
# [LightGBM] [Info] Number of data points in the train set: 4790, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498747 -> initscore=-0.005010
# [LightGBM] [Info] Start training from score -0.005010

# %%
lgb_acc
# Out:
# 0.8956594323873122

# %%
from scipy.misc import derivative

def focal_loss(ytrue, ypred, gamma=2.0):   
    p = 1 / (1 + np.exp(-ypred))
    loss = -(1 - ytrue) * p**gamma * np.log(1 - p) - ytrue * (1 - p)**gamma * np.log(p)
    return loss


def focal_loss_metric(ytrue, ypred):
    return 'focal_loss_metric', np.mean(focal_loss(ytrue, ypred)), False


def focal_loss_objective(ytrue, ypred):
    func = lambda z: focal_loss(ytrue, z)
    grad = derivative(func, ypred, n=1, dx=1e-6)
    hess = derivative(func, ypred, n=2, dx=1e-6)
    return grad, hess

# %%
gbm_focal_loss = lgb.LGBMClassifier(objective=focal_loss_objective, learning_rate=0.25, n_estimators=16000, max_depth=1,boosting_type='gbdt',verbosity=1,metric='auc',num_threads = 100,force_row_wise=True)
gbm_focal_loss.fit(X_train, y_train, eval_set=[(X_test, y_test)], eval_metric=focal_loss_metric)
# Out:
# [LightGBM] [Warning] num_threads is set=100, n_jobs=-1 will be ignored. Current value: num_threads=100
# [LightGBM] [Warning] num_threads is set=100, n_jobs=-1 will be ignored. Current value: num_threads=100
# [LightGBM] [Warning] Using self-defined objective function
# [LightGBM] [Info] Total Bins 1825
# [LightGBM] [Info] Number of data points in the train set: 4790, number of used features: 11
# [LightGBM] [Warning] num_threads is set=100, n_jobs=-1 will be ignored. Current value: num_threads=100
# [LightGBM] [Warning] Using self-defined objective function
# [1]	valid_0's auc: 0.624735	valid_0's focal_loss_metric: 0.169657
# [2]	valid_0's auc: 0.626041	valid_0's focal_loss_metric: 0.1679
# [3]	valid_0's auc: 0.642174	valid_0's focal_loss_metric: 0.16647
# [4]	valid_0's auc: 0.662995	valid_0's focal_loss_metric: 0.165512
# [5]	valid_0's auc: 0.678515	valid_0's focal_loss_metric: 0.164234
# [6]	valid_0's auc: 0.68145	valid_0's focal_loss_metric: 0.163288
# [7]	valid_0's auc: 0.692601	valid_0's focal_loss_metric: 0.162106
# [8]	valid_0's auc: 0.698939	valid_0's focal_loss_metric: 0.161319
# [9]	valid_0's auc: 0.698539	valid_0's focal_loss_metric: 0.160766
# [10]	valid_0's auc: 0.701695	valid_0's focal_loss_metric: 0.160222
# [11]	valid_0's auc: 0.698634	valid_0's focal_loss_metric: 0.1601
# [12]	valid_0's auc: 0.7021	valid_0's focal_loss_metric: 0.159459
# [13]	valid_0's auc: 0.702691	valid_0's focal_loss_metric: 0.159138
# [14]	valid_0's auc: 0.702456	valid_0's focal_loss_metric: 0.158905
# [15]	valid_0's auc: 0.706624	valid_0's focal_loss_metric: 0.158505
# [16]	valid_0's auc: 0.71059	valid_0's focal_loss_metric: 0.15815
# [17]	valid_0's auc: 0.713979	valid_0's focal_loss_metric: 0.157657
# [18]	valid_0's auc: 0.716303	valid_0's focal_loss_metric: 0.157291
# [19]	valid_0's auc: 0.721025	valid_0's focal_loss_metric: 0.156925
# [20]	valid_0's auc: 0.720423	valid_0's focal_loss_metric: 0.156675
# [21]	valid_0's auc: 0.725306	valid_0's focal_loss_metric: 0.156333
# [22]	valid_0's auc: 0.724345	valid_0's focal_loss_metric: 0.156108
# [23]	valid_0's auc: 0.726349	valid_0's focal_loss_metric: 0.155777
# [24]	valid_0's auc: 0.730279	valid_0's focal_loss_metric: 0.155473
# [25]	valid_0's auc: 0.729398	valid_0's focal_loss_metric: 0.155261
# [26]	valid_0's auc: 0.729105	valid_0's focal_loss_metric: 0.15517
# [27]	valid_0's auc: 0.730668	valid_0's focal_loss_metric: 0.154889
# [28]	valid_0's auc: 0.734001	valid_0's focal_loss_metric: 0.154619
# [29]	valid_0's auc: 0.733254	valid_0's focal_loss_metric: 0.154421
# [30]	valid_0's auc: 0.735838	valid_0's focal_loss_metric: 0.154159
# [31]	valid_0's auc: 0.737605	valid_0's focal_loss_metric: 0.153867
# [32]	valid_0's auc: 0.738762	valid_0's focal_loss_metric: 0.153603
# [33]	valid_0's auc: 0.73989	valid_0's focal_loss_metric: 0.153484
# [34]	valid_0's auc: 0.74136	valid_0's focal_loss_metric: 0.153327
# [35]	valid_0's auc: 0.743004	valid_0's focal_loss_metric: 0.153099
# [36]	valid_0's auc: 0.74262	valid_0's focal_loss_metric: 0.152959
# [37]	valid_0's auc: 0.745273	valid_0's focal_loss_metric: 0.152665
# [38]	valid_0's auc: 0.744892	valid_0's focal_loss_metric: 0.152528
# [39]	valid_0's auc: 0.74706	valid_0's focal_loss_metric: 0.152264
# [40]	valid_0's auc: 0.748763	valid_0's focal_loss_metric: 0.152048
# [41]	valid_0's auc: 0.748161	valid_0's focal_loss_metric: 0.151918
# [42]	valid_0's auc: 0.750302	valid_0's focal_loss_metric: 0.151677
# [43]	valid_0's auc: 0.749532	valid_0's focal_loss_metric: 0.151555
# [44]	valid_0's auc: 0.749962	valid_0's focal_loss_metric: 0.151262
# [45]	valid_0's auc: 0.751202	valid_0's focal_loss_metric: 0.15102
# [46]	valid_0's auc: 0.751616	valid_0's focal_loss_metric: 0.150959
# [47]	valid_0's auc: 0.75309	valid_0's focal_loss_metric: 0.150764
# [48]	valid_0's auc: 0.754863	valid_0's focal_loss_metric: 0.150541
# [49]	valid_0's auc: 0.75427	valid_0's focal_loss_metric: 0.150428
# [50]	valid_0's auc: 0.755853	valid_0's focal_loss_metric: 0.150219
# [51]	valid_0's auc: 0.755284	valid_0's focal_loss_metric: 0.150116
# [52]	valid_0's auc: 0.755128	valid_0's focal_loss_metric: 0.150049
# [53]	valid_0's auc: 0.756402	valid_0's focal_loss_metric: 0.149858
# [54]	valid_0's auc: 0.756629	valid_0's focal_loss_metric: 0.149791
# [55]	valid_0's auc: 0.758013	valid_0's focal_loss_metric: 0.149537
# [56]	valid_0's auc: 0.759271	valid_0's focal_loss_metric: 0.149413
# [57]	valid_0's auc: 0.759313	valid_0's focal_loss_metric: 0.149371
# [58]	valid_0's auc: 0.759899	valid_0's focal_loss_metric: 0.149235
# [59]	valid_0's auc: 0.761487	valid_0's focal_loss_metric: 0.149135
# [60]	valid_0's auc: 0.761724	valid_0's focal_loss_metric: 0.148919
# [61]	valid_0's auc: 0.762717	valid_0's focal_loss_metric: 0.148776
# [62]	valid_0's auc: 0.764606	valid_0's focal_loss_metric: 0.148585
# [63]	valid_0's auc: 0.763756	valid_0's focal_loss_metric: 0.148489
# [64]	valid_0's auc: 0.765526	valid_0's focal_loss_metric: 0.148307
# [65]	valid_0's auc: 0.766422	valid_0's focal_loss_metric: 0.14809
# [66]	valid_0's auc: 0.767925	valid_0's focal_loss_metric: 0.147925
# [67]	valid_0's auc: 0.767049	valid_0's focal_loss_metric: 0.14783
# [68]	valid_0's auc: 0.767448	valid_0's focal_loss_metric: 0.147682
# [69]	valid_0's auc: 0.768925	valid_0's focal_loss_metric: 0.147528
# [70]	valid_0's auc: 0.767919	valid_0's focal_loss_metric: 0.147441
# [71]	valid_0's auc: 0.769508	valid_0's focal_loss_metric: 0.147289
# [72]	valid_0's auc: 0.770238	valid_0's focal_loss_metric: 0.147093
# [73]	valid_0's auc: 0.770447	valid_0's focal_loss_metric: 0.147061
# [74]	valid_0's auc: 0.772078	valid_0's focal_loss_metric: 0.14698
# [75]	valid_0's auc: 0.772716	valid_0's focal_loss_metric: 0.146756
# [76]	valid_0's auc: 0.773143	valid_0's focal_loss_metric: 0.146701
# [77]	valid_0's auc: 0.773895	valid_0's focal_loss_metric: 0.146594
# [78]	valid_0's auc: 0.774489	valid_0's focal_loss_metric: 0.146448
# [79]	valid_0's auc: 0.774163	valid_0's focal_loss_metric: 0.146393
# [80]	valid_0's auc: 0.773951	valid_0's focal_loss_metric: 0.14635
# [81]	valid_0's auc: 0.773704	valid_0's focal_loss_metric: 0.146338
# [82]	valid_0's auc: 0.775109	valid_0's focal_loss_metric: 0.146262
# [83]	valid_0's auc: 0.775191	valid_0's focal_loss_metric: 0.146143
# [84]	valid_0's auc: 0.774266	valid_0's focal_loss_metric: 0.146091
# [85]	valid_0's auc: 0.775955	valid_0's focal_loss_metric: 0.145914
# [86]	valid_0's auc: 0.775191	valid_0's focal_loss_metric: 0.145861
# [87]	valid_0's auc: 0.776624	valid_0's focal_loss_metric: 0.145701
# [88]	valid_0's auc: 0.777109	valid_0's focal_loss_metric: 0.145541
# [89]	valid_0's auc: 0.778288	valid_0's focal_loss_metric: 0.145399
# [90]	valid_0's auc: 0.777639	valid_0's focal_loss_metric: 0.14534
# [91]	valid_0's auc: 0.778734	valid_0's focal_loss_metric: 0.145204
# [92]	valid_0's auc: 0.779537	valid_0's focal_loss_metric: 0.145084
# [93]	valid_0's auc: 0.778809	valid_0's focal_loss_metric: 0.145032
# [94]	valid_0's auc: 0.778558	valid_0's focal_loss_metric: 0.144991
# [95]	valid_0's auc: 0.779512	valid_0's focal_loss_metric: 0.144806
# [96]	valid_0's auc: 0.77979	valid_0's focal_loss_metric: 0.144639
# [97]	valid_0's auc: 0.779499	valid_0's focal_loss_metric: 0.144611
# [98]	valid_0's auc: 0.780462	valid_0's focal_loss_metric: 0.144462
# [99]	valid_0's auc: 0.780621	valid_0's focal_loss_metric: 0.144401
# [100]	valid_0's auc: 0.781139	valid_0's focal_loss_metric: 0.144318
# [101]	valid_0's auc: 0.781608	valid_0's focal_loss_metric: 0.144198
# [102]	valid_0's auc: 0.782302	valid_0's focal_loss_metric: 0.144072
# [103]	valid_0's auc: 0.783478	valid_0's focal_loss_metric: 0.143947
# [104]	valid_0's auc: 0.783891	valid_0's focal_loss_metric: 0.143795
# [105]	valid_0's auc: 0.78447	valid_0's focal_loss_metric: 0.143728
# [106]	valid_0's auc: 0.78483	valid_0's focal_loss_metric: 0.143698
# [107]	valid_0's auc: 0.78512	valid_0's focal_loss_metric: 0.143602
# [108]	valid_0's auc: 0.786324	valid_0's focal_loss_metric: 0.143458
# [109]	valid_0's auc: 0.78631	valid_0's focal_loss_metric: 0.143407
# [110]	valid_0's auc: 0.787297	valid_0's focal_loss_metric: 0.143281
# [111]	valid_0's auc: 0.787896	valid_0's focal_loss_metric: 0.143115
# [112]	valid_0's auc: 0.78886	valid_0's focal_loss_metric: 0.142998
# [113]	valid_0's auc: 0.789465	valid_0's focal_loss_metric: 0.142846
# [114]	valid_0's auc: 0.789789	valid_0's focal_loss_metric: 0.142729
# [115]	valid_0's auc: 0.790906	valid_0's focal_loss_metric: 0.142671
# [116]	valid_0's auc: 0.790892	valid_0's focal_loss_metric: 0.142518
# [117]	valid_0's auc: 0.790196	valid_0's focal_loss_metric: 0.142483
# [118]	valid_0's auc: 0.791425	valid_0's focal_loss_metric: 0.142342
# [119]	valid_0's auc: 0.790681	valid_0's focal_loss_metric: 0.142305
# [120]	valid_0's auc: 0.791832	valid_0's focal_loss_metric: 0.142178
# [121]	valid_0's auc: 0.792094	valid_0's focal_loss_metric: 0.142094
# [122]	valid_0's auc: 0.792841	valid_0's focal_loss_metric: 0.141954
# [123]	valid_0's auc: 0.792768	valid_0's focal_loss_metric: 0.141828
# [124]	valid_0's auc: 0.794181	valid_0's focal_loss_metric: 0.141713
# [125]	valid_0's auc: 0.793094	valid_0's focal_loss_metric: 0.141671
# [126]	valid_0's auc: 0.794482	valid_0's focal_loss_metric: 0.141561
# [127]	valid_0's auc: 0.79342	valid_0's focal_loss_metric: 0.141523
# [128]	valid_0's auc: 0.793554	valid_0's focal_loss_metric: 0.141487
# [129]	valid_0's auc: 0.794443	valid_0's focal_loss_metric: 0.141442
# [130]	valid_0's auc: 0.795528	valid_0's focal_loss_metric: 0.141339
# [131]	valid_0's auc: 0.795486	valid_0's focal_loss_metric: 0.141254
# [132]	valid_0's auc: 0.795196	valid_0's focal_loss_metric: 0.141274
# [133]	valid_0's auc: 0.79574	valid_0's focal_loss_metric: 0.141188
# [134]	valid_0's auc: 0.795439	valid_0's focal_loss_metric: 0.141173
# [135]	valid_0's auc: 0.796222	valid_0's focal_loss_metric: 0.141077
# [136]	valid_0's auc: 0.796186	valid_0's focal_loss_metric: 0.140956
# [137]	valid_0's auc: 0.796824	valid_0's focal_loss_metric: 0.140809
# [138]	valid_0's auc: 0.796972	valid_0's focal_loss_metric: 0.140765
# [139]	valid_0's auc: 0.797172	valid_0's focal_loss_metric: 0.140695
# [140]	valid_0's auc: 0.796825	valid_0's focal_loss_metric: 0.140717
# [141]	valid_0's auc: 0.797879	valid_0's focal_loss_metric: 0.14061
# [142]	valid_0's auc: 0.797909	valid_0's focal_loss_metric: 0.14056
# [143]	valid_0's auc: 0.798489	valid_0's focal_loss_metric: 0.140459
# [144]	valid_0's auc: 0.799022	valid_0's focal_loss_metric: 0.140314
# [145]	valid_0's auc: 0.799504	valid_0's focal_loss_metric: 0.140222
# [146]	valid_0's auc: 0.799755	valid_0's focal_loss_metric: 0.140126
# [147]	valid_0's auc: 0.800521	valid_0's focal_loss_metric: 0.140033
# [148]	valid_0's auc: 0.799975	valid_0's focal_loss_metric: 0.139992
# [149]	valid_0's auc: 0.800767	valid_0's focal_loss_metric: 0.1399
# [150]	valid_0's auc: 0.800178	valid_0's focal_loss_metric: 0.139864
# [151]	valid_0's auc: 0.800909	valid_0's focal_loss_metric: 0.139773
# [152]	valid_0's auc: 0.801026	valid_0's focal_loss_metric: 0.139697
# [153]	valid_0's auc: 0.801455	valid_0's focal_loss_metric: 0.139607
# [154]	valid_0's auc: 0.801597	valid_0's focal_loss_metric: 0.139528
# [155]	valid_0's auc: 0.802428	valid_0's focal_loss_metric: 0.139438
# [156]	valid_0's auc: 0.801815	valid_0's focal_loss_metric: 0.139406
# [157]	valid_0's auc: 0.802609	valid_0's focal_loss_metric: 0.139319
# [158]	valid_0's auc: 0.803052	valid_0's focal_loss_metric: 0.139292
# [159]	valid_0's auc: 0.803091	valid_0's focal_loss_metric: 0.139254
# [160]	valid_0's auc: 0.80361	valid_0's focal_loss_metric: 0.139154
# [161]	valid_0's auc: 0.804393	valid_0's focal_loss_metric: 0.139014
# [162]	valid_0's auc: 0.804766	valid_0's focal_loss_metric: 0.138919
# [163]	valid_0's auc: 0.804945	valid_0's focal_loss_metric: 0.138886
# [164]	valid_0's auc: 0.804195	valid_0's focal_loss_metric: 0.138858
# [165]	valid_0's auc: 0.803366	valid_0's focal_loss_metric: 0.138865
# [166]	valid_0's auc: 0.804001	valid_0's focal_loss_metric: 0.138837
# [167]	valid_0's auc: 0.803775	valid_0's focal_loss_metric: 0.13875
# [168]	valid_0's auc: 0.80375	valid_0's focal_loss_metric: 0.138741
# [169]	valid_0's auc: 0.804063	valid_0's focal_loss_metric: 0.138698
# [170]	valid_0's auc: 0.804205	valid_0's focal_loss_metric: 0.138626
# [171]	valid_0's auc: 0.804662	valid_0's focal_loss_metric: 0.138595
# [172]	valid_0's auc: 0.805197	valid_0's focal_loss_metric: 0.138474
# [173]	valid_0's auc: 0.805874	valid_0's focal_loss_metric: 0.138373
# [174]	valid_0's auc: 0.806223	valid_0's focal_loss_metric: 0.138258
# [175]	valid_0's auc: 0.806671	valid_0's focal_loss_metric: 0.138229
# [176]	valid_0's auc: 0.806825	valid_0's focal_loss_metric: 0.138162
# [177]	valid_0's auc: 0.807257	valid_0's focal_loss_metric: 0.138139
# [178]	valid_0's auc: 0.807639	valid_0's focal_loss_metric: 0.138019
# [179]	valid_0's auc: 0.80828	valid_0's focal_loss_metric: 0.137931
# [180]	valid_0's auc: 0.80811	valid_0's focal_loss_metric: 0.137904
# [181]	valid_0's auc: 0.80886	valid_0's focal_loss_metric: 0.137784
# [182]	valid_0's auc: 0.809512	valid_0's focal_loss_metric: 0.137701
# [183]	valid_0's auc: 0.80986	valid_0's focal_loss_metric: 0.137586
# [184]	valid_0's auc: 0.810342	valid_0's focal_loss_metric: 0.137564
# [185]	valid_0's auc: 0.810958	valid_0's focal_loss_metric: 0.137483
# [186]	valid_0's auc: 0.811017	valid_0's focal_loss_metric: 0.137416
# [187]	valid_0's auc: 0.811413	valid_0's focal_loss_metric: 0.137335
# [188]	valid_0's auc: 0.81209	valid_0's focal_loss_metric: 0.137177
# [189]	valid_0's auc: 0.812469	valid_0's focal_loss_metric: 0.137066
# [190]	valid_0's auc: 0.812104	valid_0's focal_loss_metric: 0.13702
# [191]	valid_0's auc: 0.812636	valid_0's focal_loss_metric: 0.136999
# [192]	valid_0's auc: 0.81293	valid_0's focal_loss_metric: 0.136867
# [193]	valid_0's auc: 0.813413	valid_0's focal_loss_metric: 0.136836
# [194]	valid_0's auc: 0.813282	valid_0's focal_loss_metric: 0.136783
# [195]	valid_0's auc: 0.813998	valid_0's focal_loss_metric: 0.136684
# [196]	valid_0's auc: 0.813878	valid_0's focal_loss_metric: 0.136633
# [197]	valid_0's auc: 0.814358	valid_0's focal_loss_metric: 0.136549
# [198]	valid_0's auc: 0.814923	valid_0's focal_loss_metric: 0.136419
# [199]	valid_0's auc: 0.815545	valid_0's focal_loss_metric: 0.136357
# [200]	valid_0's auc: 0.815598	valid_0's focal_loss_metric: 0.136297
# [201]	valid_0's auc: 0.816169	valid_0's focal_loss_metric: 0.136216
# [202]	valid_0's auc: 0.815696	valid_0's focal_loss_metric: 0.136192
# [203]	valid_0's auc: 0.816245	valid_0's focal_loss_metric: 0.136113
# [204]	valid_0's auc: 0.81584	valid_0's focal_loss_metric: 0.136092
# [205]	valid_0's auc: 0.815735	valid_0's focal_loss_metric: 0.13609
# [206]	valid_0's auc: 0.815796	valid_0's focal_loss_metric: 0.136079
# [207]	valid_0's auc: 0.815768	valid_0's focal_loss_metric: 0.135978
# [208]	valid_0's auc: 0.815932	valid_0's focal_loss_metric: 0.135917
# [209]	valid_0's auc: 0.816267	valid_0's focal_loss_metric: 0.13583
# [210]	valid_0's auc: 0.816272	valid_0's focal_loss_metric: 0.135865
# [211]	valid_0's auc: 0.816022	valid_0's focal_loss_metric: 0.135872
# [212]	valid_0's auc: 0.816548	valid_0's focal_loss_metric: 0.135856
# [213]	valid_0's auc: 0.81666	valid_0's focal_loss_metric: 0.135791
# [214]	valid_0's auc: 0.817109	valid_0's focal_loss_metric: 0.13568
# [215]	valid_0's auc: 0.817421	valid_0's focal_loss_metric: 0.1356
# [216]	valid_0's auc: 0.817544	valid_0's focal_loss_metric: 0.135547
# [217]	valid_0's auc: 0.817925	valid_0's focal_loss_metric: 0.135473
# [218]	valid_0's auc: 0.817677	valid_0's focal_loss_metric: 0.135453
# [219]	valid_0's auc: 0.818065	valid_0's focal_loss_metric: 0.135379
# [220]	valid_0's auc: 0.818146	valid_0's focal_loss_metric: 0.135323
# [221]	valid_0's auc: 0.818686	valid_0's focal_loss_metric: 0.135262
# [222]	valid_0's auc: 0.81884	valid_0's focal_loss_metric: 0.135178
# [223]	valid_0's auc: 0.819283	valid_0's focal_loss_metric: 0.135104
# [224]	valid_0's auc: 0.818962	valid_0's focal_loss_metric: 0.135087
# [225]	valid_0's auc: 0.818986	valid_0's focal_loss_metric: 0.135018
# [226]	valid_0's auc: 0.819	valid_0's focal_loss_metric: 0.135007
# [227]	valid_0's auc: 0.818785	valid_0's focal_loss_metric: 0.13501
# [228]	valid_0's auc: 0.819418	valid_0's focal_loss_metric: 0.134995
# [229]	valid_0's auc: 0.81951	valid_0's focal_loss_metric: 0.134955
# [230]	valid_0's auc: 0.819705	valid_0's focal_loss_metric: 0.1349
# [231]	valid_0's auc: 0.820165	valid_0's focal_loss_metric: 0.134816
# [232]	valid_0's auc: 0.820435	valid_0's focal_loss_metric: 0.134749
# [233]	valid_0's auc: 0.820368	valid_0's focal_loss_metric: 0.134699
# [234]	valid_0's auc: 0.821102	valid_0's focal_loss_metric: 0.134644
# [235]	valid_0's auc: 0.820906	valid_0's focal_loss_metric: 0.134593
# [236]	valid_0's auc: 0.821486	valid_0's focal_loss_metric: 0.134521
# [237]	valid_0's auc: 0.820996	valid_0's focal_loss_metric: 0.134506
# [238]	valid_0's auc: 0.821539	valid_0's focal_loss_metric: 0.134437
# [239]	valid_0's auc: 0.821475	valid_0's focal_loss_metric: 0.134389
# [240]	valid_0's auc: 0.822242	valid_0's focal_loss_metric: 0.134334
# [241]	valid_0's auc: 0.822122	valid_0's focal_loss_metric: 0.134287
# [242]	valid_0's auc: 0.822752	valid_0's focal_loss_metric: 0.134234
# [243]	valid_0's auc: 0.823089	valid_0's focal_loss_metric: 0.134165
# [244]	valid_0's auc: 0.82303	valid_0's focal_loss_metric: 0.134141
# [245]	valid_0's auc: 0.823348	valid_0's focal_loss_metric: 0.134039
# [246]	valid_0's auc: 0.823702	valid_0's focal_loss_metric: 0.133971
# [247]	valid_0's auc: 0.823596	valid_0's focal_loss_metric: 0.133925
# [248]	valid_0's auc: 0.823529	valid_0's focal_loss_metric: 0.133922
# [249]	valid_0's auc: 0.823574	valid_0's focal_loss_metric: 0.133869
# [250]	valid_0's auc: 0.824056	valid_0's focal_loss_metric: 0.133795
# [251]	valid_0's auc: 0.823755	valid_0's focal_loss_metric: 0.133792
# [252]	valid_0's auc: 0.823797	valid_0's focal_loss_metric: 0.133739
# [253]	valid_0's auc: 0.824287	valid_0's focal_loss_metric: 0.133673
# [254]	valid_0's auc: 0.824558	valid_0's focal_loss_metric: 0.133561
# [255]	valid_0's auc: 0.825004	valid_0's focal_loss_metric: 0.133544
# [256]	valid_0's auc: 0.825277	valid_0's focal_loss_metric: 0.13344
# [257]	valid_0's auc: 0.825628	valid_0's focal_loss_metric: 0.133425
# [258]	valid_0's auc: 0.825609	valid_0's focal_loss_metric: 0.133372
# [259]	valid_0's auc: 0.825667	valid_0's focal_loss_metric: 0.133345
# [260]	valid_0's auc: 0.826367	valid_0's focal_loss_metric: 0.133232
# [261]	valid_0's auc: 0.82637	valid_0's focal_loss_metric: 0.133221
# [262]	valid_0's auc: 0.826869	valid_0's focal_loss_metric: 0.133126
# [263]	valid_0's auc: 0.826445	valid_0's focal_loss_metric: 0.133137
# [264]	valid_0's auc: 0.82676	valid_0's focal_loss_metric: 0.133108
# [265]	valid_0's auc: 0.827089	valid_0's focal_loss_metric: 0.133044
# [266]	valid_0's auc: 0.826961	valid_0's focal_loss_metric: 0.133026
# [267]	valid_0's auc: 0.827666	valid_0's focal_loss_metric: 0.132933
# [268]	valid_0's auc: 0.828112	valid_0's focal_loss_metric: 0.132838
# [269]	valid_0's auc: 0.828287	valid_0's focal_loss_metric: 0.132821
# [270]	valid_0's auc: 0.828148	valid_0's focal_loss_metric: 0.132808
# [271]	valid_0's auc: 0.828502	valid_0's focal_loss_metric: 0.132739
# [272]	valid_0's auc: 0.828842	valid_0's focal_loss_metric: 0.132642
# [273]	valid_0's auc: 0.829101	valid_0's focal_loss_metric: 0.13263
# [274]	valid_0's auc: 0.829352	valid_0's focal_loss_metric: 0.132539
# [275]	valid_0's auc: 0.829701	valid_0's focal_loss_metric: 0.132471
# [276]	valid_0's auc: 0.829285	valid_0's focal_loss_metric: 0.132507
# [277]	valid_0's auc: 0.829648	valid_0's focal_loss_metric: 0.132446
# [278]	valid_0's auc: 0.829564	valid_0's focal_loss_metric: 0.132407
# [279]	valid_0's auc: 0.829901	valid_0's focal_loss_metric: 0.132345
# [280]	valid_0's auc: 0.829943	valid_0's focal_loss_metric: 0.132301
# [281]	valid_0's auc: 0.830152	valid_0's focal_loss_metric: 0.132288
# [282]	valid_0's auc: 0.830551	valid_0's focal_loss_metric: 0.132201
# [283]	valid_0's auc: 0.831178	valid_0's focal_loss_metric: 0.132109
# [284]	valid_0's auc: 0.831142	valid_0's focal_loss_metric: 0.132098
# [285]	valid_0's auc: 0.831401	valid_0's focal_loss_metric: 0.132031
# [286]	valid_0's auc: 0.831303	valid_0's focal_loss_metric: 0.132023
# [287]	valid_0's auc: 0.831905	valid_0's focal_loss_metric: 0.131931
# [288]	valid_0's auc: 0.83173	valid_0's focal_loss_metric: 0.131939
# [289]	valid_0's auc: 0.83227	valid_0's focal_loss_metric: 0.131855
# [290]	valid_0's auc: 0.832187	valid_0's focal_loss_metric: 0.131846
# [291]	valid_0's auc: 0.831774	valid_0's focal_loss_metric: 0.131897
# [292]	valid_0's auc: 0.832413	valid_0's focal_loss_metric: 0.131793
# [293]	valid_0's auc: 0.832477	valid_0's focal_loss_metric: 0.131767
# [294]	valid_0's auc: 0.832374	valid_0's focal_loss_metric: 0.13172
# [295]	valid_0's auc: 0.832315	valid_0's focal_loss_metric: 0.131699
# [296]	valid_0's auc: 0.831877	valid_0's focal_loss_metric: 0.131692
# [297]	valid_0's auc: 0.832519	valid_0's focal_loss_metric: 0.131617
# [298]	valid_0's auc: 0.832351	valid_0's focal_loss_metric: 0.131579
# [299]	valid_0's auc: 0.833001	valid_0's focal_loss_metric: 0.131525
# [300]	valid_0's auc: 0.832772	valid_0's focal_loss_metric: 0.131485
# [301]	valid_0's auc: 0.833402	valid_0's focal_loss_metric: 0.131418
# [302]	valid_0's auc: 0.832872	valid_0's focal_loss_metric: 0.131408
# [303]	valid_0's auc: 0.833519	valid_0's focal_loss_metric: 0.13136
# [304]	valid_0's auc: 0.833349	valid_0's focal_loss_metric: 0.131319
# [305]	valid_0's auc: 0.833915	valid_0's focal_loss_metric: 0.131254
# [306]	valid_0's auc: 0.833469	valid_0's focal_loss_metric: 0.131244
# [307]	valid_0's auc: 0.833999	valid_0's focal_loss_metric: 0.131182
# [308]	valid_0's auc: 0.833968	valid_0's focal_loss_metric: 0.131145
# [309]	valid_0's auc: 0.834422	valid_0's focal_loss_metric: 0.131099
# [310]	valid_0's auc: 0.834339	valid_0's focal_loss_metric: 0.13106
# [311]	valid_0's auc: 0.834668	valid_0's focal_loss_metric: 0.131048
# [312]	valid_0's auc: 0.835175	valid_0's focal_loss_metric: 0.130948
# [313]	valid_0's auc: 0.835665	valid_0's focal_loss_metric: 0.130888
# [314]	valid_0's auc: 0.83571	valid_0's focal_loss_metric: 0.130884
# [315]	valid_0's auc: 0.835635	valid_0's focal_loss_metric: 0.130926
# [316]	valid_0's auc: 0.835373	valid_0's focal_loss_metric: 0.130931
# [317]	valid_0's auc: 0.83547	valid_0's focal_loss_metric: 0.130875
# [318]	valid_0's auc: 0.835955	valid_0's focal_loss_metric: 0.130787
# [319]	valid_0's auc: 0.835969	valid_0's focal_loss_metric: 0.130778
# [320]	valid_0's auc: 0.836373	valid_0's focal_loss_metric: 0.130695
# [321]	valid_0's auc: 0.836376	valid_0's focal_loss_metric: 0.130687
# [322]	valid_0's auc: 0.836541	valid_0's focal_loss_metric: 0.130642
# [323]	valid_0's auc: 0.836543	valid_0's focal_loss_metric: 0.130623
# [324]	valid_0's auc: 0.836789	valid_0's focal_loss_metric: 0.130541
# [325]	valid_0's auc: 0.837134	valid_0's focal_loss_metric: 0.130473
# [326]	valid_0's auc: 0.836836	valid_0's focal_loss_metric: 0.130508
# [327]	valid_0's auc: 0.836768	valid_0's focal_loss_metric: 0.130545
# [328]	valid_0's auc: 0.836818	valid_0's focal_loss_metric: 0.130477
# [329]	valid_0's auc: 0.837122	valid_0's focal_loss_metric: 0.130472
# [330]	valid_0's auc: 0.837256	valid_0's focal_loss_metric: 0.13037
# [331]	valid_0's auc: 0.837359	valid_0's focal_loss_metric: 0.130388
# [332]	valid_0's auc: 0.837434	valid_0's focal_loss_metric: 0.130384
# [333]	valid_0's auc: 0.837292	valid_0's focal_loss_metric: 0.130356
# [334]	valid_0's auc: 0.837526	valid_0's focal_loss_metric: 0.130297
# [335]	valid_0's auc: 0.837735	valid_0's focal_loss_metric: 0.130214
# [336]	valid_0's auc: 0.837702	valid_0's focal_loss_metric: 0.130216
# [337]	valid_0's auc: 0.837711	valid_0's focal_loss_metric: 0.130137
# [338]	valid_0's auc: 0.83738	valid_0's focal_loss_metric: 0.130134
# [339]	valid_0's auc: 0.837831	valid_0's focal_loss_metric: 0.130066
# [340]	valid_0's auc: 0.837951	valid_0's focal_loss_metric: 0.130009
# [341]	valid_0's auc: 0.838447	valid_0's focal_loss_metric: 0.129962
# [342]	valid_0's auc: 0.838338	valid_0's focal_loss_metric: 0.129928
# [343]	valid_0's auc: 0.838701	valid_0's focal_loss_metric: 0.129868
# [344]	valid_0's auc: 0.838411	valid_0's focal_loss_metric: 0.129862
# [345]	valid_0's auc: 0.838846	valid_0's focal_loss_metric: 0.129818
# [346]	valid_0's auc: 0.838776	valid_0's focal_loss_metric: 0.129785
# [347]	valid_0's auc: 0.839113	valid_0's focal_loss_metric: 0.129726
# [348]	valid_0's auc: 0.839069	valid_0's focal_loss_metric: 0.129715
# [349]	valid_0's auc: 0.839334	valid_0's focal_loss_metric: 0.129659
# [350]	valid_0's auc: 0.839105	valid_0's focal_loss_metric: 0.129653
# [351]	valid_0's auc: 0.839481	valid_0's focal_loss_metric: 0.129613
# [352]	valid_0's auc: 0.83932	valid_0's focal_loss_metric: 0.129584
# [353]	valid_0's auc: 0.839072	valid_0's focal_loss_metric: 0.1296
# [354]	valid_0's auc: 0.839116	valid_0's focal_loss_metric: 0.129556
# [355]	valid_0's auc: 0.839434	valid_0's focal_loss_metric: 0.129502
# [356]	valid_0's auc: 0.839392	valid_0's focal_loss_metric: 0.129495
# [357]	valid_0's auc: 0.839623	valid_0's focal_loss_metric: 0.129443
# [358]	valid_0's auc: 0.839894	valid_0's focal_loss_metric: 0.129363
# [359]	valid_0's auc: 0.840019	valid_0's focal_loss_metric: 0.129319
# [360]	valid_0's auc: 0.839885	valid_0's focal_loss_metric: 0.129262
# [361]	valid_0's auc: 0.840021	valid_0's focal_loss_metric: 0.129264
# [362]	valid_0's auc: 0.840527	valid_0's focal_loss_metric: 0.129198
# [363]	valid_0's auc: 0.840175	valid_0's focal_loss_metric: 0.12921
# [364]	valid_0's auc: 0.840858	valid_0's focal_loss_metric: 0.129128
# [365]	valid_0's auc: 0.840683	valid_0's focal_loss_metric: 0.129122
# [366]	valid_0's auc: 0.841031	valid_0's focal_loss_metric: 0.129065
# [367]	valid_0's auc: 0.841154	valid_0's focal_loss_metric: 0.128988
# [368]	valid_0's auc: 0.841497	valid_0's focal_loss_metric: 0.128955
# [369]	valid_0's auc: 0.841463	valid_0's focal_loss_metric: 0.128915
# [370]	valid_0's auc: 0.841862	valid_0's focal_loss_metric: 0.128883
# [371]	valid_0's auc: 0.841747	valid_0's focal_loss_metric: 0.128846
# [372]	valid_0's auc: 0.842157	valid_0's focal_loss_metric: 0.128816
# [373]	valid_0's auc: 0.842171	valid_0's focal_loss_metric: 0.128743
# [374]	valid_0's auc: 0.842684	valid_0's focal_loss_metric: 0.128688
# [375]	valid_0's auc: 0.842257	valid_0's focal_loss_metric: 0.128684
# [376]	valid_0's auc: 0.843069	valid_0's focal_loss_metric: 0.128602
# [377]	valid_0's auc: 0.84265	valid_0's focal_loss_metric: 0.128615
# [378]	valid_0's auc: 0.843358	valid_0's focal_loss_metric: 0.12854
# [379]	valid_0's auc: 0.842977	valid_0's focal_loss_metric: 0.128535
# [380]	valid_0's auc: 0.843693	valid_0's focal_loss_metric: 0.128463
# [381]	valid_0's auc: 0.84328	valid_0's focal_loss_metric: 0.128477
# [382]	valid_0's auc: 0.84359	valid_0's focal_loss_metric: 0.128472
# [383]	valid_0's auc: 0.843593	valid_0's focal_loss_metric: 0.128433
# [384]	valid_0's auc: 0.843846	valid_0's focal_loss_metric: 0.128381
# [385]	valid_0's auc: 0.84386	valid_0's focal_loss_metric: 0.128342
# [386]	valid_0's auc: 0.844	valid_0's focal_loss_metric: 0.128328
# [387]	valid_0's auc: 0.844002	valid_0's focal_loss_metric: 0.128291
# [388]	valid_0's auc: 0.844103	valid_0's focal_loss_metric: 0.128278
# [389]	valid_0's auc: 0.844111	valid_0's focal_loss_metric: 0.128263
# [390]	valid_0's auc: 0.844111	valid_0's focal_loss_metric: 0.128227
# [391]	valid_0's auc: 0.844429	valid_0's focal_loss_metric: 0.128176
# [392]	valid_0's auc: 0.844571	valid_0's focal_loss_metric: 0.128178
# [393]	valid_0's auc: 0.844663	valid_0's focal_loss_metric: 0.12809
# [394]	valid_0's auc: 0.84466	valid_0's focal_loss_metric: 0.128087
# [395]	valid_0's auc: 0.844936	valid_0's focal_loss_metric: 0.128063
# [396]	valid_0's auc: 0.845131	valid_0's focal_loss_metric: 0.127986
# [397]	valid_0's auc: 0.845396	valid_0's focal_loss_metric: 0.127935
# [398]	valid_0's auc: 0.84563	valid_0's focal_loss_metric: 0.127865
# [399]	valid_0's auc: 0.84573	valid_0's focal_loss_metric: 0.127859
# [400]	valid_0's auc: 0.845666	valid_0's focal_loss_metric: 0.127825
# [401]	valid_0's auc: 0.845951	valid_0's focal_loss_metric: 0.1278
# [402]	valid_0's auc: 0.845666	valid_0's focal_loss_metric: 0.127798
# [403]	valid_0's auc: 0.846319	valid_0's focal_loss_metric: 0.127723
# [404]	valid_0's auc: 0.846224	valid_0's focal_loss_metric: 0.127693
# [405]	valid_0's auc: 0.846603	valid_0's focal_loss_metric: 0.127668
# [406]	valid_0's auc: 0.84677	valid_0's focal_loss_metric: 0.127601
# [407]	valid_0's auc: 0.847107	valid_0's focal_loss_metric: 0.12755
# [408]	valid_0's auc: 0.846765	valid_0's focal_loss_metric: 0.127548
# [409]	valid_0's auc: 0.847294	valid_0's focal_loss_metric: 0.127484
# [410]	valid_0's auc: 0.846873	valid_0's focal_loss_metric: 0.127522
# [411]	valid_0's auc: 0.846425	valid_0's focal_loss_metric: 0.127573
# [412]	valid_0's auc: 0.847002	valid_0's focal_loss_metric: 0.12748
# [413]	valid_0's auc: 0.846971	valid_0's focal_loss_metric: 0.127465
# [414]	valid_0's auc: 0.84735	valid_0's focal_loss_metric: 0.127408
# [415]	valid_0's auc: 0.847264	valid_0's focal_loss_metric: 0.127396
# [416]	valid_0's auc: 0.847818	valid_0's focal_loss_metric: 0.127308
# [417]	valid_0's auc: 0.848105	valid_0's focal_loss_metric: 0.127304
# [418]	valid_0's auc: 0.848195	valid_0's focal_loss_metric: 0.127238
# [419]	valid_0's auc: 0.848565	valid_0's focal_loss_metric: 0.127188
# [420]	valid_0's auc: 0.84854	valid_0's focal_loss_metric: 0.127126
# [421]	valid_0's auc: 0.848902	valid_0's focal_loss_metric: 0.127122
# [422]	valid_0's auc: 0.848738	valid_0's focal_loss_metric: 0.127093
# [423]	valid_0's auc: 0.848691	valid_0's focal_loss_metric: 0.127082
# [424]	valid_0's auc: 0.848981	valid_0's focal_loss_metric: 0.127027
# [425]	valid_0's auc: 0.849374	valid_0's focal_loss_metric: 0.127004
# [426]	valid_0's auc: 0.849689	valid_0's focal_loss_metric: 0.126959
# [427]	valid_0's auc: 0.849471	valid_0's focal_loss_metric: 0.126946
# [428]	valid_0's auc: 0.8499	valid_0's focal_loss_metric: 0.126912
# [429]	valid_0's auc: 0.849683	valid_0's focal_loss_metric: 0.126878
# [430]	valid_0's auc: 0.850054	valid_0's focal_loss_metric: 0.126828
# [431]	valid_0's auc: 0.849728	valid_0's focal_loss_metric: 0.126823
# [432]	valid_0's auc: 0.850112	valid_0's focal_loss_metric: 0.126774
# [433]	valid_0's auc: 0.849903	valid_0's focal_loss_metric: 0.126744
# [434]	valid_0's auc: 0.85041	valid_0's focal_loss_metric: 0.126708
# [435]	valid_0's auc: 0.850179	valid_0's focal_loss_metric: 0.126678
# [436]	valid_0's auc: 0.850659	valid_0's focal_loss_metric: 0.126642
# [437]	valid_0's auc: 0.850416	valid_0's focal_loss_metric: 0.126614
# [438]	valid_0's auc: 0.850781	valid_0's focal_loss_metric: 0.126565
# [439]	valid_0's auc: 0.850472	valid_0's focal_loss_metric: 0.126561
# [440]	valid_0's auc: 0.850826	valid_0's focal_loss_metric: 0.126513
# [441]	valid_0's auc: 0.850505	valid_0's focal_loss_metric: 0.12651
# [442]	valid_0's auc: 0.850837	valid_0's focal_loss_metric: 0.126463
# [443]	valid_0's auc: 0.850628	valid_0's focal_loss_metric: 0.126455
# [444]	valid_0's auc: 0.851077	valid_0's focal_loss_metric: 0.126422
# [445]	valid_0's auc: 0.850856	valid_0's focal_loss_metric: 0.126401
# [446]	valid_0's auc: 0.85116	valid_0's focal_loss_metric: 0.126348
# [447]	valid_0's auc: 0.85121	valid_0's focal_loss_metric: 0.126284
# [448]	valid_0's auc: 0.851369	valid_0's focal_loss_metric: 0.126241
# [449]	valid_0's auc: 0.851252	valid_0's focal_loss_metric: 0.126241
# [450]	valid_0's auc: 0.851776	valid_0's focal_loss_metric: 0.126169
# [451]	valid_0's auc: 0.8515	valid_0's focal_loss_metric: 0.126185
# [452]	valid_0's auc: 0.851935	valid_0's focal_loss_metric: 0.126119
# [453]	valid_0's auc: 0.851609	valid_0's focal_loss_metric: 0.126155
# [454]	valid_0's auc: 0.85162	valid_0's focal_loss_metric: 0.126115
# [455]	valid_0's auc: 0.851709	valid_0's focal_loss_metric: 0.126116
# [456]	valid_0's auc: 0.851988	valid_0's focal_loss_metric: 0.12607
# [457]	valid_0's auc: 0.851963	valid_0's focal_loss_metric: 0.126035
# [458]	valid_0's auc: 0.852066	valid_0's focal_loss_metric: 0.126024
# [459]	valid_0's auc: 0.852002	valid_0's focal_loss_metric: 0.125991
# [460]	valid_0's auc: 0.852133	valid_0's focal_loss_metric: 0.12598
# [461]	valid_0's auc: 0.851966	valid_0's focal_loss_metric: 0.125956
# [462]	valid_0's auc: 0.852225	valid_0's focal_loss_metric: 0.125904
# [463]	valid_0's auc: 0.851996	valid_0's focal_loss_metric: 0.125887
# [464]	valid_0's auc: 0.852445	valid_0's focal_loss_metric: 0.12585
# [465]	valid_0's auc: 0.852364	valid_0's focal_loss_metric: 0.125818
# [466]	valid_0's auc: 0.852704	valid_0's focal_loss_metric: 0.125773
# [467]	valid_0's auc: 0.852671	valid_0's focal_loss_metric: 0.125775
# [468]	valid_0's auc: 0.852532	valid_0's focal_loss_metric: 0.125778
# [469]	valid_0's auc: 0.852345	valid_0's focal_loss_metric: 0.125754
# [470]	valid_0's auc: 0.852746	valid_0's focal_loss_metric: 0.12572
# [471]	valid_0's auc: 0.85252	valid_0's focal_loss_metric: 0.125696
# [472]	valid_0's auc: 0.852916	valid_0's focal_loss_metric: 0.125649
# [473]	valid_0's auc: 0.852557	valid_0's focal_loss_metric: 0.125647
# [474]	valid_0's auc: 0.852972	valid_0's focal_loss_metric: 0.125602
# [475]	valid_0's auc: 0.852593	valid_0's focal_loss_metric: 0.1256
# [476]	valid_0's auc: 0.853005	valid_0's focal_loss_metric: 0.125556
# [477]	valid_0's auc: 0.852833	valid_0's focal_loss_metric: 0.125532
# [478]	valid_0's auc: 0.853265	valid_0's focal_loss_metric: 0.1255
# [479]	valid_0's auc: 0.853577	valid_0's focal_loss_metric: 0.125441
# [480]	valid_0's auc: 0.853608	valid_0's focal_loss_metric: 0.125477
# [481]	valid_0's auc: 0.853566	valid_0's focal_loss_metric: 0.12543
# [482]	valid_0's auc: 0.853541	valid_0's focal_loss_metric: 0.125429
# [483]	valid_0's auc: 0.853365	valid_0's focal_loss_metric: 0.125426
# [484]	valid_0's auc: 0.853248	valid_0's focal_loss_metric: 0.125403
# [485]	valid_0's auc: 0.85356	valid_0's focal_loss_metric: 0.125379
# [486]	valid_0's auc: 0.853571	valid_0's focal_loss_metric: 0.125337
# [487]	valid_0's auc: 0.853761	valid_0's focal_loss_metric: 0.125334
# [488]	valid_0's auc: 0.8539	valid_0's focal_loss_metric: 0.125274
# [489]	valid_0's auc: 0.854196	valid_0's focal_loss_metric: 0.125227
# [490]	valid_0's auc: 0.854012	valid_0's focal_loss_metric: 0.125228
# [491]	valid_0's auc: 0.854575	valid_0's focal_loss_metric: 0.125163
# [492]	valid_0's auc: 0.854229	valid_0's focal_loss_metric: 0.125179
# [493]	valid_0's auc: 0.85412	valid_0's focal_loss_metric: 0.125218
# [494]	valid_0's auc: 0.853939	valid_0's focal_loss_metric: 0.125194
# [495]	valid_0's auc: 0.854315	valid_0's focal_loss_metric: 0.125164
# [496]	valid_0's auc: 0.854143	valid_0's focal_loss_metric: 0.125148
# [497]	valid_0's auc: 0.854374	valid_0's focal_loss_metric: 0.125102
# [498]	valid_0's auc: 0.854212	valid_0's focal_loss_metric: 0.125067
# [499]	valid_0's auc: 0.854463	valid_0's focal_loss_metric: 0.125069
# [500]	valid_0's auc: 0.854533	valid_0's focal_loss_metric: 0.125012
# [501]	valid_0's auc: 0.854472	valid_0's focal_loss_metric: 0.125016
# [502]	valid_0's auc: 0.854996	valid_0's focal_loss_metric: 0.124954
# [503]	valid_0's auc: 0.854753	valid_0's focal_loss_metric: 0.124956
# [504]	valid_0's auc: 0.855032	valid_0's focal_loss_metric: 0.124912
# [505]	valid_0's auc: 0.855182	valid_0's focal_loss_metric: 0.124852
# [506]	valid_0's auc: 0.855113	valid_0's focal_loss_metric: 0.124845
# [507]	valid_0's auc: 0.855612	valid_0's focal_loss_metric: 0.124767
# [508]	valid_0's auc: 0.855698	valid_0's focal_loss_metric: 0.124764
# [509]	valid_0's auc: 0.855868	valid_0's focal_loss_metric: 0.124721
# [510]	valid_0's auc: 0.85601	valid_0's focal_loss_metric: 0.1247
# [511]	valid_0's auc: 0.856164	valid_0's focal_loss_metric: 0.124659
# [512]	valid_0's auc: 0.856205	valid_0's focal_loss_metric: 0.124656
# [513]	valid_0's auc: 0.856339	valid_0's focal_loss_metric: 0.124617
# [514]	valid_0's auc: 0.856492	valid_0's focal_loss_metric: 0.124595
# [515]	valid_0's auc: 0.856498	valid_0's focal_loss_metric: 0.124571
# [516]	valid_0's auc: 0.856055	valid_0's focal_loss_metric: 0.124622
# [517]	valid_0's auc: 0.85586	valid_0's focal_loss_metric: 0.124625
# [518]	valid_0's auc: 0.855821	valid_0's focal_loss_metric: 0.124617
# [519]	valid_0's auc: 0.855747	valid_0's focal_loss_metric: 0.124595
# [520]	valid_0's auc: 0.855934	valid_0's focal_loss_metric: 0.124529
# [521]	valid_0's auc: 0.855925	valid_0's focal_loss_metric: 0.12454
# [522]	valid_0's auc: 0.856237	valid_0's focal_loss_metric: 0.124474
# [523]	valid_0's auc: 0.85624	valid_0's focal_loss_metric: 0.124433
# [524]	valid_0's auc: 0.856254	valid_0's focal_loss_metric: 0.12444
# [525]	valid_0's auc: 0.856173	valid_0's focal_loss_metric: 0.124464
# [526]	valid_0's auc: 0.855981	valid_0's focal_loss_metric: 0.124458
# [527]	valid_0's auc: 0.855872	valid_0's focal_loss_metric: 0.124439
# [528]	valid_0's auc: 0.856274	valid_0's focal_loss_metric: 0.124394
# [529]	valid_0's auc: 0.855895	valid_0's focal_loss_metric: 0.124394
# [530]	valid_0's auc: 0.856293	valid_0's focal_loss_metric: 0.12435
# [531]	valid_0's auc: 0.855906	valid_0's focal_loss_metric: 0.12435
# [532]	valid_0's auc: 0.85631	valid_0's focal_loss_metric: 0.124308
# [533]	valid_0's auc: 0.856081	valid_0's focal_loss_metric: 0.124304
# [534]	valid_0's auc: 0.85641	valid_0's focal_loss_metric: 0.124263
# [535]	valid_0's auc: 0.856101	valid_0's focal_loss_metric: 0.124263
# [536]	valid_0's auc: 0.856427	valid_0's focal_loss_metric: 0.124223
# [537]	valid_0's auc: 0.856321	valid_0's focal_loss_metric: 0.124204
# [538]	valid_0's auc: 0.856711	valid_0's focal_loss_metric: 0.124175
# [539]	valid_0's auc: 0.856511	valid_0's focal_loss_metric: 0.124155
# [540]	valid_0's auc: 0.856396	valid_0's focal_loss_metric: 0.124167
# [541]	valid_0's auc: 0.856736	valid_0's focal_loss_metric: 0.124101
# [542]	valid_0's auc: 0.856959	valid_0's focal_loss_metric: 0.124085
# [543]	valid_0's auc: 0.856773	valid_0's focal_loss_metric: 0.124069
# [544]	valid_0's auc: 0.857191	valid_0's focal_loss_metric: 0.12404
# [545]	valid_0's auc: 0.856929	valid_0's focal_loss_metric: 0.124021
# [546]	valid_0's auc: 0.857288	valid_0's focal_loss_metric: 0.123981
# [547]	valid_0's auc: 0.857274	valid_0's focal_loss_metric: 0.123986
# [548]	valid_0's auc: 0.857425	valid_0's focal_loss_metric: 0.123984
# [549]	valid_0's auc: 0.857455	valid_0's focal_loss_metric: 0.123925
# [550]	valid_0's auc: 0.857731	valid_0's focal_loss_metric: 0.123885
# [551]	valid_0's auc: 0.857444	valid_0's focal_loss_metric: 0.123888
# [552]	valid_0's auc: 0.857904	valid_0's focal_loss_metric: 0.123826
# [553]	valid_0's auc: 0.857745	valid_0's focal_loss_metric: 0.123831
# [554]	valid_0's auc: 0.857924	valid_0's focal_loss_metric: 0.123791
# [555]	valid_0's auc: 0.857943	valid_0's focal_loss_metric: 0.123753
# [556]	valid_0's auc: 0.858214	valid_0's focal_loss_metric: 0.123732
# [557]	valid_0's auc: 0.85842	valid_0's focal_loss_metric: 0.123684
# [558]	valid_0's auc: 0.858386	valid_0's focal_loss_metric: 0.123678
# [559]	valid_0's auc: 0.858807	valid_0's focal_loss_metric: 0.123604
# [560]	valid_0's auc: 0.858771	valid_0's focal_loss_metric: 0.123599
# [561]	valid_0's auc: 0.858899	valid_0's focal_loss_metric: 0.12355
# [562]	valid_0's auc: 0.858958	valid_0's focal_loss_metric: 0.123553
# [563]	valid_0's auc: 0.858869	valid_0's focal_loss_metric: 0.123529
# [564]	valid_0's auc: 0.858883	valid_0's focal_loss_metric: 0.123508
# [565]	valid_0's auc: 0.859136	valid_0's focal_loss_metric: 0.123488
# [566]	valid_0's auc: 0.859133	valid_0's focal_loss_metric: 0.12345
# [567]	valid_0's auc: 0.859267	valid_0's focal_loss_metric: 0.123447
# [568]	valid_0's auc: 0.859306	valid_0's focal_loss_metric: 0.123391
# [569]	valid_0's auc: 0.859769	valid_0's focal_loss_metric: 0.123332
# [570]	valid_0's auc: 0.859409	valid_0's focal_loss_metric: 0.123349
# [571]	valid_0's auc: 0.859696	valid_0's focal_loss_metric: 0.123295
# [572]	valid_0's auc: 0.859407	valid_0's focal_loss_metric: 0.123328
# [573]	valid_0's auc: 0.859479	valid_0's focal_loss_metric: 0.123266
# [574]	valid_0's auc: 0.85971	valid_0's focal_loss_metric: 0.123256
# [575]	valid_0's auc: 0.859889	valid_0's focal_loss_metric: 0.123195
# [576]	valid_0's auc: 0.859883	valid_0's focal_loss_metric: 0.123224
# [577]	valid_0's auc: 0.860067	valid_0's focal_loss_metric: 0.123222
# [578]	valid_0's auc: 0.859992	valid_0's focal_loss_metric: 0.123183
# [579]	valid_0's auc: 0.86031	valid_0's focal_loss_metric: 0.123165
# [580]	valid_0's auc: 0.86024	valid_0's focal_loss_metric: 0.123127
# [581]	valid_0's auc: 0.860368	valid_0's focal_loss_metric: 0.123125
# [582]	valid_0's auc: 0.860441	valid_0's focal_loss_metric: 0.123071
# [583]	valid_0's auc: 0.860678	valid_0's focal_loss_metric: 0.123034
# [584]	valid_0's auc: 0.860463	valid_0's focal_loss_metric: 0.123039
# [585]	valid_0's auc: 0.860976	valid_0's focal_loss_metric: 0.122979
# [586]	valid_0's auc: 0.860644	valid_0's focal_loss_metric: 0.122985
# [587]	valid_0's auc: 0.860898	valid_0's focal_loss_metric: 0.122925
# [588]	valid_0's auc: 0.860678	valid_0's focal_loss_metric: 0.122926
# [589]	valid_0's auc: 0.860407	valid_0's focal_loss_metric: 0.122934
# [590]	valid_0's auc: 0.860418	valid_0's focal_loss_metric: 0.122943
# [591]	valid_0's auc: 0.860597	valid_0's focal_loss_metric: 0.122884
# [592]	valid_0's auc: 0.860547	valid_0's focal_loss_metric: 0.122913
# [593]	valid_0's auc: 0.860588	valid_0's focal_loss_metric: 0.122871
# [594]	valid_0's auc: 0.860613	valid_0's focal_loss_metric: 0.122878
# [595]	valid_0's auc: 0.860555	valid_0's focal_loss_metric: 0.12289
# [596]	valid_0's auc: 0.860711	valid_0's focal_loss_metric: 0.122884
# [597]	valid_0's auc: 0.860641	valid_0's focal_loss_metric: 0.122851
# [598]	valid_0's auc: 0.860881	valid_0's focal_loss_metric: 0.122811
# [599]	valid_0's auc: 0.86085	valid_0's focal_loss_metric: 0.122782
# [600]	valid_0's auc: 0.860923	valid_0's focal_loss_metric: 0.122775
# [601]	valid_0's auc: 0.860898	valid_0's focal_loss_metric: 0.122747
# [602]	valid_0's auc: 0.860967	valid_0's focal_loss_metric: 0.12274
# [603]	valid_0's auc: 0.860965	valid_0's focal_loss_metric: 0.122741
# [604]	valid_0's auc: 0.861154	valid_0's focal_loss_metric: 0.122702
# [605]	valid_0's auc: 0.861118	valid_0's focal_loss_metric: 0.122673
# [606]	valid_0's auc: 0.861333	valid_0's focal_loss_metric: 0.122636
# [607]	valid_0's auc: 0.861497	valid_0's focal_loss_metric: 0.122602
# [608]	valid_0's auc: 0.861583	valid_0's focal_loss_metric: 0.122563
# [609]	valid_0's auc: 0.861542	valid_0's focal_loss_metric: 0.122536
# [610]	valid_0's auc: 0.861597	valid_0's focal_loss_metric: 0.12253
# [611]	valid_0's auc: 0.861653	valid_0's focal_loss_metric: 0.122531
# [612]	valid_0's auc: 0.861726	valid_0's focal_loss_metric: 0.122483
# [613]	valid_0's auc: 0.861851	valid_0's focal_loss_metric: 0.122464
# [614]	valid_0's auc: 0.861759	valid_0's focal_loss_metric: 0.122452
# [615]	valid_0's auc: 0.861954	valid_0's focal_loss_metric: 0.122413
# [616]	valid_0's auc: 0.861982	valid_0's focal_loss_metric: 0.122365
# [617]	valid_0's auc: 0.862252	valid_0's focal_loss_metric: 0.122322
# [618]	valid_0's auc: 0.862202	valid_0's focal_loss_metric: 0.122337
# [619]	valid_0's auc: 0.862478	valid_0's focal_loss_metric: 0.122271
# [620]	valid_0's auc: 0.862291	valid_0's focal_loss_metric: 0.12226
# [621]	valid_0's auc: 0.862659	valid_0's focal_loss_metric: 0.12223
# [622]	valid_0's auc: 0.862428	valid_0's focal_loss_metric: 0.122214
# [623]	valid_0's auc: 0.862606	valid_0's focal_loss_metric: 0.122198
# [624]	valid_0's auc: 0.862498	valid_0's focal_loss_metric: 0.122186
# [625]	valid_0's auc: 0.862768	valid_0's focal_loss_metric: 0.122158
# [626]	valid_0's auc: 0.862662	valid_0's focal_loss_metric: 0.122142
# [627]	valid_0's auc: 0.862924	valid_0's focal_loss_metric: 0.122102
# [628]	valid_0's auc: 0.862693	valid_0's focal_loss_metric: 0.122104
# [629]	valid_0's auc: 0.86296	valid_0's focal_loss_metric: 0.122066
# [630]	valid_0's auc: 0.862824	valid_0's focal_loss_metric: 0.122063
# [631]	valid_0's auc: 0.863038	valid_0's focal_loss_metric: 0.122038
# [632]	valid_0's auc: 0.862949	valid_0's focal_loss_metric: 0.122021
# [633]	valid_0's auc: 0.863161	valid_0's focal_loss_metric: 0.121984
# [634]	valid_0's auc: 0.86298	valid_0's focal_loss_metric: 0.121986
# [635]	valid_0's auc: 0.863175	valid_0's focal_loss_metric: 0.12195
# [636]	valid_0's auc: 0.863002	valid_0's focal_loss_metric: 0.121952
# [637]	valid_0's auc: 0.862765	valid_0's focal_loss_metric: 0.121974
# [638]	valid_0's auc: 0.863161	valid_0's focal_loss_metric: 0.121898
# [639]	valid_0's auc: 0.863337	valid_0's focal_loss_metric: 0.121864
# [640]	valid_0's auc: 0.863342	valid_0's focal_loss_metric: 0.121837
# [641]	valid_0's auc: 0.863367	valid_0's focal_loss_metric: 0.121833
# [642]	valid_0's auc: 0.86332	valid_0's focal_loss_metric: 0.121816
# [643]	valid_0's auc: 0.863535	valid_0's focal_loss_metric: 0.121793
# [644]	valid_0's auc: 0.863484	valid_0's focal_loss_metric: 0.121762
# [645]	valid_0's auc: 0.863663	valid_0's focal_loss_metric: 0.121758
# [646]	valid_0's auc: 0.863638	valid_0's focal_loss_metric: 0.121726
# [647]	valid_0's auc: 0.863827	valid_0's focal_loss_metric: 0.121706
# [648]	valid_0's auc: 0.863844	valid_0's focal_loss_metric: 0.121688
# [649]	valid_0's auc: 0.863944	valid_0's focal_loss_metric: 0.121685
# [650]	valid_0's auc: 0.863975	valid_0's focal_loss_metric: 0.121653
# [651]	valid_0's auc: 0.86412	valid_0's focal_loss_metric: 0.121633
# [652]	valid_0's auc: 0.864287	valid_0's focal_loss_metric: 0.121585
# [653]	valid_0's auc: 0.864424	valid_0's focal_loss_metric: 0.121546
# [654]	valid_0's auc: 0.864474	valid_0's focal_loss_metric: 0.121516
# [655]	valid_0's auc: 0.864591	valid_0's focal_loss_metric: 0.121513
# [656]	valid_0's auc: 0.864655	valid_0's focal_loss_metric: 0.121465
# [657]	valid_0's auc: 0.864781	valid_0's focal_loss_metric: 0.121463
# [658]	valid_0's auc: 0.864792	valid_0's focal_loss_metric: 0.121431
# [659]	valid_0's auc: 0.864992	valid_0's focal_loss_metric: 0.121412
# [660]	valid_0's auc: 0.864923	valid_0's focal_loss_metric: 0.121395
# [661]	valid_0's auc: 0.864889	valid_0's focal_loss_metric: 0.121399
# [662]	valid_0's auc: 0.865146	valid_0's focal_loss_metric: 0.121353
# [663]	valid_0's auc: 0.864987	valid_0's focal_loss_metric: 0.121375
# [664]	valid_0's auc: 0.865246	valid_0's focal_loss_metric: 0.121331
# [665]	valid_0's auc: 0.865146	valid_0's focal_loss_metric: 0.121328
# [666]	valid_0's auc: 0.865533	valid_0's focal_loss_metric: 0.121261
# [667]	valid_0's auc: 0.865436	valid_0's focal_loss_metric: 0.121236
# [668]	valid_0's auc: 0.865291	valid_0's focal_loss_metric: 0.121291
# [669]	valid_0's auc: 0.865346	valid_0's focal_loss_metric: 0.121254
# [670]	valid_0's auc: 0.865201	valid_0's focal_loss_metric: 0.121252
# [671]	valid_0's auc: 0.865466	valid_0's focal_loss_metric: 0.121207
# [672]	valid_0's auc: 0.86533	valid_0's focal_loss_metric: 0.121229
# [673]	valid_0's auc: 0.865561	valid_0's focal_loss_metric: 0.121185
# [674]	valid_0's auc: 0.865405	valid_0's focal_loss_metric: 0.121206
# [675]	valid_0's auc: 0.865636	valid_0's focal_loss_metric: 0.121165
# [676]	valid_0's auc: 0.865486	valid_0's focal_loss_metric: 0.121162
# [677]	valid_0's auc: 0.865773	valid_0's focal_loss_metric: 0.121128
# [678]	valid_0's auc: 0.865606	valid_0's focal_loss_metric: 0.121113
# [679]	valid_0's auc: 0.86596	valid_0's focal_loss_metric: 0.121088
# [680]	valid_0's auc: 0.865935	valid_0's focal_loss_metric: 0.121043
# [681]	valid_0's auc: 0.866102	valid_0's focal_loss_metric: 0.121008
# [682]	valid_0's auc: 0.866185	valid_0's focal_loss_metric: 0.120986
# [683]	valid_0's auc: 0.866314	valid_0's focal_loss_metric: 0.120937
# [684]	valid_0's auc: 0.86638	valid_0's focal_loss_metric: 0.120943
# [685]	valid_0's auc: 0.866322	valid_0's focal_loss_metric: 0.120936
# [686]	valid_0's auc: 0.86642	valid_0's focal_loss_metric: 0.120933
# [687]	valid_0's auc: 0.866459	valid_0's focal_loss_metric: 0.120889
# [688]	valid_0's auc: 0.866654	valid_0's focal_loss_metric: 0.120875
# [689]	valid_0's auc: 0.8665	valid_0's focal_loss_metric: 0.120863
# [690]	valid_0's auc: 0.866679	valid_0's focal_loss_metric: 0.120849
# [691]	valid_0's auc: 0.866525	valid_0's focal_loss_metric: 0.120838
# [692]	valid_0's auc: 0.86669	valid_0's focal_loss_metric: 0.120825
# [693]	valid_0's auc: 0.866564	valid_0's focal_loss_metric: 0.120814
# [694]	valid_0's auc: 0.866737	valid_0's focal_loss_metric: 0.120802
# [695]	valid_0's auc: 0.86664	valid_0's focal_loss_metric: 0.120787
# [696]	valid_0's auc: 0.866857	valid_0's focal_loss_metric: 0.120763
# [697]	valid_0's auc: 0.866723	valid_0's focal_loss_metric: 0.120753
# [698]	valid_0's auc: 0.866556	valid_0's focal_loss_metric: 0.120775
# [699]	valid_0's auc: 0.866302	valid_0's focal_loss_metric: 0.120784
# [700]	valid_0's auc: 0.866748	valid_0's focal_loss_metric: 0.120723
# [701]	valid_0's auc: 0.866406	valid_0's focal_loss_metric: 0.120743
# ...
# [15779]	valid_0's auc: 0.936669	valid_0's focal_loss_metric: 0.0805178
# [15780]	valid_0's auc: 0.936655	valid_0's focal_loss_metric: 0.0805269
# [15781]	valid_0's auc: 0.936672	valid_0's focal_loss_metric: 0.0805166
# [15782]	valid_0's auc: 0.936655	valid_0's focal_loss_metric: 0.0805275
# [15783]	valid_0's auc: 0.936672	valid_0's focal_loss_metric: 0.0805159
# [15784]	valid_0's auc: 0.936655	valid_0's focal_loss_metric: 0.0805267
# [15785]	valid_0's auc: 0.936672	valid_0's focal_loss_metric: 0.0805153
# [15786]	valid_0's auc: 0.936655	valid_0's focal_loss_metric: 0.080526
# [15787]	valid_0's auc: 0.936666	valid_0's focal_loss_metric: 0.0805291
# [15788]	valid_0's auc: 0.93666	valid_0's focal_loss_metric: 0.0805256
# [15789]	valid_0's auc: 0.936686	valid_0's focal_loss_metric: 0.0805139
# [15790]	valid_0's auc: 0.936663	valid_0's focal_loss_metric: 0.0805236
# [15791]	valid_0's auc: 0.936672	valid_0's focal_loss_metric: 0.0805181
# [15792]	valid_0's auc: 0.936686	valid_0's focal_loss_metric: 0.0805235
# [15793]	valid_0's auc: 0.9367	valid_0's focal_loss_metric: 0.0805181
# [15794]	valid_0's auc: 0.936688	valid_0's focal_loss_metric: 0.0805234
# [15795]	valid_0's auc: 0.936672	valid_0's focal_loss_metric: 0.0805266
# [15796]	valid_0's auc: 0.936691	valid_0's focal_loss_metric: 0.0805246
# [15797]	valid_0's auc: 0.936652	valid_0's focal_loss_metric: 0.0805273
# [15798]	valid_0's auc: 0.936683	valid_0's focal_loss_metric: 0.0805252
# [15799]	valid_0's auc: 0.936652	valid_0's focal_loss_metric: 0.0805274
# [15800]	valid_0's auc: 0.936683	valid_0's focal_loss_metric: 0.0805255
# [15801]	valid_0's auc: 0.936655	valid_0's focal_loss_metric: 0.0805288
# [15802]	valid_0's auc: 0.936677	valid_0's focal_loss_metric: 0.080527
# [15803]	valid_0's auc: 0.936655	valid_0's focal_loss_metric: 0.0805297
# [15804]	valid_0's auc: 0.936686	valid_0's focal_loss_metric: 0.080526
# [15805]	valid_0's auc: 0.936716	valid_0's focal_loss_metric: 0.0805229
# [15806]	valid_0's auc: 0.936719	valid_0's focal_loss_metric: 0.0805252
# [15807]	valid_0's auc: 0.936727	valid_0's focal_loss_metric: 0.080518
# [15808]	valid_0's auc: 0.936725	valid_0's focal_loss_metric: 0.0805225
# [15809]	valid_0's auc: 0.936744	valid_0's focal_loss_metric: 0.0805133
# [15810]	valid_0's auc: 0.936722	valid_0's focal_loss_metric: 0.0805179
# [15811]	valid_0's auc: 0.936747	valid_0's focal_loss_metric: 0.0805107
# [15812]	valid_0's auc: 0.936719	valid_0's focal_loss_metric: 0.0805172
# [15813]	valid_0's auc: 0.936725	valid_0's focal_loss_metric: 0.0805094
# [15814]	valid_0's auc: 0.936739	valid_0's focal_loss_metric: 0.0805032
# [15815]	valid_0's auc: 0.936719	valid_0's focal_loss_metric: 0.080506
# [15816]	valid_0's auc: 0.936736	valid_0's focal_loss_metric: 0.0805026
# [15817]	valid_0's auc: 0.936719	valid_0's focal_loss_metric: 0.0805054
# [15818]	valid_0's auc: 0.936733	valid_0's focal_loss_metric: 0.080502
# [15819]	valid_0's auc: 0.936719	valid_0's focal_loss_metric: 0.0805067
# [15820]	valid_0's auc: 0.936713	valid_0's focal_loss_metric: 0.080509
# [15821]	valid_0's auc: 0.936686	valid_0's focal_loss_metric: 0.0805117
# [15822]	valid_0's auc: 0.936713	valid_0's focal_loss_metric: 0.0805097
# [15823]	valid_0's auc: 0.936697	valid_0's focal_loss_metric: 0.0805118
# [15824]	valid_0's auc: 0.936697	valid_0's focal_loss_metric: 0.0805087
# [15825]	valid_0's auc: 0.936691	valid_0's focal_loss_metric: 0.0805116
# [15826]	valid_0's auc: 0.936711	valid_0's focal_loss_metric: 0.080517
# [15827]	valid_0's auc: 0.936744	valid_0's focal_loss_metric: 0.0805091
# [15828]	valid_0's auc: 0.936708	valid_0's focal_loss_metric: 0.0805156
# [15829]	valid_0's auc: 0.936747	valid_0's focal_loss_metric: 0.0805087
# [15830]	valid_0's auc: 0.936713	valid_0's focal_loss_metric: 0.0805133
# [15831]	valid_0's auc: 0.936739	valid_0's focal_loss_metric: 0.0805063
# [15832]	valid_0's auc: 0.936713	valid_0's focal_loss_metric: 0.0805109
# [15833]	valid_0's auc: 0.936747	valid_0's focal_loss_metric: 0.0805019
# [15834]	valid_0's auc: 0.936713	valid_0's focal_loss_metric: 0.0805076
# [15835]	valid_0's auc: 0.93675	valid_0's focal_loss_metric: 0.0804987
# [15836]	valid_0's auc: 0.936716	valid_0's focal_loss_metric: 0.0805032
# [15837]	valid_0's auc: 0.936755	valid_0's focal_loss_metric: 0.0804963
# [15838]	valid_0's auc: 0.936716	valid_0's focal_loss_metric: 0.0805028
# [15839]	valid_0's auc: 0.936764	valid_0's focal_loss_metric: 0.0804947
# [15840]	valid_0's auc: 0.936719	valid_0's focal_loss_metric: 0.0805012
# [15841]	valid_0's auc: 0.936761	valid_0's focal_loss_metric: 0.0804942
# [15842]	valid_0's auc: 0.936722	valid_0's focal_loss_metric: 0.0804988
# [15843]	valid_0's auc: 0.936761	valid_0's focal_loss_metric: 0.0804899
# [15844]	valid_0's auc: 0.93673	valid_0's focal_loss_metric: 0.0804954
# [15845]	valid_0's auc: 0.936755	valid_0's focal_loss_metric: 0.0804912
# [15846]	valid_0's auc: 0.936766	valid_0's focal_loss_metric: 0.0804933
# [15847]	valid_0's auc: 0.93675	valid_0's focal_loss_metric: 0.0804952
# [15848]	valid_0's auc: 0.936719	valid_0's focal_loss_metric: 0.0804912
# [15849]	valid_0's auc: 0.936716	valid_0's focal_loss_metric: 0.0805032
# [15850]	valid_0's auc: 0.936747	valid_0's focal_loss_metric: 0.0804988
# [15851]	valid_0's auc: 0.936713	valid_0's focal_loss_metric: 0.0805081
# [15852]	valid_0's auc: 0.936766	valid_0's focal_loss_metric: 0.0804994
# [15853]	valid_0's auc: 0.936711	valid_0's focal_loss_metric: 0.0805084
# [15854]	valid_0's auc: 0.936766	valid_0's focal_loss_metric: 0.0805
# [15855]	valid_0's auc: 0.936789	valid_0's focal_loss_metric: 0.080482
# [15856]	valid_0's auc: 0.936786	valid_0's focal_loss_metric: 0.0804815
# [15857]	valid_0's auc: 0.93678	valid_0's focal_loss_metric: 0.0804847
# [15858]	valid_0's auc: 0.936794	valid_0's focal_loss_metric: 0.0804791
# [15859]	valid_0's auc: 0.93678	valid_0's focal_loss_metric: 0.0804843
# [15860]	valid_0's auc: 0.936811	valid_0's focal_loss_metric: 0.0804783
# [15861]	valid_0's auc: 0.936794	valid_0's focal_loss_metric: 0.0804835
# [15862]	valid_0's auc: 0.936817	valid_0's focal_loss_metric: 0.0804776
# [15863]	valid_0's auc: 0.936797	valid_0's focal_loss_metric: 0.0804835
# [15864]	valid_0's auc: 0.936822	valid_0's focal_loss_metric: 0.0804776
# [15865]	valid_0's auc: 0.9368	valid_0's focal_loss_metric: 0.0804827
# [15866]	valid_0's auc: 0.936817	valid_0's focal_loss_metric: 0.0804769
# [15867]	valid_0's auc: 0.936803	valid_0's focal_loss_metric: 0.0804827
# [15868]	valid_0's auc: 0.936819	valid_0's focal_loss_metric: 0.0804769
# [15869]	valid_0's auc: 0.936819	valid_0's focal_loss_metric: 0.0804799
# [15870]	valid_0's auc: 0.936825	valid_0's focal_loss_metric: 0.0804745
# [15871]	valid_0's auc: 0.936803	valid_0's focal_loss_metric: 0.0804832
# [15872]	valid_0's auc: 0.936825	valid_0's focal_loss_metric: 0.0804745
# [15873]	valid_0's auc: 0.936803	valid_0's focal_loss_metric: 0.0804832
# [15874]	valid_0's auc: 0.936825	valid_0's focal_loss_metric: 0.0804747
# [15875]	valid_0's auc: 0.936803	valid_0's focal_loss_metric: 0.0804833
# [15876]	valid_0's auc: 0.936825	valid_0's focal_loss_metric: 0.080475
# [15877]	valid_0's auc: 0.936836	valid_0's focal_loss_metric: 0.080478
# [15878]	valid_0's auc: 0.936808	valid_0's focal_loss_metric: 0.0804826
# [15879]	valid_0's auc: 0.936847	valid_0's focal_loss_metric: 0.080475
# [15880]	valid_0's auc: 0.936814	valid_0's focal_loss_metric: 0.0804811
# [15881]	valid_0's auc: 0.936842	valid_0's focal_loss_metric: 0.0804738
# [15882]	valid_0's auc: 0.936847	valid_0's focal_loss_metric: 0.0804785
# [15883]	valid_0's auc: 0.936844	valid_0's focal_loss_metric: 0.0804715
# [15884]	valid_0's auc: 0.936822	valid_0's focal_loss_metric: 0.0804777
# [15885]	valid_0's auc: 0.936847	valid_0's focal_loss_metric: 0.080468
# [15886]	valid_0's auc: 0.936822	valid_0's focal_loss_metric: 0.080477
# [15887]	valid_0's auc: 0.936847	valid_0's focal_loss_metric: 0.0804687
# [15888]	valid_0's auc: 0.936825	valid_0's focal_loss_metric: 0.0804772
# [15889]	valid_0's auc: 0.936839	valid_0's focal_loss_metric: 0.0804698
# [15890]	valid_0's auc: 0.936825	valid_0's focal_loss_metric: 0.0804783
# [15891]	valid_0's auc: 0.936833	valid_0's focal_loss_metric: 0.08047
# [15892]	valid_0's auc: 0.936819	valid_0's focal_loss_metric: 0.0804785
# [15893]	valid_0's auc: 0.936822	valid_0's focal_loss_metric: 0.0804711
# [15894]	valid_0's auc: 0.936803	valid_0's focal_loss_metric: 0.0804795
# [15895]	valid_0's auc: 0.936822	valid_0's focal_loss_metric: 0.0804713
# [15896]	valid_0's auc: 0.936783	valid_0's focal_loss_metric: 0.0804832
# [15897]	valid_0's auc: 0.936822	valid_0's focal_loss_metric: 0.0804736
# [15898]	valid_0's auc: 0.936783	valid_0's focal_loss_metric: 0.0804826
# [15899]	valid_0's auc: 0.936803	valid_0's focal_loss_metric: 0.0804744
# [15900]	valid_0's auc: 0.936786	valid_0's focal_loss_metric: 0.0804828
# [15901]	valid_0's auc: 0.936786	valid_0's focal_loss_metric: 0.0804755
# [15902]	valid_0's auc: 0.936783	valid_0's focal_loss_metric: 0.0804839
# [15903]	valid_0's auc: 0.936786	valid_0's focal_loss_metric: 0.0804758
# [15904]	valid_0's auc: 0.93678	valid_0's focal_loss_metric: 0.0804841
# [15905]	valid_0's auc: 0.936783	valid_0's focal_loss_metric: 0.0804768
# [15906]	valid_0's auc: 0.936778	valid_0's focal_loss_metric: 0.0804851
# [15907]	valid_0's auc: 0.936794	valid_0's focal_loss_metric: 0.0804847
# [15908]	valid_0's auc: 0.9368	valid_0's focal_loss_metric: 0.0804826
# [15909]	valid_0's auc: 0.936791	valid_0's focal_loss_metric: 0.0804841
# [15910]	valid_0's auc: 0.936797	valid_0's focal_loss_metric: 0.080482
# [15911]	valid_0's auc: 0.936817	valid_0's focal_loss_metric: 0.0804728
# [15912]	valid_0's auc: 0.9368	valid_0's focal_loss_metric: 0.0804819
# [15913]	valid_0's auc: 0.9368	valid_0's focal_loss_metric: 0.0804738
# [15914]	valid_0's auc: 0.936786	valid_0's focal_loss_metric: 0.0804857
# [15915]	valid_0's auc: 0.9368	valid_0's focal_loss_metric: 0.0804763
# [15916]	valid_0's auc: 0.936789	valid_0's focal_loss_metric: 0.0804826
# [15917]	valid_0's auc: 0.936778	valid_0's focal_loss_metric: 0.0804841
# [15918]	valid_0's auc: 0.936778	valid_0's focal_loss_metric: 0.0804824
# [15919]	valid_0's auc: 0.93678	valid_0's focal_loss_metric: 0.0804754
# [15920]	valid_0's auc: 0.936778	valid_0's focal_loss_metric: 0.0804802
# [15921]	valid_0's auc: 0.936775	valid_0's focal_loss_metric: 0.0804744
# [15922]	valid_0's auc: 0.936778	valid_0's focal_loss_metric: 0.0804814
# [15923]	valid_0's auc: 0.936766	valid_0's focal_loss_metric: 0.0804802
# [15924]	valid_0's auc: 0.936775	valid_0's focal_loss_metric: 0.0804813
# [15925]	valid_0's auc: 0.936764	valid_0's focal_loss_metric: 0.0804801
# [15926]	valid_0's auc: 0.936775	valid_0's focal_loss_metric: 0.0804812
# [15927]	valid_0's auc: 0.936764	valid_0's focal_loss_metric: 0.0804827
# [15928]	valid_0's auc: 0.936775	valid_0's focal_loss_metric: 0.0804805
# [15929]	valid_0's auc: 0.936764	valid_0's focal_loss_metric: 0.0804794
# [15930]	valid_0's auc: 0.936775	valid_0's focal_loss_metric: 0.0804804
# [15931]	valid_0's auc: 0.936761	valid_0's focal_loss_metric: 0.0804793
# [15932]	valid_0's auc: 0.936772	valid_0's focal_loss_metric: 0.0804864
# [15933]	valid_0's auc: 0.936755	valid_0's focal_loss_metric: 0.0804806
# [15934]	valid_0's auc: 0.936772	valid_0's focal_loss_metric: 0.0804854
# [15935]	valid_0's auc: 0.936769	valid_0's focal_loss_metric: 0.0804785
# [15936]	valid_0's auc: 0.936778	valid_0's focal_loss_metric: 0.0804847
# [15937]	valid_0's auc: 0.936772	valid_0's focal_loss_metric: 0.0804754
# [15938]	valid_0's auc: 0.936778	valid_0's focal_loss_metric: 0.0804844
# [15939]	valid_0's auc: 0.936772	valid_0's focal_loss_metric: 0.0804763
# [15940]	valid_0's auc: 0.936783	valid_0's focal_loss_metric: 0.0804846
# [15941]	valid_0's auc: 0.936772	valid_0's focal_loss_metric: 0.0804774
# [15942]	valid_0's auc: 0.936775	valid_0's focal_loss_metric: 0.0804857
# [15943]	valid_0's auc: 0.936778	valid_0's focal_loss_metric: 0.0804777
# [15944]	valid_0's auc: 0.93678	valid_0's focal_loss_metric: 0.0804894
# [15945]	valid_0's auc: 0.936778	valid_0's focal_loss_metric: 0.0804801
# [15946]	valid_0's auc: 0.93678	valid_0's focal_loss_metric: 0.080489
# [15947]	valid_0's auc: 0.936766	valid_0's focal_loss_metric: 0.080481
# [15948]	valid_0's auc: 0.93678	valid_0's focal_loss_metric: 0.0804892
# [15949]	valid_0's auc: 0.936761	valid_0's focal_loss_metric: 0.0804821
# [15950]	valid_0's auc: 0.936775	valid_0's focal_loss_metric: 0.0804903
# [15951]	valid_0's auc: 0.936755	valid_0's focal_loss_metric: 0.0804832
# [15952]	valid_0's auc: 0.936769	valid_0's focal_loss_metric: 0.0804879
# [15953]	valid_0's auc: 0.936741	valid_0's focal_loss_metric: 0.0804818
# [15954]	valid_0's auc: 0.936772	valid_0's focal_loss_metric: 0.0804876
# [15955]	valid_0's auc: 0.936744	valid_0's focal_loss_metric: 0.0804816
# [15956]	valid_0's auc: 0.936755	valid_0's focal_loss_metric: 0.0804875
# [15957]	valid_0's auc: 0.93673	valid_0's focal_loss_metric: 0.0804815
# [15958]	valid_0's auc: 0.93675	valid_0's focal_loss_metric: 0.0804873
# [15959]	valid_0's auc: 0.936739	valid_0's focal_loss_metric: 0.0804775
# [15960]	valid_0's auc: 0.93675	valid_0's focal_loss_metric: 0.0804676
# [15961]	valid_0's auc: 0.936755	valid_0's focal_loss_metric: 0.0804727
# [15962]	valid_0's auc: 0.936775	valid_0's focal_loss_metric: 0.0804674
# [15963]	valid_0's auc: 0.936758	valid_0's focal_loss_metric: 0.0804723
# [15964]	valid_0's auc: 0.936755	valid_0's focal_loss_metric: 0.0804681
# [15965]	valid_0's auc: 0.936747	valid_0's focal_loss_metric: 0.0804796
# [15966]	valid_0's auc: 0.936752	valid_0's focal_loss_metric: 0.0804817
# [15967]	valid_0's auc: 0.93675	valid_0's focal_loss_metric: 0.0804753
# [15968]	valid_0's auc: 0.936744	valid_0's focal_loss_metric: 0.0804832
# [15969]	valid_0's auc: 0.936741	valid_0's focal_loss_metric: 0.0804775
# [15970]	valid_0's auc: 0.936747	valid_0's focal_loss_metric: 0.0804766
# [15971]	valid_0's auc: 0.936747	valid_0's focal_loss_metric: 0.0804734
# [15972]	valid_0's auc: 0.936752	valid_0's focal_loss_metric: 0.080471
# [15973]	valid_0's auc: 0.936752	valid_0's focal_loss_metric: 0.0804729
# [15974]	valid_0's auc: 0.936747	valid_0's focal_loss_metric: 0.0804706
# [15975]	valid_0's auc: 0.93675	valid_0's focal_loss_metric: 0.0804674
# [15976]	valid_0's auc: 0.936744	valid_0's focal_loss_metric: 0.0804711
# [15977]	valid_0's auc: 0.936733	valid_0's focal_loss_metric: 0.0804706
# [15978]	valid_0's auc: 0.936719	valid_0's focal_loss_metric: 0.0804787
# [15979]	valid_0's auc: 0.936733	valid_0's focal_loss_metric: 0.0804706
# [15980]	valid_0's auc: 0.936722	valid_0's focal_loss_metric: 0.0804823
# [15981]	valid_0's auc: 0.936727	valid_0's focal_loss_metric: 0.0804729
# [15982]	valid_0's auc: 0.936722	valid_0's focal_loss_metric: 0.0804816
# [15983]	valid_0's auc: 0.936727	valid_0's focal_loss_metric: 0.0804724
# [15984]	valid_0's auc: 0.936711	valid_0's focal_loss_metric: 0.0804785
# [15985]	valid_0's auc: 0.93673	valid_0's focal_loss_metric: 0.0804716
# [15986]	valid_0's auc: 0.936711	valid_0's focal_loss_metric: 0.0804764
# [15987]	valid_0's auc: 0.936727	valid_0's focal_loss_metric: 0.0804707
# [15988]	valid_0's auc: 0.936725	valid_0's focal_loss_metric: 0.0804718
# [15989]	valid_0's auc: 0.936733	valid_0's focal_loss_metric: 0.0804707
# [15990]	valid_0's auc: 0.936713	valid_0's focal_loss_metric: 0.0804778
# [15991]	valid_0's auc: 0.93673	valid_0's focal_loss_metric: 0.0804774
# [15992]	valid_0's auc: 0.936716	valid_0's focal_loss_metric: 0.0804757
# [15993]	valid_0's auc: 0.93673	valid_0's focal_loss_metric: 0.0804753
# [15994]	valid_0's auc: 0.936761	valid_0's focal_loss_metric: 0.0804761
# [15995]	valid_0's auc: 0.936722	valid_0's focal_loss_metric: 0.080482
# [15996]	valid_0's auc: 0.936722	valid_0's focal_loss_metric: 0.0804781
# [15997]	valid_0's auc: 0.936727	valid_0's focal_loss_metric: 0.0804796
# [15998]	valid_0's auc: 0.936722	valid_0's focal_loss_metric: 0.0804757
# [15999]	valid_0's auc: 0.936727	valid_0's focal_loss_metric: 0.0804772
# [16000]	valid_0's auc: 0.936722	valid_0's focal_loss_metric: 0.0804751
# LGBMClassifier(force_row_wise=True, learning_rate=0.25, max_depth=1,
#                metric='auc', n_estimators=16000, num_threads=100,
#                objective=<function focal_loss_objective at 0x00000288E14B55E8>,
#                verbosity=1)

# %%
from scipy.special import expit                               # Import the sigmoid function from scipy
probs = expit(gbm_focal_loss.predict(X_test, raw_score=True))   # Get raw scores and then compute the probability positive class
                                                              # using the sigmoid function
y_pred = (probs > 0.5).astype(int)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
confusion = confusion_matrix(y_pred, y_test)
confusion
# Out:
# array([[549,  94],
#        [ 44, 511]], dtype=int64)

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
lgb_acc = accuracy_score(y_pred, y_test)
lgb_prec = precision_score(y_pred, y_test)
lgb_rec = recall_score(y_pred, y_test)
lgb_f1 = f1_score(y_pred, y_test)
lgb_auprc = average_precision_score(y_pred, y_test)
lgb_auroc = roc_auc_score(y_test, y_pred)
lgb_mcc = matthews_corrcoef(y_pred, y_test)

lgb_sens = TP / (TP + FN)
lgb_spec = TN / (TN + FP)

storeResults('LightGBM Focal Loss',lgb_acc,lgb_prec,lgb_rec,lgb_f1,lgb_auprc,lgb_auroc,lgb_mcc,lgb_sens,lgb_spec)

# %%
lgb_acc
# Out:
# 0.8848080133555927

# %%
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, average_precision_score, roc_auc_score, matthews_corrcoef

# Assuming you have a dataset 'data' containing your features and labels
# data should be a 2D array-like object where each row represents a sample and each column represents a feature
# labels should be a 1D array-like object containing the corresponding labels for each sample

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

clf1 = AdaBoostClassifier(n_estimators=100, random_state=0)
clf2 = RandomForestClassifier(n_estimators=50, random_state=1)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2)], voting='soft')
eclf1.fit(X_train, y_train)
y_pred = eclf1.predict(X_test)

confusion = confusion_matrix(y_test, y_pred)
TP = confusion[1,1] # true positives
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

stac_acc = accuracy_score(y_test, y_pred)
stac_prec = precision_score(y_test, y_pred)
stac_rec = recall_score(y_test, y_pred)
stac_f1 = f1_score(y_test, y_pred)
stac_auprc = average_precision_score(y_test, y_pred)
stac_auroc = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
stac_mcc = matthews_corrcoef(y_test, y_pred)

stac_sens = TP / (TP + FN)
stac_spec = TN / (TN + FP)

stac_acc  # Printing accuracy score, you can store it or use as needed

# Assuming you have a function 'storeResults' defined to store the results
storeResults('Voting Classifier', stac_acc, stac_prec, stac_rec, stac_f1, stac_auprc, stac_auroc, stac_mcc, stac_sens, stac_spec)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-bf2b937af5c8> in <module>
#       8
#       9 # Splitting the data into training and testing sets
# ---> 10 X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)
#      11
#      12 clf1 = AdaBoostClassifier(n_estimators=100, random_state=0)
#
# NameError: name 'data' is not defined

# %%
stac_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-293a0ee9a085> in <module>
# ----> 1 stac_acc
#
# NameError: name 'stac_acc' is not defined
